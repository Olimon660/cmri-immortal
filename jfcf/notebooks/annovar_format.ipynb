# %%
import pandas as pd
from glob import glob
import re
pd.options.display.max_columns = 100
from tqdm import tqdm_notebook

# %%
def map_name(name):
    name = name.replace("-", "_") 
    if name == "IIICF":
        name = "IIICF_P7"
    if name == "IIICFE6E7C4post":
        name = "IIICF_E6E7_C4_post"
    if name == "IIICFE6E7C4pre":
        name = "IIICF_E6E7_C4_pre"
    if name == "IVG_BF_LXSNpost":
        name = "IVG_BF_LXSN_post"
    if name == "IVG_BF_LXSNpre":
        name = "IVG_BF_LXSN_pre"
    if name == "JFCF_6_T_1_P":
        name = "JFCF_6_T_1_P_TEL"
    if name == "JFCF_6_T_1_PALT":
        name = "JFCF_6_T_1_P_ALT"
    if name == "JFCF6_P12_H06L4ALXX_6":
        name = "JFCF_6"
    if name in ("JFCF6_T_1J_1_3C_H06L4ALXX_3", "JFCF6_T_1J_1_3C"):
        name = "JFCF_6_T_1J_1_3C"
    if name in ("JFCF6_T_1J_6B_H06L4ALXX_4", "JFCF6_T_1J_6B"):
        name = "JFCF_6_T_1J_6B"
    if name == "JFCF_61M":
        name = "JFCF_6_T_1_M"
    if name == "JFCF_61Q":
        name = "JFCF_6_T_1_Q"
    if name == "LFS05F24post":
        name = "LFS_05F_24_post"
    if name == "LFS05F24pre":
        name = "LFS_05F_24_pre"
    if name == "MeT_4Apost":
        name = "MeT_4A_post"
    if name == "MeT_4Apre":
        name = "MeT_4A_pre"
    return name

# %%
def split_gene(df, sep='&'):
    tmp = pd.DataFrame(columns=df.columns)
    for index, row in tqdm_notebook(df.iterrows()):
        genes = row['Gene']
        for gene in genes.split(sep):
            if gene == 'NONE':
                continue
            row['Gene'] = gene
            tmp = tmp.append(row)
    return tmp

# %% [markdown]
# # combined annovar

# %%
df_list = []
for fp in glob(
        "/home/scai/processing_simoncai/tmm/tel_vs_alt/immortal_simon/annovar/somatic/*"
):
    name = fp.replace(
        "/home/scai/processing_simoncai/tmm/tel_vs_alt/immortal_simon/annovar/somatic/",
        "")
    sample = re.search(r"(JF.*)\.hg19_.*", name).group(1)
    df = pd.read_csv(fp, sep='\t')
    df['sample'] = sample
    df_list.append(df)
df_all = pd.concat(df_list)
df_all.to_csv(
    "/home/scai/processing_simoncai/tmm/tel_vs_alt/immortal_simon/annovar/combined_somatic.tsv",
    index=False,
    sep='\t')

# %%
df_all = pd.read_csv("/home/scai/processing_simoncai/tmm/tel_vs_alt/immortal_simon/annovar/combined_somatic.tsv", sep='\t')

# %%
df_all.groupby(['Func.refGene']).size()
# Out:
# Func.refGene
# UTR3                    1256
# UTR5                     188
# downstream               852
# exonic                   940
# intergenic             83056
# intronic               47278
# ncRNA_exonic             600
# ncRNA_intronic          9924
# ncRNA_splicing             7
# splicing                  34
# upstream                 869
# upstream;downstream       28
# dtype: int64

# %%
df_all[df_all['Gene.refGene'].str.contains('TP53TG3D')]
# Out:
#          Chr     Start       End Ref Alt Func.refGene           Gene.refGene  \
# 22972  chr16  32265727  32265727   T   C     intronic  LOC102723713;TP53TG3D
# 22973  chr16  32265744  32265744   T   C     intronic  LOC102723713;TP53TG3D
# 40828  chr16  32265727  32265727   T   C     intronic  LOC102723713;TP53TG3D
# 40829  chr16  32265744  32265744   T   C     intronic  LOC102723713;TP53TG3D
# 60289  chr16  32265727  32265727   T   C     intronic  LOC102723713;TP53TG3D
# 60290  chr16  32265744  32265744   T   C     intronic  LOC102723713;TP53TG3D
# 66524  chr16  32278918  32278918   C   T   intergenic     TP53TG3D;LOC390705
#
#           GeneDetail.refGene ExonicFunc.refGene AAChange.refGene cytoBand  \
# 22972                      .                  .                .  16p11.2
# 22973                      .                  .                .  16p11.2
# 40828                      .                  .                .  16p11.2
# 40829                      .                  .                .  16p11.2
# 60289                      .                  .                .  16p11.2
# 60290                      .                  .                .  16p11.2
# 66524  dist=11669;dist=21950                  .                .  16p11.2
#
#       ExAC_ALL ExAC_AFR ExAC_AMR ExAC_EAS ExAC_FIN ExAC_NFE ExAC_OTH ExAC_SAS  \
# 22972   0.2522   0.3839   0.2151   0.2247   0.2234   0.2144   0.2356   0.2692
# 22973   0.0130   0.1204   0.0160    0.005   0.0051   0.0197   0.0108   0.0037
# 40828   0.2522   0.3839   0.2151   0.2247   0.2234   0.2144   0.2356   0.2692
# 40829   0.0130   0.1204   0.0160    0.005   0.0051   0.0197   0.0108   0.0037
# 60289   0.2522   0.3839   0.2151   0.2247   0.2234   0.2144   0.2356   0.2692
# 60290   0.0130   0.1204   0.0160    0.005   0.0051   0.0197   0.0108   0.0037
# 66524        .        .        .        .        .        .        .        .
#
#          avsnp147 SIFT_score SIFT_pred Polyphen2_HDIV_score  \
# 22972  rs62043559      0.448         T                    .
# 22973  rs71264362      0.775         T                    .
# 40828  rs62043559      0.448         T                    .
# 40829  rs71264362      0.775         T                    .
# 60289  rs62043559      0.448         T                    .
# 60290  rs71264362      0.775         T                    .
# 66524           .          .         .                    .
#
#       Polyphen2_HDIV_pred Polyphen2_HVAR_score Polyphen2_HVAR_pred LRT_score  \
# 22972                   .                    .                   .         .
# 22973                   .                    .                   .         .
# 40828                   .                    .                   .         .
# 40829                   .                    .                   .         .
# 60289                   .                    .                   .         .
# 60290                   .                    .                   .         .
# 66524                   .                    .                   .         .
#
#       LRT_pred MutationTaster_score MutationTaster_pred  \
# 22972        .                    1                   N
# 22973        .                    1                   N
# 40828        .                    1                   N
# 40829        .                    1                   N
# 60289        .                    1                   N
# 60290        .                    1                   N
# 66524        .                    .                   .
#
#       MutationAssessor_score MutationAssessor_pred FATHMM_score FATHMM_pred  \
# 22972                      0                     N            .           .
# 22973                      0                     N            .           .
# 40828                      0                     N            .           .
# 40829                      0                     N            .           .
# 60289                      0                     N            .           .
# 60290                      0                     N            .           .
# 66524                      .                     .            .           .
#
#       PROVEAN_score PROVEAN_pred VEST3_score CADD_raw CADD_phred DANN_score  \
# 22972           1.5            N       0.049   -0.184      1.186      0.342
# 22973           1.5            N       0.054   -0.262      0.808      0.302
# 40828           1.5            N       0.049   -0.184      1.186      0.342
# 40829           1.5            N       0.054   -0.262      0.808      0.302
# 60289           1.5            N       0.049   -0.184      1.186      0.342
# 60290           1.5            N       0.054   -0.262      0.808      0.302
# 66524             .            .           .        .          .          .
#
#       fathmm-MKL_coding_score fathmm-MKL_coding_pred MetaSVM_score  \
# 22972                   0.001                      N             .
# 22973                   0.001                      N             .
# 40828                   0.001                      N             .
# 40829                   0.001                      N             .
# 60289                   0.001                      N             .
# 60290                   0.001                      N             .
# 66524                       .                      .             .
#
#       MetaSVM_pred MetaLR_score MetaLR_pred integrated_fitCons_score  \
# 22972            .            .           .                    0.487
# 22973            .            .           .                    0.487
# 40828            .            .           .                    0.487
# 40829            .            .           .                    0.487
# 60289            .            .           .                    0.487
# 60290            .            .           .                    0.487
# 66524            .            .           .                        .
#
#       integrated_confidence_value GERP++_RS phyloP7way_vertebrate  \
# 22972                           0         .                     .
# 22973                           0         .                     .
# 40828                           0         .                     .
# 40829                           0         .                     .
# 60289                           0         .                     .
# 60290                           0         .                     .
# 66524                           .         .                     .
#
#       phyloP20way_mammalian phastCons7way_vertebrate phastCons20way_mammalian  \
# 22972                -1.068                        .                    0.023
# 22973                -1.068                        .                    0.005
# 40828                -1.068                        .                    0.023
# 40829                -1.068                        .                    0.005
# 60289                -1.068                        .                    0.023
# 60290                -1.068                        .                    0.005
# 66524                     .                        .                        .
#
#       SiPhy_29way_logOdds  Otherinfo1 Otherinfo2  Otherinfo3 Otherinfo4  \
# 22972                   .        0.25          .          37      chr16
# 22973                   .        0.25          .          35      chr16
# 40828                   .        0.25          .          37      chr16
# 40829                   .        0.25          .          35      chr16
# 60289                   .        0.25          .          37      chr16
# 60290                   .        0.25          .          35      chr16
# 66524                   .        0.25          .          71      chr16
#
#        Otherinfo5 Otherinfo6 Otherinfo7 Otherinfo8 Otherinfo9 Otherinfo10  \
# 22972    32265727          .          T          C          .        PASS
# 22973    32265744          .          T          C          .        PASS
# 40828    32265727          .          T          C          .        PASS
# 40829    32265744          .          T          C          .        PASS
# 60289    32265727          .          T          C          .        PASS
# 60290    32265744          .          T          C          .        PASS
# 66524    32278918          .          C          T          .        PASS
#
#                                              Otherinfo11  \
# 22972  CONTQ=93;DP=57;ECNT=2;GERMQ=93;MBQ=37,41;MFRL=...
# 22973  CONTQ=93;DP=56;ECNT=2;GERMQ=93;MBQ=37,41;MFRL=...
# 40828  CONTQ=93;DP=53;ECNT=2;GERMQ=93;MBQ=37,41;MFRL=...
# 40829  CONTQ=93;DP=50;ECNT=2;GERMQ=93;MBQ=37,41;MFRL=...
# 60289  CONTQ=93;DP=61;ECNT=2;GERMQ=93;MBQ=37,41;MFRL=...
# 60290  CONTQ=93;DP=58;ECNT=2;GERMQ=93;MBQ=37,41;MFRL=...
# 66524  CONTQ=93;DP=135;ECNT=1;GERMQ=93;MBQ=37,41;MFRL...
#
#                     Otherinfo12                             Otherinfo13  \
# 22972  GT:AD:AF:DP:F1R2:F2R1:SB       0/1:16,4:0.23:20:6,3:8,1:13,3,0,4
# 22973  GT:AD:AF:DP:F1R2:F2R1:SB       0/1:17,4:0.23:21:8,3:7,1:10,7,0,4
# 40828  GT:AD:AF:DP:F1R2:F2R1:SB      0/1:13,3:0.222:16:7,2:6,1:12,1,0,3
# 40829  GT:AD:AF:DP:F1R2:F2R1:SB      0/1:12,3:0.235:15:7,2:5,1:11,1,0,3
# 60289  GT:AD:AF:DP:F1R2:F2R1:SB      0/1:20,3:0.16:23:10,1:9,2:9,11,0,3
# 60290  GT:AD:AF:DP:F1R2:F2R1:SB     0/1:19,3:0.166:22:11,1:8,2:8,11,0,3
# 66524  GT:AD:AF:DP:F1R2:F2R1:SB  0/1:47,13:0.226:60:25,6:22,7:20,27,5,8
#
#                                  Otherinfo14           sample
# 22972  0/0:37,0:0.026:37:19,0:18,0:22,15,0,0     JFCF-6_T_1_C
# 22973  0/0:35,0:0.027:35:19,0:16,0:23,12,0,0     JFCF-6_T_1_C
# 40828  0/0:37,0:0.026:37:19,0:18,0:22,15,0,0     JFCF-6_T_1_G
# 40829  0/0:35,0:0.027:35:19,0:16,0:23,12,0,0     JFCF-6_T_1_G
# 60289  0/0:37,0:0.026:37:19,0:18,0:22,15,0,0     JFCF-6_T_1_P
# 60290  0/0:35,0:0.027:35:19,0:16,0:23,12,0,0     JFCF-6_T_1_P
# 66524  0/0:71,0:0.014:71:24,0:47,0:26,45,0,0  JFCF-6_T_1_PALT

# %%
df_filtered = df_all[~df_all['Func.refGene'].isin(['intronic','intergenic', 'ncRNA_intronic'])]

# %%
df_filtered.groupby(['sample']).size()
# Out:
# sample
# JFCF-6_T_1J_11C    157208
# JFCF-6_T_1J_11E    156174
# JFCF-6_T_1_C       159015
# JFCF-6_T_1_D       152700
# JFCF-6_T_1_F       154176
# JFCF-6_T_1_G       156104
# JFCF-6_T_1_H       157514
# JFCF-6_T_1_L       150344
# JFCF-6_T_1_P       159923
# JFCF-6_T_1_PALT    158496
# JFCF-6_T_1_R       154949
# JFCF-6_T_2H        156718
# JFCF-6_T_5K        157419
# JFCF-6_p15         162196
# JFCF6_T_1J_1-3C    153227
# JFCF6_T_1J_6B      153658
# JFCF_61M           142889
# JFCF_61Q           147341
# dtype: int64

# %%
df_all[df_all['Gene.refGene']=='ATRX']
# Out:
#        Chr     Start       End Ref Alt Func.refGene Gene.refGene  \
# 6352  chrX  76960038  76960038   C   T     intronic         ATRX
# 5965  chrX  76938581  76938581   C   A       exonic         ATRX
# 6654  chrX  76833467  76833467   G   A     intronic         ATRX
#
#      GeneDetail.refGene ExonicFunc.refGene  \
# 6352                  .                  .
# 5965                  .           stopgain
# 6654                  .                  .
#
#                                        AAChange.refGene  ... Otherinfo6  \
# 6352                                                  .  ...          .
# 5965  ATRX:NM_138270:exon8:c.G2053T:p.E685X,ATRX:NM_...  ...          .
# 6654                                                  .  ...          .
#
#      Otherinfo7 Otherinfo8 Otherinfo9 Otherinfo10  \
# 6352          C          T          .        PASS
# 5965          C          A          .        PASS
# 6654          G          A          .        PASS
#
#                                             Otherinfo11  \
# 6352  CONTQ=93;DP=35;ECNT=1;GERMQ=86;MBQ=37,41;MFRL=...
# 5965  CONTQ=93;DP=26;ECNT=1;GERMQ=28;MBQ=37,41;MFRL=...
# 6654  CONTQ=93;DP=44;ECNT=1;GERMQ=55;MBQ=37,35;MFRL=...
#
#                    Otherinfo12                           Otherinfo13  \
# 6352  GT:AD:AF:DP:F1R2:F2R1:SB    0/1:0,14:0.937:14:0,4:0,10:0,0,5,9
# 5965  GT:AD:AF:DP:F1R2:F2R1:SB      0/1:4,9:0.667:13:1,6:3,3:2,2,6,3
# 6654  GT:AD:AF:DP:F1R2:F2R1:SB  0/1:14,10:0.418:24:10,2:4,7:2,12,4,6
#
#                                Otherinfo14           sample
# 6352  0/0:21,0:0.045:21:8,0:13,0:11,10,0,0     JFCF-6_T_1_L
# 5965     0/0:13,0:0.067:13:7,0:6,0:9,4,0,0  JFCF-6_T_1_PALT
# 6654   0/0:20,0:0.045:20:12,0:8,0:9,11,0,0      JFCF-6_T_5K
#
# [3 rows x 69 columns]

# %%
df_filtered.to_csv(
    "/home/scai/processing_simoncai/tmm/tel_vs_alt/immortal_simon/annovar/annovar_germline_filtered.tsv", sep='\t',
    index=False)

# %% [markdown]
# # combine annovar and SV

# %%
mutect = pd.read_csv(
    "../data/annovar/combined_somatic.tsv",
    sep='\t')
mutect_filtered = mutect[~mutect['Func.refGene'].isin(['intronic','intergenic', 'ncRNA_intronic'])]

mutect_filtered = mutect_filtered.rename(
    columns={
        'sample': 'Name',
        'Gene.refGene': 'Gene',
        'Func.refGene': 'Type',
        'Chr': 'Chr1',
        'Start': 'Pos1',
        'Ref': 'Ref1',
        'Alt': 'Alt1'
    })

mutect_filtered['Source'] = 'MuTect2'
mutect_filtered['Key'] = mutect_filtered.apply(
    lambda row:
    f"MuTect2_{row['Type']}_{row['Gene']}_{row['Chr1']}_{row['Pos1']}_{row['Ref1']}_{row['Alt1']}",
    axis=1)

cols = ['Key', 'Name', 'Source']
cols = cols + [x for x in mutect_filtered.columns if 'Other' not in x and x not in cols]
cols.remove('End')

mutect_filtered = mutect_filtered[cols]

mutect_filtered['Name'] = mutect_filtered['Name'].map(lambda x:map_name(x))

# %%
mutect_filtered.head()
# Out:
#                                            Key             Name   Source  \
# 0       MuTect2_ncRNA_exonic_RNR1_chrM_736_C_T  JFCF_6_T_1J_11C  MuTect2
# 1      MuTect2_ncRNA_exonic_RNR2_chrM_2442_G_A  JFCF_6_T_1J_11C  MuTect2
# 2      MuTect2_ncRNA_exonic_RNR2_chrM_3088_T_C  JFCF_6_T_1J_11C  MuTect2
# 8   MuTect2_downstream_FNDC10_chr1_1532854_G_C  JFCF_6_T_1J_11C  MuTect2
# 11        MuTect2_UTR5_FAAP20_chr1_2131783_G_A  JFCF_6_T_1J_11C  MuTect2
#
#     Chr1     Pos1 Ref1 Alt1          Type    Gene       GeneDetail.refGene  \
# 0   chrM      736    C    T  ncRNA_exonic    RNR1                        .
# 1   chrM     2442    G    A  ncRNA_exonic    RNR2                        .
# 2   chrM     3088    T    C  ncRNA_exonic    RNR2                        .
# 8   chr1  1532854    G    C    downstream  FNDC10                 dist=538
# 11  chr1  2131783    G    A          UTR5  FAAP20  NM_001282670:c.-1356C>T
#
#    ExonicFunc.refGene AAChange.refGene cytoBand ExAC_ALL ExAC_AFR ExAC_AMR  \
# 0                   .                .        .        .        .        .
# 1                   .                .        .        .        .        .
# 2                   .                .        .        .        .        .
# 8                   .                .  1p36.33        .        .        .
# 11                  .                .  1p36.33        .        .        .
#
#    ExAC_EAS ExAC_FIN ExAC_NFE ExAC_OTH ExAC_SAS avsnp147 SIFT_score SIFT_pred  \
# 0         .        .        .        .        .        .          .         .
# 1         .        .        .        .        .        .          .         .
# 2         .        .        .        .        .        .          .         .
# 8         .        .        .        .        .        .          .         .
# 11        .        .        .        .        .        .          .         .
#
#    Polyphen2_HDIV_score Polyphen2_HDIV_pred Polyphen2_HVAR_score  \
# 0                     .                   .                    .
# 1                     .                   .                    .
# 2                     .                   .                    .
# 8                     .                   .                    .
# 11                    .                   .                    .
#
#    Polyphen2_HVAR_pred LRT_score LRT_pred MutationTaster_score  \
# 0                    .         .        .                    .
# 1                    .         .        .                    .
# 2                    .         .        .                    .
# 8                    .         .        .                    .
# 11                   .         .        .                    .
#
#    MutationTaster_pred MutationAssessor_score MutationAssessor_pred  \
# 0                    .                      .                     .
# 1                    .                      .                     .
# 2                    .                      .                     .
# 8                    .                      .                     .
# 11                   .                      .                     .
#
#    FATHMM_score FATHMM_pred PROVEAN_score PROVEAN_pred VEST3_score CADD_raw  \
# 0             .           .             .            .           .        .
# 1             .           .             .            .           .        .
# 2             .           .             .            .           .        .
# 8             .           .             .            .           .        .
# 11            .           .             .            .           .        .
#
#    CADD_phred DANN_score fathmm-MKL_coding_score fathmm-MKL_coding_pred  \
# 0           .          .                       .                      .
# 1           .          .                       .                      .
# 2           .          .                       .                      .
# 8           .          .                       .                      .
# 11          .          .                       .                      .
#
#    MetaSVM_score MetaSVM_pred MetaLR_score MetaLR_pred  \
# 0              .            .            .           .
# 1              .            .            .           .
# 2              .            .            .           .
# 8              .            .            .           .
# 11             .            .            .           .
#
#    integrated_fitCons_score integrated_confidence_value GERP++_RS  \
# 0                         .                           .         .
# 1                         .                           .         .
# 2                         .                           .         .
# 8                         .                           .         .
# 11                        .                           .         .
#
#    phyloP7way_vertebrate phyloP20way_mammalian phastCons7way_vertebrate  \
# 0                      .                     .                        .
# 1                      .                     .                        .
# 2                      .                     .                        .
# 8                      .                     .                        .
# 11                     .                     .                        .
#
#    phastCons20way_mammalian SiPhy_29way_logOdds
# 0                         .                   .
# 1                         .                   .
# 2                         .                   .
# 8                         .                   .
# 11                        .                   .

# %%
sv_df = pd.read_csv("../data/gridss/DATA_GRIDSS.tsv", sep="\t").drop_duplicates()

# %%
sv_df['lower'] = sv_df.apply(lambda row:min(int(row['Pos1'].split('-')[0]),int(row['Pos2'].split('-')[0])),axis=1)
sv_df['upper'] = sv_df.apply(lambda row:max(int(row['Pos1'].split('-')[1]),int(row['Pos2'].split('-')[1])),axis=1)


sv_df_same_chrom = sv_df[sv_df['Chr1']==sv_df['Chr2']]

sv_df_same_chrom = sv_df_same_chrom.reset_index(drop=True)

sv_df_bed = sv_df_same_chrom[['Chr1', 'lower', 'upper', 'Key']]

sv_df_bed['strand'] = '.'
# Out:
# <ipython-input-11-47cb34aa69f5>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sv_df_bed['strand'] = '.'

# %%
sv_df_bed.to_csv("../data/gridss/sv_df.bed", index=False, header=False, sep='\t')

# %%
sv_df_bed_exon = pd.read_csv(
    "../data/gridss/sv_exon_coding_counts.bed",
    sep='\t',
    names=['chr', 'start', 'end', 'Key', 'strand', 'exon_count']).drop_duplicates(['Key'])

# %%
sv_df_same_chrom_exon = pd.merge(sv_df_same_chrom, sv_df_bed_exon,
                                 on=['Key'
                                     ]).drop(['chr', 'start', 'end', 'strand', 'lower','upper'],
                                             axis=1)

sv_df_same_chrom_exon = sv_df_same_chrom_exon[sv_df_same_chrom_exon['exon_count'] > 0].reset_index(drop=True)

sv_df_exon = pd.concat([
    sv_df[sv_df['Chr1'] != sv_df['Chr2']].reset_index(drop=True),
    sv_df_same_chrom_exon.reset_index(drop=True)
],
                       sort=False).drop(['lower','upper'],axis=1)

sv_df_exon = sv_df_exon[sv_df_exon['Consequence']!='feature_fusion']

# %%
sv_df_exon.to_csv("../data/gridss/DATA_GRIDSS_Exon_coding.tsv", sep="\t", index=False)

# %%
combined = pd.concat([sv_df_exon, mutect_filtered], ignore_index=True, sort=False)

# %%
combined.tail()
# Out:
#                                                      Key          Name  \
# 20202           MuTect2_UTR3_SHROOM4_chrX_50336329_CC_TT  JFCF_6_T_1_Q
# 20203            MuTect2_UTR3_AMMECR1_chrX_109441214_T_G  JFCF_6_T_1_Q
# 20204          MuTect2_exonic_SLC25A5_chrX_118603644_G_T  JFCF_6_T_1_Q
# 20205  MuTect2_ncRNA_exonic_LINC00894_chrX_149115253_C_T  JFCF_6_T_1_Q
# 20206         MuTect2_downstream_TTTY11_chrY_8650868_C_A  JFCF_6_T_1_Q
#
#         Source dbSNP          Type  Chr1       Pos1 Chr2 Pos2 Qual1 Qual2  \
# 20202  MuTect2   NaN          UTR3  chrX   50336329  NaN  NaN   NaN   NaN
# 20203  MuTect2   NaN          UTR3  chrX  109441214  NaN  NaN   NaN   NaN
# 20204  MuTect2   NaN        exonic  chrX  118603644  NaN  NaN   NaN   NaN
# 20205  MuTect2   NaN  ncRNA_exonic  chrX  149115253  NaN  NaN   NaN   NaN
# 20206  MuTect2   NaN    downstream  chrY    8650868  NaN  NaN   NaN   NaN
#
#        AF1  AF2 Read1 Read2       Gene Consequence Impact Ref1 Alt1 Ref2 Alt2  \
# 20202  NaN  NaN   NaN   NaN    SHROOM4         NaN    NaN   CC   TT  NaN  NaN
# 20203  NaN  NaN   NaN   NaN    AMMECR1         NaN    NaN    T    G  NaN  NaN
# 20204  NaN  NaN   NaN   NaN    SLC25A5         NaN    NaN    G    T  NaN  NaN
# 20205  NaN  NaN   NaN   NaN  LINC00894         NaN    NaN    C    T  NaN  NaN
# 20206  NaN  NaN   NaN   NaN     TTTY11         NaN    NaN    C    A  NaN  NaN
#
#        exon_count                                 GeneDetail.refGene  \
# 20202         NaN                    NM_020717:c.*3366_*3365delinsAA
# 20203         NaN  NM_001025580:c.*534A>C;NM_001171689:c.*534A>C;...
# 20204         NaN                                                  .
# 20205         NaN                                                  .
# 20206         NaN                                           dist=488
#
#       ExonicFunc.refGene                        AAChange.refGene cytoBand  \
# 20202                  .                                       .  Xp11.22
# 20203                  .                                       .     Xq23
# 20204  nonsynonymous SNV  SLC25A5:NM_001152:exon2:c.G132T:p.Q44H     Xq24
# 20205                  .                                       .     Xq28
# 20206                  .                                       .   Yp11.2
#
#         ExAC_ALL ExAC_AFR ExAC_AMR ExAC_EAS ExAC_FIN   ExAC_NFE ExAC_OTH  \
# 20202          .        .        .        .        .          .        .
# 20203          .        .        .        .        .          .        .
# 20204  8.568e-05   0.0005        0        0        0  4.323e-05        0
# 20205          .        .        .        .        .          .        .
# 20206          .        .        .        .        .          .        .
#
#       ExAC_SAS     avsnp147 SIFT_score SIFT_pred Polyphen2_HDIV_score  \
# 20202        .            .          .         .                    .
# 20203        .            .          .         .                    .
# 20204   0.0002  rs200353173      0.017         D                0.133
# 20205        .  rs369641170          .         .                    .
# 20206        .            .          .         .                    .
#
#       Polyphen2_HDIV_pred Polyphen2_HVAR_score Polyphen2_HVAR_pred LRT_score  \
# 20202                   .                    .                   .         .
# 20203                   .                    .                   .         .
# 20204                   B                0.083                   B     0.000
# 20205                   .                    .                   .         .
# 20206                   .                    .                   .         .
#
#       LRT_pred MutationTaster_score MutationTaster_pred  \
# 20202        .                    .                   .
# 20203        .                    .                   .
# 20204        D                1.000                   D
# 20205        .                    .                   .
# 20206        .                    .                   .
#
#       MutationAssessor_score MutationAssessor_pred FATHMM_score FATHMM_pred  \
# 20202                      .                     .            .           .
# 20203                      .                     .            .           .
# 20204                  2.825                     M        -1.29           T
# 20205                      .                     .            .           .
# 20206                      .                     .            .           .
#
#       PROVEAN_score PROVEAN_pred VEST3_score CADD_raw CADD_phred DANN_score  \
# 20202             .            .           .        .          .          .
# 20203             .            .           .        .          .          .
# 20204         -2.89            D       0.416    2.390      18.76      0.979
# 20205             .            .           .        .          .          .
# 20206             .            .           .        .          .          .
#
#       fathmm-MKL_coding_score fathmm-MKL_coding_pred MetaSVM_score  \
# 20202                       .                      .             .
# 20203                       .                      .             .
# 20204                   0.939                      D        -0.355
# 20205                       .                      .             .
# 20206                       .                      .             .
#
#       MetaSVM_pred MetaLR_score MetaLR_pred integrated_fitCons_score  \
# 20202            .            .           .                        .
# 20203            .            .           .                        .
# 20204            T        0.451           T                        .
# 20205            .            .           .                        .
# 20206            .            .           .                        .
#
#       integrated_confidence_value GERP++_RS phyloP7way_vertebrate  \
# 20202                           .         .                     .
# 20203                           .         .                     .
# 20204                           .     0.646                -0.327
# 20205                           .         .                     .
# 20206                           .         .                     .
#
#       phyloP20way_mammalian phastCons7way_vertebrate phastCons20way_mammalian  \
# 20202                     .                        .                        .
# 20203                     .                        .                        .
# 20204                -0.165                    0.995                    0.977
# 20205                     .                        .                        .
# 20206                     .                        .                        .
#
#       SiPhy_29way_logOdds
# 20202                   .
# 20203                   .
# 20204               7.212
# 20205                   .
# 20206                   .

# %%
combined.shape
# Out:
# (20207, 70)

# %%
combined.to_csv(
    "../data/annovar/annovar_mutect_gridss_coding.tsv",
    sep='\t',
    index=False)

# %% [markdown]
# ## split ; and &

# %%
combined_with_semi_colon = combined[combined['Gene'].str.contains(";")]

# %%
combined_with_amp = combined[combined['Gene'].str.contains("&")]

# %%
combined_with_semi_colon_split = split_gene(combined_with_semi_colon, ';')
# Out:
# <ipython-input-7-b95d0c1d8b31>:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for index, row in tqdm_notebook(df.iterrows()):
# HBox(children=(FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0), HTML(value=''…

# %%
combined_with_amp_split = split_gene(combined_with_amp, '&')
# Out:
# <ipython-input-7-b95d0c1d8b31>:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for index, row in tqdm_notebook(df.iterrows()):
# HBox(children=(FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0), HTML(value=''…

# %%
combined_with_amp_split.shape
# Out:
# (7586, 70)

# %%
combined_split = pd.concat([
    combined[~((combined['Gene'].str.contains(";")) |
               (combined['Gene'].str.contains("&")))],
    combined_with_semi_colon_split, combined_with_amp_split
])

# %%
combined_split.shape
# Out:
# (24274, 70)

# %%
combined.shape
# Out:
# (20207, 70)

# %%
combined_split.to_csv(
    "../data/annovar/annovar_mutect_gridss_coding_split.tsv", sep='\t',
    index=False)

# %%
combined['Name'].unique()
# Out:
# array(['JFCF_6', 'JFCF_6_T_1_M', 'JFCF_6_T_1_Q', 'JFCF_6_T_1_C',
#        'JFCF_6_T_1_D', 'JFCF_6_T_1_F', 'JFCF_6_T_1_G', 'JFCF_6_T_1_H',
#        'JFCF_6_T_1J_11C', 'JFCF_6_T_1J_11E', 'JFCF_6_T_1J_1_3C',
#        'JFCF_6_T_1J_6B', 'JFCF_6_T_1_L', 'JFCF_6_T_1_P_ALT',
#        'JFCF_6_T_1_P_TEL', 'JFCF_6_T_1_R', 'JFCF_6_T_2H', 'JFCF_6_T_5K'],
#       dtype=object)

# %%
sv_somatic = sv_df[(sv_df['Key'].str.contains('Somatic'))]

# %%
sv_somatic[sv_somatic['Gene']=='ATRX']
# Out:
#                                                        Key              Name  \
# 119200   SV_GRIDSS_HIGH_ATRX_Somatic_chrX_76885052_7688...      JFCF_6_T_1_M
# 193720   SV_GRIDSS_HIGH_ATRX_Somatic_chrX_76808603_7680...      JFCF_6_T_1_Q
# 354334   SV_GRIDSS_HIGH_ATRX_Somatic_chrX_76862268_7686...      JFCF_6_T_1_D
# 748718   SV_GRIDSS_HIGH_ATRX_Somatic_chrX_76853017_7685...   JFCF_6_T_1J_11E
# 821329   SV_GRIDSS_HIGH_ATRX_Somatic_chrX_76853017_7685...  JFCF_6_T_1J_1_3C
# 967784   SV_GRIDSS_HIGH_ATRX_Somatic_chrX_76795540_7679...      JFCF_6_T_1_L
# 1200011  SV_GRIDSS_HIGH_ATRX_Somatic_chrX_76788737_7678...      JFCF_6_T_1_R
# 1352382  SV_GRIDSS_HIGH_ATRX_Somatic_chrX_76783771_7678...       JFCF_6_T_5K
# 1352384  SV_GRIDSS_HIGH_ATRX_Somatic_chrX_76798390_7679...       JFCF_6_T_5K
#
#          Source  dbSNP         Type  Chr1               Pos1  Chr2  \
# 119200   GRIDSS  False  Duplication  chrX  76885052-76885055  chrX
# 193720   GRIDSS  False     Deletion  chrX  76808603-76808606  chrX
# 354334   GRIDSS  False     Deletion  chrX  76862268-76862269  chrX
# 748718   GRIDSS  False     Deletion  chrX  76853017-76853018  chrX
# 821329   GRIDSS  False     Deletion  chrX  76853017-76853018  chrX
# 967784   GRIDSS  False     Deletion  chrX  76795540-76795542  chrX
# 1200011  GRIDSS  False     Deletion  chrX  76788737-76788738  chrX
# 1352382  GRIDSS  False  Duplication  chrX  76783771-76783774  chrX
# 1352384  GRIDSS  False     Deletion  chrX  76798390-76798391  chrX
#
#                       Pos2                         Qual1  \
# 119200   76923999-76924002  NotSplit:204.12;Split:318.66
# 193720   76875533-76875536   NotSplit:141.33;Split:96.28
# 354334   77034579-77034580       NotSplit:249.27;Split:0
# 748718   77014863-77014864  NotSplit:239.33;Split:302.85
# 821329   77014863-77014864  NotSplit:343.72;Split:285.82
# 967784   76940486-76940488  NotSplit:237.43;Split:194.13
# 1200011  76876903-76876904       NotSplit:186.78;Split:0
# 1352382  76840055-76840058  NotSplit:256.58;Split:114.96
# 1352384  76799297-76799298   NotSplit:256.58;Split:30.98
#
#                                 Qual2  AF1  AF2                 Read1  \
# 119200   NotSplit:204.12;Split:318.66  NaN  NaN  NotSplit:11;Split:12
# 193720    NotSplit:141.33;Split:96.28  NaN  NaN    NotSplit:8;Split:4
# 354334        NotSplit:249.27;Split:0  NaN  NaN   NotSplit:14;Split:0
# 748718   NotSplit:239.33;Split:302.85  NaN  NaN  NotSplit:13;Split:12
# 821329   NotSplit:343.72;Split:285.82  NaN  NaN  NotSplit:19;Split:11
# 967784   NotSplit:237.43;Split:194.13  NaN  NaN   NotSplit:13;Split:7
# 1200011       NotSplit:186.78;Split:0  NaN  NaN   NotSplit:10;Split:0
# 1352382  NotSplit:256.58;Split:114.96  NaN  NaN   NotSplit:14;Split:4
# 1352384   NotSplit:256.58;Split:30.98  NaN  NaN   NotSplit:14;Split:1
#
#                         Read2  Gene                     Consequence Impact  \
# 119200   NotSplit:11;Split:12  ATRX  gene_fusion&frameshift_variant   HIGH
# 193720     NotSplit:8;Split:4  ATRX  gene_fusion&frameshift_variant   HIGH
# 354334    NotSplit:14;Split:0  ATRX  gene_fusion&frameshift_variant   HIGH
# 748718   NotSplit:13;Split:12  ATRX  gene_fusion&frameshift_variant   HIGH
# 821329   NotSplit:19;Split:11  ATRX  gene_fusion&frameshift_variant   HIGH
# 967784    NotSplit:13;Split:7  ATRX                     gene_fusion   HIGH
# 1200011   NotSplit:10;Split:0  ATRX  gene_fusion&frameshift_variant   HIGH
# 1352382   NotSplit:14;Split:4  ATRX  gene_fusion&frameshift_variant   HIGH
# 1352384   NotSplit:14;Split:1  ATRX                     gene_fusion   HIGH
#
#         Ref1                           Alt1 Ref2  \
# 119200     G               ]CHRX:76924001]G    A
# 193720     C               C[CHRX:76875535[    C
# 354334     A           AGGTA[CHRX:77034580[    T
# 748718     A               A[CHRX:77014864[    A
# 821329     A               A[CHRX:77014864[    A
# 967784     T               T[CHRX:76940487[    C
# 1200011    G  GTAGCTGGGATTAC[CHRX:76876904[    A
# 1352382    T               ]CHRX:76840057]T    C
# 1352384    T               T[CHRX:76799298[    G
#
#                                   Alt2     lower     upper
# 119200                A[CHRX:76885054[  76885052  76924002
# 193720                ]CHRX:76808605]C  76808603  76875536
# 354334            ]CHRX:76862269]GGTAT  76862268  77034580
# 748718                ]CHRX:76853018]A  76853017  77014864
# 821329                ]CHRX:76853018]A  76853017  77014864
# 967784                ]CHRX:76795541]C  76795540  76940488
# 1200011  ]CHRX:76788738]TAGCTGGGATTACA  76788737  76876904
# 1352382               C[CHRX:76783773[  76783771  76840058
# 1352384               ]CHRX:76798391]G  76798390  76799298

# %% [markdown]
# # combine annovar (no filter and SV)

# %%
mutect = pd.read_csv(
    "/home/scai/processing_simoncai/tmm/tel_vs_alt/immortal_simon/annovar/combined_somatic.tsv",
    sep='\t')

mutect = mutect.rename(
    columns={
        'sample': 'Name',
        'Gene.refGene': 'Gene',
        'Func.refGene': 'Type',
        'Chr': 'Chr1',
        'Start': 'Pos1',
        'Ref': 'Ref1',
        'Alt': 'Alt1'
    })

mutect['Source'] = 'MuTect2'
mutect['Key'] = mutect.apply(
    lambda row:
    f"MuTect2_{row['Type']}_{row['Gene']}_{row['Name']}_{row['Chr1']}_{row['Pos1']}_{row['Ref1']}_{row['Alt1']}",
    axis=1)

cols = ['Key', 'Name', 'Source']
cols = cols + [x for x in mutect.columns if 'Other' not in x and x not in cols]
cols.remove('End')

mutect = mutect[cols]

mutect['Name'] = mutect['Name'].map(lambda x:map_name(x))

# %%
df = pd.read_csv("../data/annovar/annovar_mutect_gridss_coding_split.tsv",sep='\t', low_memory=False)

# %%
df['Type'].unique()
# Out:
# array(['Translocations', 'Deletion', 'Duplication', 'Inversion',
#        'Insertion', 'ncRNA_exonic', 'downstream', 'UTR5', 'upstream',
#        'exonic', 'UTR3', 'splicing', 'ncRNA_splicing',
#        'upstream;downstream'], dtype=object)

# %%
mutect_with_combined_genes = mutect[mutect['Gene'].str.contains(';')].reset_index(drop=True)

# %%
mutect_split = split_gene(mutect_with_combined_genes, ';')
