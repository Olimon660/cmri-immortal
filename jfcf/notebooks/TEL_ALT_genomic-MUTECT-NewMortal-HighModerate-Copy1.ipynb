# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display
pd.options.display.max_columns = None
# %matplotlib inline

from venn import venn
from scipy.stats import fisher_exact

# %%
mutect_df = pd.read_csv("../immortal_simon/mutect/DATA_MUTECT.tsv", sep="\t")
sv_df = pd.read_csv("../immortal_simon/gridss/DATA_GRIDSS.tsv", sep="\t").drop_duplicates()
type_list = {'MUTECT':mutect_df, 'SV':sv_df}

# %%
mutect_df.head()
# Out:
#                                         Key             Name   Source  dbSNP  \
# 0  SNP_MuTect2_MODIFIER_MT-ND1_chrM_736_C_T  JFCF_6_T_1J_11C  MuTect2  False
# 1  SNP_MuTect2_MODIFIER_MT-ND2_chrM_736_C_T  JFCF_6_T_1J_11C  MuTect2  False
# 2  SNP_MuTect2_MODIFIER_MT-TL1_chrM_736_C_T  JFCF_6_T_1J_11C  MuTect2  False
# 3   SNP_MuTect2_MODIFIER_MT-TF_chrM_736_C_T  JFCF_6_T_1J_11C  MuTect2  False
# 4   SNP_MuTect2_MODIFIER_MT-TV_chrM_736_C_T  JFCF_6_T_1J_11C  MuTect2  False
#
#   Type  Chr1  Pos1  Chr2  Pos2         Qual1  Qual2   AF1       AF2  \
# 0  SNP  chrM   736   NaN   NaN  1037.28:3.54    NaN  0.01  0.000286
# 1  SNP  chrM   736   NaN   NaN  1037.28:3.54    NaN  0.01  0.000286
# 2  SNP  chrM   736   NaN   NaN  1037.28:3.54    NaN  0.01  0.000286
# 3  SNP  chrM   736   NaN   NaN  1037.28:3.54    NaN  0.01  0.000286
# 4  SNP  chrM   736   NaN   NaN  1037.28:3.54    NaN  0.01  0.000286
#
#         Read1      Read2    Gene              Consequence    Impact Ref1 Alt1  \
# 0  [3898, 40]  [3465, 0]  MT-ND1    upstream_gene_variant  MODIFIER    C    T
# 1  [3898, 40]  [3465, 0]  MT-ND2    upstream_gene_variant  MODIFIER    C    T
# 2  [3898, 40]  [3465, 0]  MT-TL1    upstream_gene_variant  MODIFIER    C    T
# 3  [3898, 40]  [3465, 0]   MT-TF  downstream_gene_variant  MODIFIER    C    T
# 4  [3898, 40]  [3465, 0]   MT-TV    upstream_gene_variant  MODIFIER    C    T
#
#    Ref2  Alt2
# 0   NaN   NaN
# 1   NaN   NaN
# 2   NaN   NaN
# 3   NaN   NaN
# 4   NaN   NaN

# %%
mutect_df[(mutect_df["Gene"]=="TP53TG3D")&(mutect_df["Impact"]=="MODERATE")]
# Out:
#                                                     Key              Name  \
# 37060  SNP_MuTect2_MODERATE_TP53TG3D_chr16_32265727_T_C      JFCF_6_T_1_C
# 37063  SNP_MuTect2_MODERATE_TP53TG3D_chr16_32265727_T_C      JFCF_6_T_1_C
# 37069  SNP_MuTect2_MODERATE_TP53TG3D_chr16_32265744_T_C      JFCF_6_T_1_C
# 37072  SNP_MuTect2_MODERATE_TP53TG3D_chr16_32265744_T_C      JFCF_6_T_1_C
# 66110  SNP_MuTect2_MODERATE_TP53TG3D_chr16_32265727_T_C      JFCF_6_T_1_G
# 66113  SNP_MuTect2_MODERATE_TP53TG3D_chr16_32265727_T_C      JFCF_6_T_1_G
# 66119  SNP_MuTect2_MODERATE_TP53TG3D_chr16_32265744_T_C      JFCF_6_T_1_G
# 66122  SNP_MuTect2_MODERATE_TP53TG3D_chr16_32265744_T_C      JFCF_6_T_1_G
# 97594  SNP_MuTect2_MODERATE_TP53TG3D_chr16_32265727_T_C  JFCF_6_T_1_P_TEL
# 97597  SNP_MuTect2_MODERATE_TP53TG3D_chr16_32265727_T_C  JFCF_6_T_1_P_TEL
# 97603  SNP_MuTect2_MODERATE_TP53TG3D_chr16_32265744_T_C  JFCF_6_T_1_P_TEL
# 97606  SNP_MuTect2_MODERATE_TP53TG3D_chr16_32265744_T_C  JFCF_6_T_1_P_TEL
#
#         Source  dbSNP Type   Chr1      Pos1  Chr2  Pos2       Qual1  Qual2  \
# 37060  MuTect2  False  SNP  chr16  32265727   NaN   NaN  11.13:1.58    NaN
# 37063  MuTect2  False  SNP  chr16  32265727   NaN   NaN  11.13:1.58    NaN
# 37069  MuTect2  False  SNP  chr16  32265744   NaN   NaN  10.53:1.56    NaN
# 37072  MuTect2  False  SNP  chr16  32265744   NaN   NaN  10.53:1.56    NaN
# 66110  MuTect2  False  SNP  chr16  32265727   NaN   NaN  11.13:1.58    NaN
# 66113  MuTect2  False  SNP  chr16  32265727   NaN   NaN  11.13:1.58    NaN
# 66119  MuTect2  False  SNP  chr16  32265744   NaN   NaN  10.53:1.56    NaN
# 66122  MuTect2  False  SNP  chr16  32265744   NaN   NaN  10.53:1.56    NaN
# 97594  MuTect2  False  SNP  chr16  32265727   NaN   NaN  11.13:1.58    NaN
# 97597  MuTect2  False  SNP  chr16  32265727   NaN   NaN  11.13:1.58    NaN
# 97603  MuTect2  False  SNP  chr16  32265744   NaN   NaN  10.53:1.56    NaN
# 97606  MuTect2  False  SNP  chr16  32265744   NaN   NaN  10.53:1.56    NaN
#
#          AF1    AF2    Read1    Read2      Gene  \
# 37060  0.230  0.026  [16, 4]  [37, 0]  TP53TG3D
# 37063  0.230  0.026  [16, 4]  [37, 0]  TP53TG3D
# 37069  0.230  0.027  [17, 4]  [35, 0]  TP53TG3D
# 37072  0.230  0.027  [17, 4]  [35, 0]  TP53TG3D
# 66110  0.222  0.026  [13, 3]  [37, 0]  TP53TG3D
# 66113  0.222  0.026  [13, 3]  [37, 0]  TP53TG3D
# 66119  0.235  0.027  [12, 3]  [35, 0]  TP53TG3D
# 66122  0.235  0.027  [12, 3]  [35, 0]  TP53TG3D
# 97594  0.160  0.026  [20, 3]  [37, 0]  TP53TG3D
# 97597  0.160  0.026  [20, 3]  [37, 0]  TP53TG3D
# 97603  0.166  0.027  [19, 3]  [35, 0]  TP53TG3D
# 97606  0.166  0.027  [19, 3]  [35, 0]  TP53TG3D
#
#                                    Consequence    Impact Ref1 Alt1  Ref2  Alt2
# 37060  missense_variant&NMD_transcript_variant  MODERATE    T    C   NaN   NaN
# 37063                         missense_variant  MODERATE    T    C   NaN   NaN
# 37069  missense_variant&NMD_transcript_variant  MODERATE    T    C   NaN   NaN
# 37072                         missense_variant  MODERATE    T    C   NaN   NaN
# 66110  missense_variant&NMD_transcript_variant  MODERATE    T    C   NaN   NaN
# 66113                         missense_variant  MODERATE    T    C   NaN   NaN
# 66119  missense_variant&NMD_transcript_variant  MODERATE    T    C   NaN   NaN
# 66122                         missense_variant  MODERATE    T    C   NaN   NaN
# 97594  missense_variant&NMD_transcript_variant  MODERATE    T    C   NaN   NaN
# 97597                         missense_variant  MODERATE    T    C   NaN   NaN
# 97603  missense_variant&NMD_transcript_variant  MODERATE    T    C   NaN   NaN
# 97606                         missense_variant  MODERATE    T    C   NaN   NaN

# %%
mutect_df[(mutect_df["Source"]=="MuTect2")&(mutect_df["Gene"].str.contains("INC"))&(mutect_df["Impact"]!="MODIFIER")]
# Out:
#                                                   Key             Name  \
# 26893    SNP_MuTect2_LOW_LINC00665_chr19_36806854_C_T  JFCF_6_T_1J_11E
# 132856  IND_MuTect2_LOW_LINC00116_chr2_110980520_CA_C      JFCF_6_T_5K
#
#          Source  dbSNP Type   Chr1       Pos1  Chr2  Pos2       Qual1  Qual2  \
# 26893   MuTect2  False  SNP  chr19   36806854   NaN   NaN  10.53:1.56    NaN
# 132856  MuTect2   True  IND   chr2  110980520   NaN   NaN   7.42:0.99    NaN
#
#           AF1    AF2    Read1    Read2       Gene  \
# 26893   0.148  0.027  [22, 3]  [35, 0]  LINC00665
# 132856  0.711  0.035  [4, 11]  [25, 0]  LINC00116
#
#                                               Consequence Impact Ref1 Alt1  \
# 26893   splice_region_variant&intron_variant&non_codin...    LOW    C    T
# 132856  splice_region_variant&intron_variant&non_codin...    LOW   CA    C
#
#         Ref2  Alt2
# 26893    NaN   NaN
# 132856   NaN   NaN

# %%
mutect_df[(mutect_df["Key"].str.contains("LINC"))]["Impact"].unique()
# Out:
# array(['MODIFIER', 'LOW'], dtype=object)

# %%
sv_df[(sv_df["Key"].str.contains("LINC"))]["Impact"].unique()
# Out:
# array(['HIGH'], dtype=object)

# %%
samples = pd.read_csv("../data/samples/SAMPLES_Excel.tsv", sep="\t")
samples['label'] = samples.apply(lambda x: "T" if x['TMM'] == 'TEL' else "M"
                                 if (x['WestATRX'] == "Neg" or x['WestDAXX'] == "Neg") else "AP",
                                 axis=1)

# %%
samples = samples[samples['Mortal'].str.contains('JFCF')]

# %%
gene_list = ['ATRX', 'DAXX', 'TP53']
sample_list = np.concatenate(
    (samples['Immortal'].unique(), samples['Mortal'].unique()))
type_list = {'Somatic': mutect_df, 'SV': sv_df}
sv_df = sv_df[sv_df['Key'].str.contains('_Somatic')]

# %%
mapping = dict(zip(samples['Immortal'].values, samples['label'].values))
combined_df_all = pd.concat([mutect_df, sv_df])

# %%
df = combined_df_all[
    (combined_df_all['Impact'].isin(['HIGH', 'MODERATE']))
    & (combined_df_all['Name'] != 'JFCF_6_P_pLKO_5') &
    (combined_df_all['Name'].str.contains('JFCF'))].sort_values(
        by=['Key', 'Name'])

df = df.drop_duplicates(
    subset=df.columns.values[df.columns.values != 'Consequence'])
df = df.drop_duplicates(subset=['Key', 'Name'])

# %%
df_TEL = df[df['Name'].isin(samples[samples['TMM']=='TEL']['Immortal'])]
df_ALT = df[df['Name'].isin(samples[samples['TMM']=='ALT']['Immortal'])]
df_Mortal = df[df['Name'].isin(samples['Mortal'])]

# %% [markdown]
# # ALT vs TEL mutations

# %%
mutations = {
    'TEL': set(df_TEL['Key']),
    'ALT': set(df_ALT['Key'])
}

# %%
venn(mutations)
plt.title("TEL/ALT/Mortal Distinct Mutations")
# Out:
# Text(0.5, 1.0, 'TEL/ALT/Mortal Distinct Mutations')

# %%
res = pd.DataFrame({'Key':df['Key'].unique()})
for key, value in mutations.items():
    res[key] = res['Key'].map(lambda x:True if x in value else False)
key_gene = df.groupby(['Key','Gene','Consequence']).size().reset_index().drop([0], axis=1)

key_gene = key_gene.drop_duplicates("Key", keep='first')

res = pd.merge(res, key_gene, on=['Key'])

res = res.sort_values(by=['Gene','Key'])

# %%
res.to_csv("../results/mutations_TEL_ALT_somatic_new_highmoderate.tsv", index=False, sep="\t")

# %%
mutations_genes = {
    'TEL': set(df_TEL['Gene']),
    'ALT': set(df_ALT['Gene'])
}

# %%
venn(mutations_genes)
plt.title("TEL/ALT/Mortal Mutated Genes")
# Out:
# Text(0.5, 1.0, 'TEL/ALT/Mortal Mutated Genes')

# %%
tel_only = set(df_TEL['Key']) - set(df_ALT['Key']) - set(df_Mortal['Key'])
alt_only = set(df_ALT['Key']) - set(df_TEL['Key']) - set(df_Mortal['Key'])
mortal_only = set(df_Mortal['Key']) - set(df_ALT['Key']) - set(df_TEL['Key'])

# %%
alt_mutations = df[df['Key'].isin(alt_only)][['Gene', 'Name', 'Impact']].drop_duplicates().groupby(
    ['Gene']).size().sort_values(ascending=False).reset_index()

# %%
tel_mutations = df[df['Key'].isin(tel_only)][['Gene', 'Name', 'Impact']].drop_duplicates().groupby(
    ['Gene']).size().sort_values(ascending=False).reset_index()

# %%
alt_mutations.columns = ['Gene', 'count']
alt_mutations.to_csv("../results/alt_only_mutations_JFCF_only_somatic_new_highmoderate.tsv", index=False, sep='\t')

# %%
tel_mutations.columns = ['Gene', 'count']

tel_mutations.to_csv("../results/tel_only_mutations_JFCF_only_somatic_new_highmoderate.tsv", index=False, sep='\t')

# %% [markdown]
# Check TERT. It seems both ALT and TEL have TERT mutations.

# %%
samples[samples['Immortal'].isin(df[df['Gene']=='TERT']['Name'].unique())]
# Out:
# Empty DataFrame
# Columns: [Mortal, Immortal, TMM, WestATRX, WestDAXX, SWATH, label]
# Index: []

# %%
df['Pos1'] = df['Pos1'].astype(str)

# %%
df[df['Gene']=='CBWD1'].sort_values(by=['Name'])
# Out:
# Empty DataFrame
# Columns: [Key, Name, Source, dbSNP, Type, Chr1, Pos1, Chr2, Pos2, Qual1, Qual2, AF1, AF2, Read1, Read2, Gene, Consequence, Impact, Ref1, Alt1, Ref2, Alt2]
# Index: []

# %%
df.to_csv("../results/all_JFCF_mutations_details_no_plko_somatic_new_highmoderate.tsv", index=False, sep="\t")

# %%
df.head()
# Out:
#                                                      Key              Name  \
# 42121        IND_MuTect2_HIGH_AFF1_chr4_88048827_AAA_TGT      JFCF_6_T_1_D
# 93586       IND_MuTect2_HIGH_AKAP12_chr6_151673338_CTG_C  JFCF_6_T_1_P_TEL
# 73379      IND_MuTect2_HIGH_ARHGAP39_chr8_145770781_CT_C      JFCF_6_T_1_H
# 73382  IND_MuTect2_HIGH_ARHGAP39_chr8_145770786_GGCAC...      JFCF_6_T_1_H
# 52975  IND_MuTect2_HIGH_CMTR1_chr6_37442303_T_TGATACG...      JFCF_6_T_1_F
#
#         Source  dbSNP Type  Chr1       Pos1 Chr2 Pos2       Qual1 Qual2  \
# 42121  MuTect2  False  IND  chr4   88048827  NaN  NaN   7.83:1.44   NaN
# 93586  MuTect2  False  IND  chr6  151673338  NaN  NaN   7.22:1.41   NaN
# 73379  MuTect2  False  IND  chr8  145770781  NaN  NaN   7.53:1.41   NaN
# 73382  MuTect2  False  IND  chr8  145770786  NaN  NaN   8.13:1.45   NaN
# 52975  MuTect2  False  IND  chr6   37442303  NaN  NaN  12.64:1.63   NaN
#
#          AF1    AF2     Read1    Read2      Gene  \
# 42121  0.714  0.035   [5, 14]  [26, 0]      AFF1
# 93586  0.541  0.038  [16, 19]  [24, 0]    AKAP12
# 73379  0.367  0.037   [11, 6]  [25, 0]  ARHGAP39
# 73382  0.314  0.034   [12, 5]  [27, 0]  ARHGAP39
# 52975  0.154  0.023   [21, 3]  [42, 0]     CMTR1
#
#                           Consequence Impact      Ref1            Alt1 Ref2  \
# 42121                     stop_gained   HIGH       AAA             TGT  NaN
# 93586              frameshift_variant   HIGH       CTG               C  NaN
# 73379              frameshift_variant   HIGH        CT               C  NaN
# 73382              frameshift_variant   HIGH  GGCACAGC               G  NaN
# 52975  stop_gained&frameshift_variant   HIGH         T  TGATACGGCGACCA  NaN
#
#       Alt2
# 42121  NaN
# 93586  NaN
# 73379  NaN
# 73382  NaN
# 52975  NaN

# %% [markdown]
# # All ALT & All TEL

# %%
df_ALT_genes = set(df_ALT['Gene']) - set(df_Mortal['Gene'])
df_TEL_genes = set(df_TEL['Gene']) - set(df_Mortal['Gene'])

# %%
df_ALT_no_mortal = df_ALT[df_ALT['Gene'].isin(df_ALT_genes)]
df_TEL_no_mortal = df_TEL[df_TEL['Gene'].isin(df_TEL_genes)]

# %%
df_ALT_no_mortal[['Name', 'Gene']].drop_duplicates().groupby(
    ['Gene']).size().sort_values(ascending=False).head(20)
# Out:
# Gene
# ATRX         9
# MYO18A       7
# CTNS         6
# NTRK2        6
# IGF1R        5
# CDH1         5
# EVI5         4
# APOB         4
# SERPINA12    4
# SBSN         4
# ZNF827       4
# PSMB7        3
# IGLL5        3
# SUGCT        3
# PARK2        3
# NBPF12       3
# MUC4         3
# U1.8         3
# FXN          2
# DGKK         2
# dtype: int64

# %%
df_TEL_no_mortal[['Name', 'Gene']].drop_duplicates().groupby(
    ['Gene']).size().sort_values(ascending=False).head(20)
# Out:
# Gene
# ZNF827       6
# SUGCT        5
# CTNS         5
# SERPINA12    5
# IGF1R        5
# MYO18A       5
# NTRK2        4
# APOB         4
# EVI5         4
# SBSN         4
# CDH1         4
# MUC4         4
# CEP170       3
# SLC25A5      3
# CSMD3        3
# AUTS2        3
# MYO9B        3
# NAALADL2     3
# TP53TG3D     3
# NBPF10       3
# dtype: int64

# %%
df_TEL[df_TEL['Gene']=='ZNF827']
# Out:
#                                                        Key              Name  \
# 614470   SV_GRIDSS_HIGH_ZNF827_Somatic_chr4_146807211_1...   JFCF_6_T_1J_11C
# 217314   SV_GRIDSS_HIGH_ZNF827_Somatic_chr4_146807211_1...      JFCF_6_T_1_C
# 377622   SV_GRIDSS_HIGH_ZNF827_Somatic_chr4_146807211_1...      JFCF_6_T_1_F
# 454346   SV_GRIDSS_HIGH_ZNF827_Somatic_chr4_146807211_1...      JFCF_6_T_1_G
# 532205   SV_GRIDSS_HIGH_ZNF827_Somatic_chr4_146807211_1...      JFCF_6_T_1_H
# 1067852  SV_GRIDSS_HIGH_ZNF827_Somatic_chr4_146807211_1...  JFCF_6_T_1_P_TEL
# 614472   SV_GRIDSS_HIGH_ZNF827_Somatic_chr4_146824366_1...   JFCF_6_T_1J_11C
# 217316   SV_GRIDSS_HIGH_ZNF827_Somatic_chr4_146824366_1...      JFCF_6_T_1_C
# 377624   SV_GRIDSS_HIGH_ZNF827_Somatic_chr4_146824366_1...      JFCF_6_T_1_F
# 454348   SV_GRIDSS_HIGH_ZNF827_Somatic_chr4_146824366_1...      JFCF_6_T_1_G
# 532207   SV_GRIDSS_HIGH_ZNF827_Somatic_chr4_146824366_1...      JFCF_6_T_1_H
# 1067854  SV_GRIDSS_HIGH_ZNF827_Somatic_chr4_146824366_1...  JFCF_6_T_1_P_TEL
#
#          Source  dbSNP      Type  Chr1                 Pos1  Chr2  \
# 614470   GRIDSS  False  Deletion  chr4  146807211-146807212  chr4
# 217314   GRIDSS  False  Deletion  chr4  146807211-146807212  chr4
# 377622   GRIDSS  False  Deletion  chr4  146807211-146807212  chr4
# 454346   GRIDSS  False  Deletion  chr4  146807211-146807212  chr4
# 532205   GRIDSS  False  Deletion  chr4  146807211-146807212  chr4
# 1067852  GRIDSS  False  Deletion  chr4  146807211-146807212  chr4
# 614472   GRIDSS  False  Deletion  chr4  146824366-146824367  chr4
# 217316   GRIDSS  False  Deletion  chr4  146824366-146824367  chr4
# 377624   GRIDSS  False  Deletion  chr4  146824366-146824367  chr4
# 454348   GRIDSS  False  Deletion  chr4  146824366-146824367  chr4
# 532207   GRIDSS  False  Deletion  chr4  146824366-146824367  chr4
# 1067854  GRIDSS  False  Deletion  chr4  146824366-146824367  chr4
#
#                         Pos2                         Qual1  \
# 614470   146823317-146823318    NotSplit:199.65;Split:28.3
# 217314   146823317-146823318  NotSplit:479.78;Split:319.62
# 377622   146823317-146823318  NotSplit:403.27;Split:196.97
# 454346   146823317-146823318  NotSplit:313.83;Split:335.65
# 532205   146823317-146823318  NotSplit:163.83;Split:171.71
# 1067852  146823317-146823318  NotSplit:165.15;Split:230.39
# 614472   146859516-146859517    NotSplit:36.3;Split:290.68
# 217316   146859516-146859517   NotSplit:92.26;Split:332.77
# 377624   146859516-146859517   NotSplit:54.99;Split:650.74
# 454348   146859516-146859517   NotSplit:55.38;Split:202.04
# 532207   146859516-146859517   NotSplit:36.41;Split:114.92
# 1067854  146859516-146859517   NotSplit:55.05;Split:341.58
#
#                                 Qual2  AF1  AF2                 Read1  \
# 614470     NotSplit:199.65;Split:28.3  NaN  NaN   NotSplit:11;Split:1
# 217314   NotSplit:479.78;Split:319.62  NaN  NaN  NotSplit:26;Split:11
# 377622   NotSplit:403.27;Split:196.97  NaN  NaN   NotSplit:22;Split:7
# 454346   NotSplit:313.83;Split:335.65  NaN  NaN  NotSplit:17;Split:11
# 532205   NotSplit:163.83;Split:171.71  NaN  NaN    NotSplit:9;Split:6
# 1067852  NotSplit:165.15;Split:230.39  NaN  NaN    NotSplit:9;Split:8
# 614472     NotSplit:36.3;Split:290.68  NaN  NaN   NotSplit:2;Split:11
# 217316    NotSplit:92.26;Split:332.77  NaN  NaN   NotSplit:5;Split:12
# 377624    NotSplit:54.99;Split:650.74  NaN  NaN   NotSplit:3;Split:24
# 454348    NotSplit:55.38;Split:202.04  NaN  NaN    NotSplit:3;Split:7
# 532207    NotSplit:36.41;Split:114.92  NaN  NaN    NotSplit:2;Split:4
# 1067854   NotSplit:55.05;Split:341.58  NaN  NaN   NotSplit:3;Split:12
#
#                         Read2    Gene                     Consequence Impact  \
# 614470    NotSplit:11;Split:1  ZNF827  gene_fusion&frameshift_variant   HIGH
# 217314   NotSplit:26;Split:11  ZNF827  gene_fusion&frameshift_variant   HIGH
# 377622    NotSplit:22;Split:7  ZNF827  gene_fusion&frameshift_variant   HIGH
# 454346   NotSplit:17;Split:11  ZNF827  gene_fusion&frameshift_variant   HIGH
# 532205     NotSplit:9;Split:6  ZNF827  gene_fusion&frameshift_variant   HIGH
# 1067852    NotSplit:9;Split:8  ZNF827  gene_fusion&frameshift_variant   HIGH
# 614472    NotSplit:2;Split:11  ZNF827                     gene_fusion   HIGH
# 217316    NotSplit:5;Split:12  ZNF827                     gene_fusion   HIGH
# 377624    NotSplit:3;Split:24  ZNF827                     gene_fusion   HIGH
# 454348     NotSplit:3;Split:7  ZNF827                     gene_fusion   HIGH
# 532207     NotSplit:2;Split:4  ZNF827                     gene_fusion   HIGH
# 1067854   NotSplit:3;Split:12  ZNF827                     gene_fusion   HIGH
#
#         Ref1                                        Alt1 Ref2  \
# 614470     A  AGGCTTTCCACTTTCCTCTTCTGAGG[CHR4:146823318[    C
# 217314     A  AGGCTTTCCACTTTCCTCTTCTGAGG[CHR4:146823318[    C
# 377622     A  AGGCTTTCCACTTTCCTCTTCTGAGG[CHR4:146823318[    C
# 454346     A  AGGCTTTCCACTTTCCTCTTCTGAGG[CHR4:146823318[    C
# 532205     A  AGGCTTTCCACTTTCCTCTTCTGAGG[CHR4:146823318[    C
# 1067852    A  AGGCTTTCCACTTTCCTCTTCTGAGG[CHR4:146823318[    C
# 614472     T                           T[CHR4:146859517[    G
# 217316     T                           T[CHR4:146859517[    G
# 377624     T                           T[CHR4:146859517[    G
# 454348     T                           T[CHR4:146859517[    G
# 532207     T                           T[CHR4:146859517[    G
# 1067854    T                           T[CHR4:146859517[    G
#
#                                                Alt2
# 614470   ]CHR4:146807212]GGCTTTCCACTTTCCTCTTCTGAGGC
# 217314   ]CHR4:146807212]GGCTTTCCACTTTCCTCTTCTGAGGC
# 377622   ]CHR4:146807212]GGCTTTCCACTTTCCTCTTCTGAGGC
# 454346   ]CHR4:146807212]GGCTTTCCACTTTCCTCTTCTGAGGC
# 532205   ]CHR4:146807212]GGCTTTCCACTTTCCTCTTCTGAGGC
# 1067852  ]CHR4:146807212]GGCTTTCCACTTTCCTCTTCTGAGGC
# 614472                            ]CHR4:146824367]G
# 217316                            ]CHR4:146824367]G
# 377624                            ]CHR4:146824367]G
# 454348                            ]CHR4:146824367]G
# 532207                            ]CHR4:146824367]G
# 1067854                           ]CHR4:146824367]G

# %%
df_ALT[df_ALT['Gene']=='TERT']
# Out:
#                                                Key              Name   Source  \
# 102753  SNP_MuTect2_MODIFIER_TERT_chr5_1284675_T_C  JFCF_6_T_1_P_ALT  MuTect2
#
#         dbSNP Type  Chr1     Pos1 Chr2 Pos2       Qual1 Qual2   AF1    AF2  \
# 102753  False  SNP  chr5  1284675  NaN  NaN  2.27:0.761   NaN  0.62  0.091
#
#          Read1   Read2  Gene     Consequence    Impact Ref1 Alt1 Ref2 Alt2
# 102753  [3, 5]  [8, 0]  TERT  intron_variant  MODIFIER    T    C  NaN  NaN

# %% [markdown]
# ## Matrix

# %%
df_ALT_mat = df_ALT.groupby(['Name', 'Gene']).size()
df_ALT_mat = df_ALT_mat.reset_index(name='count')
df_ALT_mat = df_ALT_mat.pivot(columns='Name', index='Gene', values='count').fillna(0)

# %%
df_TEL_mat = df_TEL.groupby(['Name', 'Gene']).size()
df_TEL_mat = df_TEL_mat.reset_index(name='count')

df_TEL_mat = df_TEL_mat.pivot(columns='Name', index='Gene', values='count').fillna(0)

# %%
df_mat = pd.merge(df_ALT_mat,df_TEL_mat, how='outer', on='Gene').fillna(0).astype(int)

# %%
df_mat.to_csv("../results/telnet_mat_highmoderate.tsv", sep='\t')

# %% [markdown]
# # ALT and TEL specific

# %%
df_ALT_mutations = set(df_ALT['Key'].unique())
df_TEL_mutations = set(df_TEL['Key'].unique())

# %%
df_ALT_specific_mutations = df_ALT_mutations - df_TEL_mutations
df_TEL_specific_mutations = df_TEL_mutations - df_ALT_mutations

# %%
df_ALT_specific = df_ALT[df_ALT['Key'].isin(df_ALT_specific_mutations)]
df_TEL_specific = df_TEL[df_TEL['Key'].isin(df_TEL_specific_mutations)]

# %%
df_ALT_specific[['Name', 'Gene']].drop_duplicates().groupby(
    ['Gene']).size().sort_values(ascending=False).head(20)
# Out:
# Gene
# ATRX         9
# PARK2        3
# NBPF12       3
# IGLL5        3
# MMP11        2
# CTNNA2       2
# FXN          2
# CHD6         2
# UMAD1        2
# SAMD12       2
# C2CD3        2
# IGFN1        2
# CREB5        2
# TMTC1        2
# LINC01220    2
# IDH3A        2
# ARHGEF3      2
# TNS3         2
# CNTN5        2
# HMGA2        2
# dtype: int64

# %%
df_TEL_specific[['Name', 'Gene']].drop_duplicates().groupby(
    ['Gene']).size().sort_values(ascending=False).head(6)
# Out:
# Gene
# MYO9B       3
# MUC4        3
# NAALADL2    3
# AUTS2       3
# TP53TG3D    3
# CSMD3       3
# dtype: int64

# %% [markdown]
# # ALT vs TEL Fisher Test

# %%
df_count_merge = pd.merge(
    df_ALT_no_mortal[['Name', 'Gene']].drop_duplicates().groupby(
        ['Gene']).size().reset_index(name='count_ALT'),
    df_TEL_no_mortal[['Name', 'Gene']].drop_duplicates().groupby(
        ['Gene']).size().reset_index(name='count_TEL'), how='outer').fillna(0)

# %%
df_count_merge.head()
# Out:
#          Gene  count_ALT  count_TEL
# 0         A2M        1.0        0.0
# 1        AARD        1.0        0.0
# 2        ABI1        1.0        0.0
# 3  AC096644.1        1.0        0.0
# 4  AC131097.4        1.0        0.0

# %%
df_count_merge['p_value'] = df_count_merge.apply(lambda row: fisher_exact(
    np.array([[row['count_ALT'], row['count_TEL']],
              [9 - row['count_ALT'], 8 - row['count_TEL']]]))[1], axis=1)
df_count_merge['p_value_less'] = df_count_merge.apply(lambda row: fisher_exact(
    np.array([[row['count_ALT'], row['count_TEL']],
              [9 - row['count_ALT'], 8 - row['count_TEL']]]), alternative='less')[1], axis=1)
df_count_merge['p_value_greater'] = df_count_merge.apply(lambda row: fisher_exact(
    np.array([[row['count_ALT'], row['count_TEL']],
              [9 - row['count_ALT'], 8 - row['count_TEL']]]), alternative='greater')[1], axis=1)

# %%
pd.options.display.max_rows = 500

# %%
df_count_merge.sort_values(by=['p_value'])
# Out:
#           Gene  count_ALT  count_TEL   p_value  p_value_less  p_value_greater
# 49        ATRX        9.0        0.0  0.000041      1.000000         0.000041
# 1116  TP53TG3D        0.0        3.0  0.082353      0.082353         1.000000
# 729      CSMD3        0.0        3.0  0.082353      0.082353         1.000000
# 646      AUTS2        0.0        3.0  0.082353      0.082353         1.000000
# 933   NAALADL2        0.0        3.0  0.082353      0.082353         1.000000
# ...        ...        ...        ...       ...           ...              ...
# 400     NOTCH3        1.0        0.0  1.000000      1.000000         0.529412
# 399     NOTCH1        1.0        0.0  1.000000      1.000000         0.529412
# 398     NOS1AP        1.0        0.0  1.000000      1.000000         0.529412
# 404      NPHS2        1.0        0.0  1.000000      1.000000         0.529412
# 0          A2M        1.0        0.0  1.000000      1.000000         0.529412
#
# [1153 rows x 6 columns]

# %%
df_count_merge.to_csv("../results/MUTECT_Fisher_HighModerate.tsv", index=False, sep='\t')

# %%
tel_genes_list = pd.read_csv ("../immortal_simon/annovar/TelNet_2093GeneList.csv")
#Telnet telomere related gene list
top_tel_genes_list =tel_genes_list[tel_genes_list["TelNet Score"]>=3].sort_values(by=["Gene symbol"])
# Top 267 telomere-related genes (TelNet score >=3, max=10)
cp_genes_list = pd.read_csv ("../immortal_simon/annovar/CRsandHP_521GeneList.csv")
# 521 CRs and HP gene list

# %%
df_count_merge[df_count_merge["Gene"].isin(tel_genes_list["Gene symbol"])].sort_values(by=["count_ALT"],ascending=False)
# Out:
#           Gene  count_ALT  count_TEL   p_value  p_value_less  p_value_greater
# 49        ATRX        9.0        0.0  0.000041      1.000000         0.000041
# 606     ZNF827        4.0        6.0  0.334842      0.217812         0.963595
# 262      IDH3A        2.0        0.0  0.470588      1.000000         0.264706
# 223        FXN        2.0        0.0  0.470588      1.000000         0.264706
# 160        DMD        2.0        0.0  0.470588      1.000000         0.264706
# 256      HMGA2        2.0        0.0  0.470588      1.000000         0.264706
# 132      CREB5        2.0        1.0  1.000000      0.876471         0.547059
# 517    SLC25A5        2.0        3.0  0.619910      0.436652         0.889140
# 280      JAZF1        2.0        0.0  0.470588      1.000000         0.264706
# 474     RB1CC1        1.0        1.0  1.000000      0.735294         0.794118
# 459      PRMT5        1.0        0.0  1.000000      1.000000         0.529412
# 444       PIGN        1.0        0.0  1.000000      1.000000         0.529412
# 488    RPS6KA5        1.0        0.0  1.000000      1.000000         0.529412
# 489      RRAS2        1.0        0.0  1.000000      1.000000         0.529412
# 499      SCYL1        1.0        0.0  1.000000      1.000000         0.529412
# 443     PHLPP1        1.0        0.0  1.000000      1.000000         0.529412
# 512      SIRT1        1.0        0.0  1.000000      1.000000         0.529412
# 17       AHNAK        1.0        0.0  1.000000      1.000000         0.529412
# 531       SOX5        1.0        1.0  1.000000      0.735294         0.794118
# 525       SND1        1.0        1.0  1.000000      0.735294         0.794118
# 529      SOAT1        1.0        0.0  1.000000      1.000000         0.529412
# 436       PCNT        1.0        0.0  1.000000      1.000000         0.529412
# 537      STAT3        1.0        0.0  1.000000      1.000000         0.529412
# 545      SYNE1        1.0        0.0  1.000000      1.000000         0.529412
# 549     TAGLN2        1.0        0.0  1.000000      1.000000         0.529412
# 35       ANXA2        1.0        0.0  1.000000      1.000000         0.529412
# 555      TENM3        1.0        0.0  1.000000      1.000000         0.529412
# 560       TNIK        1.0        0.0  1.000000      1.000000         0.529412
# 577      USP18        1.0        0.0  1.000000      1.000000         0.529412
# 579       UTRN        1.0        0.0  1.000000      1.000000         0.529412
# 588      YWHAE        1.0        0.0  1.000000      1.000000         0.529412
# 591     ZC3H18        1.0        0.0  1.000000      1.000000         0.529412
# 437      PDS5B        1.0        0.0  1.000000      1.000000         0.529412
# 554      TCOF1        1.0        0.0  1.000000      1.000000         0.529412
# 430     PAXIP1        1.0        0.0  1.000000      1.000000         0.529412
# 156       DLG2        1.0        1.0  1.000000      0.735294         0.794118
# 411      NUP98        1.0        0.0  1.000000      1.000000         0.529412
# 38    ARHGAP12        1.0        0.0  1.000000      1.000000         0.529412
# 67    C17orf49        1.0        0.0  1.000000      1.000000         0.529412
# 76       CABP2        1.0        1.0  1.000000      0.735294         0.794118
# 80      CAMK1D        1.0        0.0  1.000000      1.000000         0.529412
# 83        CBX3        1.0        0.0  1.000000      1.000000         0.529412
# 90        CCM2        1.0        0.0  1.000000      1.000000         0.529412
# 137       CTC1        1.0        0.0  1.000000      1.000000         0.529412
# 148    DCLRE1A        1.0        0.0  1.000000      1.000000         0.529412
# 153      DHX35        1.0        0.0  1.000000      1.000000         0.529412
# 58        BET1        1.0        0.0  1.000000      1.000000         0.529412
# 177       E2F3        1.0        0.0  1.000000      1.000000         0.529412
# 251   HIST1H3H        1.0        0.0  1.000000      1.000000         0.529412
# 190    EPB41L1        1.0        0.0  1.000000      1.000000         0.529412
# 274      IPO13        1.0        0.0  1.000000      1.000000         0.529412
# 252   HIST1H4K        1.0        0.0  1.000000      1.000000         0.529412
# 390       NEK7        1.0        0.0  1.000000      1.000000         0.529412
# 249      HIF1A        1.0        0.0  1.000000      1.000000         0.529412
# 246       HELZ        1.0        0.0  1.000000      1.000000         0.529412
# 245      HDAC9        1.0        0.0  1.000000      1.000000         0.529412
# 219      FOXP1        1.0        0.0  1.000000      1.000000         0.529412
# 409     NUDCD2        1.0        0.0  1.000000      1.000000         0.529412
# 920       MLH3        0.0        1.0  0.470588      0.470588         1.000000
# 1038     RHPN1        0.0        1.0  0.470588      0.470588         1.000000
# 961       OLA1        0.0        1.0  0.470588      0.470588         1.000000
# 963      OPHN1        0.0        1.0  0.470588      0.470588         1.000000
# 998     PIK3C3        0.0        1.0  0.470588      0.470588         1.000000
# 999     PIK3CB        0.0        1.0  0.470588      0.470588         1.000000
# 1003     PLCH1        0.0        1.0  0.470588      0.470588         1.000000
# 1014     PRKD1        0.0        1.0  0.470588      0.470588         1.000000
# 1020     PTPRG        0.0        1.0  0.470588      0.470588         1.000000
# 1031       RB1        0.0        1.0  0.470588      0.470588         1.000000
# 1104     TDRD6        0.0        1.0  0.470588      0.470588         1.000000
# 1048    RPRD1B        0.0        1.0  0.470588      0.470588         1.000000
# 1077   SMARCA5        0.0        1.0  0.470588      0.470588         1.000000
# 1098     SYNE2        0.0        1.0  0.470588      0.470588         1.000000
# 1107      TEP1        0.0        1.0  0.470588      0.470588         1.000000
# 1121    TSG101        0.0        1.0  0.470588      0.470588         1.000000
# 1129      UGDH        0.0        1.0  0.470588      0.470588         1.000000
# 1133      VRK1        0.0        1.0  0.470588      0.470588         1.000000
# 1137      WEE1        0.0        1.0  0.470588      0.470588         1.000000
# 912      MECP2        0.0        1.0  0.470588      0.470588         1.000000
# 919      MKI67        0.0        1.0  0.470588      0.470588         1.000000
# 770     ELOVL7        0.0        1.0  0.470588      0.470588         1.000000
# 910      MECOM        0.0        2.0  0.205882      0.205882         1.000000
# 768      EIF5B        0.0        1.0  0.470588      0.470588         1.000000
# 679    CACNA1B        0.0        1.0  0.470588      0.470588         1.000000
# 716      CMTR1        0.0        1.0  0.470588      0.470588         1.000000
# 722     CPPED1        0.0        1.0  0.470588      0.470588         1.000000
# 727       CRYM        0.0        1.0  0.470588      0.470588         1.000000
# 728      CSE1L        0.0        1.0  0.470588      0.470588         1.000000
# 755        DST        0.0        1.0  0.470588      0.470588         1.000000
# 762      EHMT1        0.0        1.0  0.470588      0.470588         1.000000
# 767     EIF5A2        0.0        1.0  0.470588      0.470588         1.000000
# 774      EPHA4        0.0        1.0  0.470588      0.470588         1.000000
# 907      MCPH1        0.0        1.0  0.470588      0.470588         1.000000
# 811    GDAP1L1        0.0        1.0  0.470588      0.470588         1.000000
# 818      GNL3L        0.0        1.0  0.470588      0.470588         1.000000
# 825      GREM1        0.0        1.0  0.470588      0.470588         1.000000
# 837      HNF4A        0.0        1.0  0.470588      0.470588         1.000000
# 863      KMT2A        0.0        1.0  0.470588      0.470588         1.000000
# 896      LPIN3        0.0        1.0  0.470588      0.470588         1.000000
# 903    MACROD2        0.0        1.0  0.470588      0.470588         1.000000
# 904     MAD1L1        0.0        1.0  0.470588      0.470588         1.000000
# 1140      XRN1        0.0        1.0  0.470588      0.470588         1.000000

# %%
df_count_merge[df_count_merge["Gene"].isin(top_tel_genes_list["Gene symbol"])].sort_values(by=["count_ALT"],ascending=False)
# Out:
#           Gene  count_ALT  count_TEL   p_value  p_value_less  p_value_greater
# 49        ATRX        9.0        0.0  0.000041      1.000000         0.000041
# 606     ZNF827        4.0        6.0  0.334842      0.217812         0.963595
# 83        CBX3        1.0        0.0  1.000000      1.000000         0.529412
# 137       CTC1        1.0        0.0  1.000000      1.000000         0.529412
# 249      HIF1A        1.0        0.0  1.000000      1.000000         0.529412
# 251   HIST1H3H        1.0        0.0  1.000000      1.000000         0.529412
# 252   HIST1H4K        1.0        0.0  1.000000      1.000000         0.529412
# 390       NEK7        1.0        0.0  1.000000      1.000000         0.529412
# 499      SCYL1        1.0        0.0  1.000000      1.000000         0.529412
# 512      SIRT1        1.0        0.0  1.000000      1.000000         0.529412
# 537      STAT3        1.0        0.0  1.000000      1.000000         0.529412
# 818      GNL3L        0.0        1.0  0.470588      0.470588         1.000000
# 904     MAD1L1        0.0        1.0  0.470588      0.470588         1.000000
# 907      MCPH1        0.0        1.0  0.470588      0.470588         1.000000
# 1031       RB1        0.0        1.0  0.470588      0.470588         1.000000
# 1107      TEP1        0.0        1.0  0.470588      0.470588         1.000000

# %%
sv_df[(sv_df["Key"].str.contains("_RB1_"))]
# Out:
#                                                       Key            Name  \
# 874319  SV_GRIDSS_HIGH_RB1_Somatic_chr13_49032017_4903...  JFCF_6_T_1J_6B
#
#         Source  dbSNP      Type   Chr1               Pos1   Chr2  \
# 874319  GRIDSS  False  Deletion  chr13  49032017-49032018  chr13
#
#                      Pos2               Qual1               Qual2  AF1  AF2  \
# 874319  49032029-49032030  NotSplit:0;Split:0  NotSplit:0;Split:0  NaN  NaN
#
#                      Read1               Read2 Gene  Consequence Impact Ref1  \
# 874319  NotSplit:0;Split:0  NotSplit:0;Split:0  RB1  gene_fusion   HIGH    C
#
#                      Alt1 Ref2               Alt2
# 874319  C[CHR13:49032030[    G  ]CHR13:49032018]G

# %%
df_count_merge[df_count_merge["Gene"].isin(cp_genes_list["Gene symbol"])].sort_values(by=["count_ALT"],ascending=False)
# Out:
#           Gene  count_ALT  count_TEL   p_value  p_value_less  p_value_greater
# 49        ATRX        9.0        0.0  0.000041      1.000000         0.000041
# 115       CHD6        2.0        0.0  0.470588      1.000000         0.264706
# 250   HIST1H1T        2.0        1.0  1.000000      0.876471         0.547059
# 24      ALKBH3        1.0        0.0  1.000000      1.000000         0.529412
# 282      KAT6A        1.0        0.0  1.000000      1.000000         0.529412
# 42       ASXL3        1.0        0.0  1.000000      1.000000         0.529412
# 525       SND1        1.0        1.0  1.000000      0.735294         0.794118
# 512      SIRT1        1.0        0.0  1.000000      1.000000         0.529412
# 507      SETD5        1.0        0.0  1.000000      1.000000         0.529412
# 477      RNF17        1.0        0.0  1.000000      1.000000         0.529412
# 459      PRMT5        1.0        0.0  1.000000      1.000000         0.529412
# 388      NCOA6        1.0        0.0  1.000000      1.000000         0.529412
# 564     TRIM24        1.0        0.0  1.000000      1.000000         0.529412
# 245      HDAC9        1.0        0.0  1.000000      1.000000         0.529412
# 189      EP400        1.0        0.0  1.000000      1.000000         0.529412
# 168       DPF3        1.0        0.0  1.000000      1.000000         0.529412
# 83        CBX3        1.0        0.0  1.000000      1.000000         0.529412
# 61       BTAF1        1.0        0.0  1.000000      1.000000         0.529412
# 60       BRWD1        1.0        0.0  1.000000      1.000000         0.529412
# 193      ERCC6        1.0        0.0  1.000000      1.000000         0.529412
# 944      NCOA3        0.0        1.0  0.470588      0.470588         1.000000
# 1101   TBL1XR1        0.0        1.0  0.470588      0.470588         1.000000
# 1077   SMARCA5        0.0        1.0  0.470588      0.470588         1.000000
# 1049      RSF1        0.0        1.0  0.470588      0.470588         1.000000
# 1013     PRDM7        0.0        1.0  0.470588      0.470588         1.000000
# 1012    PRDM11        0.0        1.0  0.470588      0.470588         1.000000
# 996      PHRF1        0.0        1.0  0.470588      0.470588         1.000000
# 995      PHF12        0.0        1.0  0.470588      0.470588         1.000000
# 863      KMT2A        0.0        1.0  0.470588      0.470588         1.000000
# 912      MECP2        0.0        1.0  0.470588      0.470588         1.000000
# 910      MECOM        0.0        2.0  0.205882      0.205882         1.000000
# 867    L3MBTL4        0.0        1.0  0.470588      0.470588         1.000000
# 858   KIAA2026        0.0        1.0  0.470588      0.470588         1.000000
# 844       ING3        0.0        1.0  0.470588      0.470588         1.000000
# 777       EYA2        0.0        1.0  0.470588      0.470588         1.000000
# 762      EHMT1        0.0        1.0  0.470588      0.470588         1.000000
# 613     ACTL6A        0.0        1.0  0.470588      0.470588         1.000000
# 1104     TDRD6        0.0        1.0  0.470588      0.470588         1.000000

# %% [markdown]
# # 1J comparison

# %%
df_1J_ALT = df[df['Name'].isin(['JFCF_6_T_1J_11E','JFCF_6_T_1J_1_3C'])]
df_1J_TEL = df[df['Name'].isin(['JFCF_6_T_1J_11C','JFCF_6_T_1J_6B'])]

# %%
df_1J_ALT_mutations = set(df_1J_ALT['Key'].unique())
df_1J_TEL_mutations = set(df_1J_TEL['Key'].unique())

df_1J_ALT_specific_mutations = df_1J_ALT_mutations - df_1J_TEL_mutations
df_1J_TEL_specific_mutations = df_1J_TEL_mutations - df_1J_ALT_mutations

df_1J_ALT_specific = df_1J_ALT[df_1J_ALT['Key'].isin(df_1J_ALT_specific_mutations)]
df_1J_TEL_specific = df_1J_TEL[df_1J_TEL['Key'].isin(df_1J_TEL_specific_mutations)]

# %%
df_1J_ALT_specific[['Name', 'Gene']].drop_duplicates().groupby(
    ['Gene']).size().sort_values(ascending=False).head(20)
# Out:
# Gene
# JAZF1                2
# ATRX                 2
# HMGA2                2
# FXN                  2
# LINC01220            2
# LOC400684            2
# MMP11                2
# DPY19L3&LOC400684    2
# DGKK                 2
# PARK2                2
# CNTN5                2
# CMIP&WFDC1           2
# SAMD12               2
# CTNNA2               2
# IDH3A                2
# ACACA&PARD6G         2
# ADAMTSL3&PARD6G      2
# ACACA&PARD6G-AS1     2
# WFDC1                2
# EXOC6                1
# dtype: int64

# %%
df_1J_TEL_specific[['Name', 'Gene']].drop_duplicates().groupby(
    ['Gene']).size().sort_values(ascending=False).head(20)
# Out:
# Gene
# CARNMT1&RORB           2
# C9orf41-AS1            2
# ADD1                   2
# NBPF10                 2
# GSDMA&MED24            2
# RORB                   2
# GSDMA&PSMD3            2
# FLG2                   2
# CARNMT1                2
# C9orf41-AS1&RORB       2
# C9orf41-AS1&CARNMT1    2
# KISS1                  1
# KIF16B                 1
# INSRR                  1
# IL18RAP                1
# INPP5B                 1
# ING3                   1
# KRTAP10-7              1
# IGLL5                  1
# IGFN1                  1
# dtype: int64

# %% [markdown]
# # P_ALT vs P_TEL

# %%
df_P_ALT = df[df['Name'].isin(['JFCF_6_T_1_P_ALT'])]
df_P_TEL = df[df['Name'].isin(['JFCF_6_T_1_P_TEL'])]

# %%
df_P_ALT_mutations = set(df_P_ALT['Key'].unique())
df_P_TEL_mutations = set(df_P_TEL['Key'].unique())

df_P_ALT_specific_mutations = df_P_ALT_mutations - df_P_TEL_mutations
df_P_TEL_specific_mutations = df_P_TEL_mutations - df_P_ALT_mutations

df_P_ALT_specific = df_P_ALT[df_P_ALT['Key'].isin(df_P_ALT_specific_mutations)]
df_P_TEL_specific = df_P_TEL[df_P_TEL['Key'].isin(df_P_TEL_specific_mutations)]

# %%
df_P_ALT_specific[['Name', 'Gene']].drop_duplicates()
# Out:
#                      Name                    Gene
# 104289   JFCF_6_T_1_P_ALT                   LRGUK
# 109606   JFCF_6_T_1_P_ALT                    ATRX
# 107382   JFCF_6_T_1_P_ALT                   SPG11
# 99759    JFCF_6_T_1_P_ALT                    U1.8
# 105405   JFCF_6_T_1_P_ALT                ARHGAP12
# 105876   JFCF_6_T_1_P_ALT                C11orf48
# 100381   JFCF_6_T_1_P_ALT                C1orf116
# 109299   JFCF_6_T_1_P_ALT                 FAM230A
# 103375   JFCF_6_T_1_P_ALT                     HK3
# 109234   JFCF_6_T_1_P_ALT               KRTAP10-6
# 104469   JFCF_6_T_1_P_ALT                   MICU3
# 108632   JFCF_6_T_1_P_ALT                   MUC16
# 108331   JFCF_6_T_1_P_ALT                  QRICH2
# 106616   JFCF_6_T_1_P_ALT                   RNF17
# 104438   JFCF_6_T_1_P_ALT                   RP1L1
# 109708   JFCF_6_T_1_P_ALT                 SLC25A5
# 1036666  JFCF_6_T_1_P_ALT                   CCBE1
# 1010062  JFCF_6_T_1_P_ALT                  ELAVL2
# 1013824  JFCF_6_T_1_P_ALT                   ERCC6
# 1028674  JFCF_6_T_1_P_ALT                FAM189A1
# 989401   JFCF_6_T_1_P_ALT                   GSTCD
# 1042791  JFCF_6_T_1_P_ALT  LOC101927859&LOC729461
# 1042789  JFCF_6_T_1_P_ALT            LOC101927859
# 1036999  JFCF_6_T_1_P_ALT               LOC284294
# 1042790  JFCF_6_T_1_P_ALT               LOC729461
# 1029724  JFCF_6_T_1_P_ALT                   LOXL1
# 1029681  JFCF_6_T_1_P_ALT                  MEGF11
# 1036113  JFCF_6_T_1_P_ALT                    NPC1
# 1013527  JFCF_6_T_1_P_ALT                   PARD3
# 1025569  JFCF_6_T_1_P_ALT                    PCCA
# 1024373  JFCF_6_T_1_P_ALT                   PCDH9
# 1023767  JFCF_6_T_1_P_ALT                   PDS5B
# 1013825  JFCF_6_T_1_P_ALT                   PGBD3
# 1036950  JFCF_6_T_1_P_ALT                    PIGN
# 1037571  JFCF_6_T_1_P_ALT                 PIP5K1C
# 1029997  JFCF_6_T_1_P_ALT              PML&SCAPER
# 1023784  JFCF_6_T_1_P_ALT                 STARD13
# 1029875  JFCF_6_T_1_P_ALT                 TBC1D21
# 1020490  JFCF_6_T_1_P_ALT                   TMTC1
# 990302   JFCF_6_T_1_P_ALT                  ZNF827

# %%
df_P_TEL_specific[['Name', 'Gene']].drop_duplicates()
# Out:
#                      Name           Gene
# 93586    JFCF_6_T_1_P_TEL         AKAP12
# 94343    JFCF_6_T_1_P_TEL          FGFR1
# 95631    JFCF_6_T_1_P_TEL            MDK
# 98475    JFCF_6_T_1_P_TEL          MYO9B
# 98182    JFCF_6_T_1_P_TEL  RP11-683L23.1
# ...                   ...            ...
# 1062575  JFCF_6_T_1_P_TEL         PIK3CB
# 1090666  JFCF_6_T_1_P_TEL          PSMB7
# 1058113  JFCF_6_T_1_P_TEL          SGPP2
# 1081201  JFCF_6_T_1_P_TEL          SUGCT
# 1048251  JFCF_6_T_1_P_TEL         ZNF644
#
# [71 rows x 2 columns]

# %% [markdown]
# # intersection

# %%
print(set(df_P_ALT_specific['Gene']).intersection(set(df_1J_ALT_specific['Gene'])))
# Out:
# {'ATRX', 'PIP5K1C'}

# %%
set(df_P_TEL_specific['Gene']).intersection(set(df_1J_TEL_specific['Gene']))
# Out:
# {'AUTS2', 'CELA3A', 'MUC4', 'MYO9B', 'NAALADL2', 'TAS2R43'}

# %% [markdown]
# # gene list

# %%
genes = pd.read_excel('../data/TelomereRelatedGeneList_2020020.xlsx', sheet_name='Overall')

# %%
df_gene_list = df[df['Gene'].isin(genes['Gene'])]
df_TEL_gene_list = df_gene_list[df_gene_list['Name'].isin(samples[samples['TMM']=='TEL']['Immortal'])]
df_ALT_gene_list = df_gene_list[df_gene_list['Name'].isin(samples[samples['TMM']=='ALT']['Immortal'])]

# %% [markdown]
# ## non-specific

# %%
df_ALT_gene_list[['Name', 'Gene']].drop_duplicates().groupby(
    ['Gene']).size().sort_values(ascending=False).head(25)
# Out:
# Gene
# ATRX        9
# ZNF827      4
# IDH3A       2
# TCOF1       1
# TAGLN2      1
# CBX3        1
# CTC1        1
# DCLRE1A     1
# E2F3        1
# HELZ        1
# HIF1A       1
# NEK7        1
# YWHAE       1
# PRMT5       1
# SCYL1       1
# SIRT1       1
# SND1        1
# STAT3       1
# SUV420H2    1
# PAXIP1      1
# dtype: int64

# %%
df_TEL_gene_list[['Name', 'Gene']].drop_duplicates().groupby(
    ['Gene']).size().sort_values(ascending=False).head(20)
# Out:
# Gene
# ZNF827     6
# WEE1       1
# TEP1       1
# TDRD6      1
# SND1       1
# SMARCA5    1
# RPRD1B     1
# RB1        1
# OLA1       1
# MKI67      1
# MCPH1      1
# MAD1L1     1
# GNL3L      1
# EIF5A2     1
# CSE1L      1
# dtype: int64

# %%
df_ALT_gene_list_mat = df_ALT_gene_list.groupby(['Name', 'Gene']).size()
df_ALT_gene_list_mat = df_ALT_gene_list_mat.reset_index(name='count')
df_ALT_gene_list_mat = df_ALT_gene_list_mat.pivot(columns='Name', index='Gene', values='count').fillna(0)

# %%
df_TEL_gene_list_mat = df_TEL_gene_list.groupby(['Name', 'Gene']).size()
df_TEL_gene_list_mat = df_TEL_gene_list_mat.reset_index(name='count')

df_TEL_gene_list_mat = df_TEL_gene_list_mat.pivot(columns='Name', index='Gene', values='count').fillna(0)

# %%
df_gene_list_mat = pd.merge(df_ALT_gene_list_mat,df_TEL_gene_list_mat, how='outer', on='Gene').fillna(0).astype(int)

# %%
df_gene_list_mat.to_csv("../results/gene_list_mat_highmoderate.tsv", sep='\t')

# %% [markdown]
# ## specific

# %%
df_ALT_mutations_gene_list = set(df_ALT_gene_list['Key'].unique())
df_TEL_mutations_gene_list = set(df_TEL_gene_list['Key'].unique())

# %%
df_ALT_specific_mutations_gene_list = df_ALT_mutations_gene_list - df_TEL_mutations_gene_list
df_TEL_specific_mutations_gene_list = df_TEL_mutations_gene_list - df_ALT_mutations_gene_list

# %%
df_ALT_specific_gene_list = df_ALT_gene_list[df_ALT_gene_list['Key'].isin(df_ALT_specific_mutations_gene_list)]
df_TEL_specific_gene_list = df_TEL_gene_list[df_TEL_gene_list['Key'].isin(df_TEL_specific_mutations_gene_list)]

# %%
df_ALT_specific_gene_list[['Name', 'Gene']].drop_duplicates().groupby(
    ['Gene']).size().sort_values(ascending=False).head(20)
# Out:
# Gene
# ATRX        9
# IDH3A       2
# YWHAE       1
# CBX3        1
# CTC1        1
# DCLRE1A     1
# E2F3        1
# HELZ        1
# HIF1A       1
# NEK7        1
# ZNF827      1
# PRMT5       1
# SCYL1       1
# SIRT1       1
# SND1        1
# STAT3       1
# SUV420H2    1
# TAGLN2      1
# TCOF1       1
# PAXIP1      1
# dtype: int64

# %%
df_TEL_specific_gene_list[['Name', 'Gene']].drop_duplicates().groupby(
    ['Gene']).size().sort_values(ascending=False).head(20)
# Out:
# Gene
# WEE1       1
# TEP1       1
# TDRD6      1
# SND1       1
# SMARCA5    1
# RPRD1B     1
# RB1        1
# OLA1       1
# MKI67      1
# MCPH1      1
# MAD1L1     1
# GNL3L      1
# EIF5A2     1
# CSE1L      1
# dtype: int64

# %% [markdown]
# # gene list TelNet

# %%
genes = pd.read_csv('../data/TelNet_2093GeneList.csv')

# %%
df_gene_list = df[df['Gene'].isin(genes['Gene symbol'])]
df_TEL_gene_list = df_gene_list[df_gene_list['Name'].isin(samples[samples['TMM']=='TEL']['Immortal'])]
df_ALT_gene_list = df_gene_list[df_gene_list['Name'].isin(samples[samples['TMM']=='ALT']['Immortal'])]

# %% [markdown]
# ## non-specific

# %%
df_ALT_gene_list[['Name', 'Gene']].drop_duplicates().groupby(
    ['Gene']).size().sort_values(ascending=False).head(25)
# Out:
# Gene
# ATRX        9
# ZNF827      4
# SLC25A5     2
# CREB5       2
# DMD         2
# FXN         2
# HMGA2       2
# IDH3A       2
# JAZF1       2
# SYNE1       1
# HIST1H3H    1
# HELZ        1
# HDAC9       1
# TNIK        1
# FOXP1       1
# EPB41L1     1
# E2F3        1
# USP18       1
# DLG2        1
# DHX35       1
# DCLRE1A     1
# CTC1        1
# UTRN        1
# CCM2        1
# CBX3        1
# dtype: int64

# %%
df_TEL_gene_list[['Name', 'Gene']].drop_duplicates().groupby(
    ['Gene']).size().sort_values(ascending=False).head(20)
# Out:
# Gene
# ZNF827     6
# SLC25A5    3
# MECOM      2
# CMTR1      1
# EPHA4      1
# MCPH1      1
# MAD1L1     1
# MACROD2    1
# LPIN3      1
# KMT2A      1
# HNF4A      1
# GREM1      1
# GNL3L      1
# GDAP1L1    1
# ELOVL7     1
# CPPED1     1
# MECP2      1
# CACNA1B    1
# EIF5A2     1
# EHMT1      1
# dtype: int64

# %%
df_ALT_gene_list_mat = df_ALT_gene_list.groupby(['Name', 'Gene']).size()
df_ALT_gene_list_mat = df_ALT_gene_list_mat.reset_index(name='count')
df_ALT_gene_list_mat = df_ALT_gene_list_mat.pivot(columns='Name', index='Gene', values='count').fillna(0)

# %%
df_TEL_gene_list_mat = df_TEL_gene_list.groupby(['Name', 'Gene']).size()
df_TEL_gene_list_mat = df_TEL_gene_list_mat.reset_index(name='count')

df_TEL_gene_list_mat = df_TEL_gene_list_mat.pivot(columns='Name', index='Gene', values='count').fillna(0)

# %%
df_gene_list_mat = pd.merge(df_ALT_gene_list_mat,df_TEL_gene_list_mat, how='outer', on='Gene').fillna(0).astype(int)

# %%
df_gene_list_mat.to_csv("../results/gene_list_telnet_mat_highmoderate.tsv", sep='\t')

# %% [markdown]
# ## specific

# %%
df_ALT_mutations_gene_list = set(df_ALT_gene_list['Key'].unique())
df_TEL_mutations_gene_list = set(df_TEL_gene_list['Key'].unique())

# %%
df_ALT_specific_mutations_gene_list = df_ALT_mutations_gene_list - df_TEL_mutations_gene_list
df_TEL_specific_mutations_gene_list = df_TEL_mutations_gene_list - df_ALT_mutations_gene_list

# %%
df_ALT_specific_gene_list = df_ALT_gene_list[df_ALT_gene_list['Key'].isin(df_ALT_specific_mutations_gene_list)]
df_TEL_specific_gene_list = df_TEL_gene_list[df_TEL_gene_list['Key'].isin(df_TEL_specific_mutations_gene_list)]

# %%
df_ALT_specific_gene_list[['Name', 'Gene']].drop_duplicates().groupby(
    ['Gene']).size().sort_values(ascending=False).head(20)
# Out:
# Gene
# ATRX        9
# JAZF1       2
# DMD         2
# IDH3A       2
# HMGA2       2
# CREB5       2
# FXN         2
# HIST1H4K    1
# HIST1H3H    1
# HIF1A       1
# HELZ        1
# HDAC9       1
# FOXP1       1
# EPB41L1     1
# E2F3        1
# DLG2        1
# ZC3H18      1
# DHX35       1
# DCLRE1A     1
# CTC1        1
# dtype: int64

# %%
df_TEL_specific_gene_list[['Name', 'Gene']].drop_duplicates().groupby(
    ['Gene']).size().sort_values(ascending=False).head(20)
# Out:
# Gene
# MECOM      2
# WEE1       1
# MCPH1      1
# MAD1L1     1
# MACROD2    1
# LPIN3      1
# KMT2A      1
# HNF4A      1
# GREM1      1
# GNL3L      1
# GDAP1L1    1
# EPHA4      1
# XRN1       1
# EIF5B      1
# EIF5A2     1
# EHMT1      1
# DST        1
# DLG2       1
# CSE1L      1
# CRYM       1
# dtype: int64
