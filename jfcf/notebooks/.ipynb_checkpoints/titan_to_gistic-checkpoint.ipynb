# %%
import glob
import pandas as pd
import numpy as np

# %%
files = glob.glob("../data/CNA_results/segs/*")

# %%
dfs = [pd.read_csv(f, sep='\t') for f in files]

# %%
for df in dfs:
    to_del = []
    for i in range(1, df.shape[0]):
        if int(df.iloc[i, 2]) < int(df.iloc[i - 1, 3]) and df.iloc[i, 0] == df.iloc[
                i - 1, 0] and df.iloc[i, 1] == df.iloc[i - 1, 1]:
            to_del.append(i-1)
    df = df.drop(to_del)

# %%
df_all = pd.concat(dfs)

# %%
df_all['Sample'] = df_all['Sample'].str.replace('tumor_sample_', '')

# %%
df_all.head()
# Out:
#   Sample Chromosome  Start_Position.bp.  End_Position.bp.  Length.snp.  \
# 0  GM847       chr1              820979         145119663        94047
# 1  GM847       chr1           145390231         147389060          831
# 2  GM847       chr1           147389678         147389996           18
# 3  GM847       chr1           147717298         149201760          233
# 4  GM847       chr1           149203811         149239973          449
#
#    Median_Ratio  Median_logR  TITAN_state TITAN_call  Copy_Number  MinorCN  \
# 0      0.655172     0.125145            3        HET            2        1
# 1      1.000000    -0.386005            2       NLOH            2        0
# 2      0.640000    -0.514327            3        HET            2        1
# 3      1.000000    -0.434125            2       NLOH            2        0
# 4      0.600000    -0.373116            3        HET            2        1
#
#    MajorCN  Clonal_Cluster  Cellular_Prevalence  logR_Copy_Number  \
# 0        1             NaN                  NaN          2.185415
# 1        2             1.0                  1.0          1.519662
# 2        1             NaN                  NaN          1.386405
# 3        2             1.0                  1.0          1.468298
# 4        1             NaN                  NaN          1.533713
#
#    Corrected_Ratio  Corrected_Copy_Number Corrected_Call  Corrected_MajorCN  \
# 0         0.658447                      2           NEUT                  1
# 1         1.000000                      2           NEUT                  2
# 2         0.644658                      2           NEUT                  1
# 3         1.000000                      2           NEUT                  2
# 4         0.603008                      2           NEUT                  1
#
#    Corrected_MinorCN
# 0                  1
# 1                  0
# 2                  1
# 3                  0
# 4                  1

# %%
df_all['Sample'].unique()
# Out:
# array(['GM847', 'IIICF_402DE_D2', 'IIICF_a2', 'IIICF_c', 'IIICF_d2',
#        'IIICF_E6_A1', 'IIICF_E6_A2', 'IIICF_E6E7_A1',
#        'IIICF_E6E7_C4_post', 'IIICF_T_A6', 'IIICF_T_B1', 'IIICF_T_B3',
#        'IIICF_T_C3', 'IIICF_T_C4', 'IVG_BF_LXSN_post', 'JFCF_6_P_pLKO_5',
#        'JFCF_6_T_1_C', 'JFCF_6_T_1_D', 'JFCF_6_T_1_F', 'JFCF_6_T_1_G',
#        'JFCF_6_T_1_H', 'JFCF_6_T_1J_11C', 'JFCF_6_T_1J_11E',
#        'JFCF_6_T_1J_1_3C', 'JFCF_6_T_1J_6B', 'JFCF_6_T_1_L',
#        'JFCF_6_T_1_M', 'JFCF_6_T_1_P_ALT', 'JFCF_6_T_1_P_TEL',
#        'JFCF_6_T_1_Q', 'JFCF_6_T_1_R', 'JFCF_6_T_2H', 'JFCF_6_T_5K',
#        'LFS_05F_24_post', 'MeT_4A_post', 'VA13'], dtype=object)

# %%
df_all['logR'] = df_all.apply(
    lambda row: np.log2(row['logR_Copy_Number'] / 2)
    if row['Chromosome'] != 'chrX' else np.log2(row['logR_Copy_Number'] / 1), axis=1)

# %%
df_all = df_all[['Sample', 'Chromosome', 'Start_Position.bp.', 'End_Position.bp.', 'Length.snp.', 'logR']]
df_all['Chromosome'] = df_all['Chromosome'].str.replace('chr', '')
df_all['Chromosome'] = df_all['Chromosome'].str.replace('X', '23')
df_all['Chromosome'] = df_all['Chromosome'].str.replace('Y', '24')
# Out:
# /home/scai/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/scai/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/scai/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# # Alex

# %%
ATRX_WT = [
    'IIICF_402DE_D2', 'IIICF_d2', 'IIICF_E6E7_A1', 'IIICF_T_C3',
    'IIICF_E6E7_C4_post', 'IVG_BF_LXSN_post', 'LFS_05F_24_post', 'MeT_4A_post'
]
ATRX_MUT = [
    'JFCF_6_T_1J_1_3C', 'JFCF_6_T_1_M', 'JFCF_6_P_pLKO_5', 'JFCF_6_T_1_Q',
    'IIICF_a2', 'IIICF_E6_A2', 'IIICF_T_B1', 'IIICF_T_B3', 'IIICF_T_C4',
    'GM847', 'IIICF_c', 'JFCF_6_T_1_D', 'JFCF_6_T_1J_11E', 'JFCF_6_T_1J_1_3C',
    'JFCF_6_T_1_L', 'JFCF_6_T_1_P_ALT', 'JFCF_6_T_1_R', 'JFCF_6_T_5K',
    'IIICF_T_A6', 'VA13'
]

# %%
df_ATRX_WT = df_all[df_all['Sample'].isin(ATRX_WT)]
df_ATRX_MUT = df_all[df_all['Sample'].isin(ATRX_MUT)]

# %%
df_ATRX_WT.to_csv('../data/cnv_gistic_ATRX_WT.txt', sep='\t', index=False, header=False)
df_ATRX_MUT.to_csv('../data/cnv_gistic_ATRX_MUT.txt', sep='\t', index=False, header=False)

# %% [markdown]
# # JFCF ALT vs TEL

# %%
JFCF_ALT = [
    'JFCF_6_T_1J_1_3C', 'JFCF_6_T_1_M', 'JFCF_6_T_1_Q',
    'JFCF_6_T_1_D', 'JFCF_6_T_1J_11E',
    'JFCF_6_T_1_L', 'JFCF_6_T_1_P_ALT', 'JFCF_6_T_1_R', 'JFCF_6_T_5K'
]
JFCF_TEL = [
    'JFCF_6_T_1_C', 'JFCF_6_T_1_F', 'JFCF_6_T_1_G',
    'JFCF_6_T_1_H', 'JFCF_6_T_1_P_TEL',
    'JFCF_6_T_1J_11C', 'JFCF_6_T_1J_6B', 'JFCF_6_T_2H'
]

# %%
df_JFCF_ALT = df_all[df_all['Sample'].isin(JFCF_ALT)]
df_JFCF_TEL = df_all[df_all['Sample'].isin(JFCF_TEL)]

# %%
df_JFCF_ALT.to_csv('../data/cnv_gistic_JFCF_ALT.txt', sep='\t', index=False, header=False)
df_JFCF_TEL.to_csv('../data/cnv_gistic_JFCF_TEL.txt', sep='\t', index=False, header=False)

# %%
df_JFCF_TEL['Sample'].unique().size
# Out:
# 8

# %%
df_JFCF_TEL[(df_JFCF_TEL['Sample'] != 'JFCF_6_T_1_C') & (df_JFCF_TEL['Chromosome']=='7')]
# Out:
#             Sample Chromosome  Start_Position.bp.  End_Position.bp.  \
# 207   JFCF_6_T_1_F          7               50134           7099830
# 208   JFCF_6_T_1_F          7             7100414           7104895
# 209   JFCF_6_T_1_F          7             7124967          65833085
# 210   JFCF_6_T_1_F          7            65834094          65834280
# 211   JFCF_6_T_1_F          7            65838141          99179970
# ...            ...        ...                 ...               ...
# 1974   JFCF_6_T_2H          7           154400432         155779971
# 1975   JFCF_6_T_2H          7           155780296         155787823
# 1976   JFCF_6_T_2H          7           155790922         156909587
# 1977   JFCF_6_T_2H          7           156923858         157138136
# 1978   JFCF_6_T_2H          7           157139345         159119220
#
#       Length.snp.      logR
# 207          5817  0.000000
# 208            29  0.584963
# 209         43427  0.000000
# 210            13  0.000000
# 211         21683  0.000000
# ...           ...       ...
# 1974         1235  0.000000
# 1975           15 -1.000000
# 1976          835  0.000000
# 1977          194  0.584963
# 1978         1320  0.000000
#
# [455 rows x 6 columns]

# %%
df_all[df_all['Sample']=='JFCF_6_T_1_D']
# Out:
#             Sample Chromosome  Start_Position.bp.  End_Position.bp.  \
# 0     JFCF_6_T_1_D       chr1              821038          26599542
# 1     JFCF_6_T_1_D       chr1            26600483          26610030
# 2     JFCF_6_T_1_D       chr1            26612297          72149769
# 3     JFCF_6_T_1_D       chr1            72150052          72299344
# 4     JFCF_6_T_1_D       chr1            72300145          86957925
# ...            ...        ...                 ...               ...
# 1482  JFCF_6_T_1_D       chrX            78793320          86920387
# 1483  JFCF_6_T_1_D       chrX            88293160         122681584
# 1484  JFCF_6_T_1_D       chrX           122939896         130461551
# 1485  JFCF_6_T_1_D       chrX           130495219         140846514
# 1486  JFCF_6_T_1_D       chrX           145131562         154871281
#
#       Length.snp.  Median_Ratio  Median_logR  TITAN_state TITAN_call  \
# 0           18365      0.666667    -0.101086            3        HET
# 1              12      0.692876    -1.183549            1       DLOH
# 2           27914      0.666667    -0.022627            3        HET
# 3             140      1.000000    -0.551061            1       DLOH
# 4           10330      0.666667    -0.005953            3        HET
# ...           ...           ...          ...          ...        ...
# 1482           18      0.961538     0.175957            2       NLOH
# 1483          121      0.750000     0.292554            5       GAIN
# 1484            9      1.000000     0.314440            4       ALOH
# 1485           47      0.666667     0.159949            3        HET
# 1486           12      0.964286     0.292122            2       NLOH
#
#       Copy_Number  MinorCN  MajorCN  Clonal_Cluster  Cellular_Prevalence  \
# 0               2        1        1             NaN                  NaN
# 1               1        0        1             1.0                  1.0
# 2               2        1        1             NaN                  NaN
# 3               1        0        1             1.0                  1.0
# 4               2        1        1             NaN                  NaN
# ...           ...      ...      ...             ...                  ...
# 1482            2        0        2             1.0                  1.0
# 1483            3        1        2             1.0                  1.0
# 1484            3        0        3             1.0                  1.0
# 1485            2        1        1             NaN                  NaN
# 1486            2        0        2             1.0                  1.0
#
#       logR_Copy_Number  Corrected_Ratio  Corrected_Copy_Number Corrected_Call  \
# 0             1.852238         0.683187                      2           NEUT
# 1             0.777770         0.738405                      1           HETD
# 2             1.966020         0.682231                      2           NEUT
# 3             1.306748         1.000000                      1           HETD
# 4             1.991008         0.682036                      2           NEUT
# ...                ...              ...                    ...            ...
# 1482          2.283242         0.998650                      2           NEUT
# 1483          2.490887         0.768427                      3           GAIN
# 1484          2.531768         1.000000                      3           GAIN
# 1485          2.256021         0.680230                      2           NEUT
# 1486          2.490086         0.998518                      2           NEUT
#
#       Corrected_MajorCN  Corrected_MinorCN
# 0                     1                  1
# 1                     1                  0
# 2                     1                  1
# 3                     1                  0
# 4                     1                  1
# ...                 ...                ...
# 1482                  2                  0
# 1483                  2                  1
# 1484                  3                  0
# 1485                  1                  1
# 1486                  2                  0
#
# [1487 rows x 20 columns]

# %%
df_JFCF_ALT[df_JFCF_ALT['Chromosome']=='7']
# Out:
#            Sample Chromosome  Start_Position.bp.  End_Position.bp.  \
# 639  JFCF_6_T_1_D          7               50134           4605862
# 640  JFCF_6_T_1_D          7             4607364           4649534
# 641  JFCF_6_T_1_D          7             4650495           5159711
# 642  JFCF_6_T_1_D          7             5170413           5229115
# 643  JFCF_6_T_1_D          7             5230373           5539958
# ..            ...        ...                 ...               ...
# 391   JFCF_6_T_5K          7           142166488         149415333
# 392   JFCF_6_T_5K          7           149421210         149461487
# 393   JFCF_6_T_5K          7           149484798         152105765
# 394   JFCF_6_T_5K          7           152105784         152105877
# 395   JFCF_6_T_5K          7           152105887         159119220
#
#      Length.snp.      logR
# 639         4232  0.171414
# 640           62  0.427804
# 641          459  0.172717
# 642          154  0.428363
# 643          288  0.220138
# ..           ...       ...
# 391         5976 -0.064129
# 392           28  0.526949
# 393         1990 -0.060136
# 394            4  0.016849
# 395         5605 -0.117980
#
# [766 rows x 6 columns]
