# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
"""
Demonstrates plotting chromosome ideograms and genes (or any features, really)
using matplotlib.
1) Assumes a file from UCSC's Table Browser from the "cytoBandIdeo" table,
saved as "ideogram.txt". Lines look like this::
    #chrom  chromStart  chromEnd  name    gieStain
    chr1    0           2300000   p36.33  gneg
    chr1    2300000     5300000   p36.32  gpos25
    chr1    5300000     7100000   p36.31  gneg
2) Assumes another file, "ucsc_genes.txt", which is a BED format file
   downloaded from UCSC's Table Browser. This script will work with any
   BED-format file.
"""

from matplotlib import pyplot as plt
from matplotlib.collections import BrokenBarHCollection
import pandas
from matplotlib.lines import Line2D

# Here's the function that we'll call for each dataframe (once for chromosome
# ideograms, once for genes).  The rest of this script will be prepping data
# for input to this function
#
def chromosome_collections(df, y_positions, height, gene_mode=False, **kwargs):
    """
    Yields BrokenBarHCollection of features that can be added to an Axes
    object.
    Parameters
    ----------
    df : pandas.DataFrame
        Must at least have columns ['chrom', 'start', 'end', 'color']. If no
        column 'width', it will be calculated from start/end.
    y_positions : dict
        Keys are chromosomes, values are y-value at which to anchor the
        BrokenBarHCollection
    height : float
        Height of each BrokenBarHCollection
    Additional kwargs are passed to BrokenBarHCollection
    """
    del_width = False
    if 'width' not in df.columns:
        del_width = True
        df['width'] = df['end'] - df['start']
    for chrom, group in df.groupby('chrom'):
        print(chrom)
        yrange = (y_positions[chrom], height)
        xranges = group[['start', 'width']].values
        yield BrokenBarHCollection(
            xranges,
            yrange,
            facecolors=group['colors'],
            edgecolors='black' if not gene_mode else group['colors'],
            **kwargs)
    if del_width:
        del df['width']


# Height of each ideogram
chrom_height = 1

# Spacing between consecutive ideograms
chrom_spacing = 1

# Height of the gene track. Should be smaller than `chrom_spacing` in order to
# fit correctly
gene_height = 0.6

# Padding between the top of a gene track and its corresponding ideogram
gene_padding = 0.1

# Width, height (in inches)
figsize = (10, 14)

genes = pandas.read_table('../data/insertion_sites_1.txt',
                          names=['chrom', 'start', 'end', 'name'],
                          usecols=range(4),
                          low_memory=False)

# Decide which chromosomes to use
chromosome_list = [
    f'chr{i}' for i in list(range(1, 23)) + ['M', 'X', 'Y']
    if f'chr{i}' in genes['chrom'].unique()
]

# Keep track of the y positions for ideograms and genes for each chromosome,
# and the center of each ideogram (which is where we'll put the ytick labels)
ybase = 0
chrom_ybase = {}
gene_ybase = {}
chrom_centers = {}

# Iterate in reverse so that items in the beginning of `chromosome_list` will
# appear at the top of the plot
for chrom in chromosome_list[::-1]:
    chrom_ybase[chrom] = ybase
    chrom_centers[chrom] = ybase + chrom_height / 2.
    gene_ybase[chrom] = ybase - gene_height - gene_padding
    ybase += chrom_height + chrom_spacing

# Read in ideogram.txt, downloaded from UCSC Table Browser
ideo = pandas.read_table('ideogram.txt',
                         skiprows=1,
                         names=['chrom', 'start', 'end', 'name', 'gieStain'],
                         low_memory=False)

# Filter out chromosomes not in our list
ideo = ideo[ideo.chrom.apply(lambda x: x in chromosome_list)]

# Add a new column for width
ideo['width'] = ideo.end - ideo.start

# Colors for different chromosome stains
color_lookup = {
    'gneg': (1., 1., 1.),
    'gpos25': (.6, .6, .6),
    'gpos50': (.4, .4, .4),
    'gpos75': (.2, .2, .2),
    'gpos100': (0., 0., 0.),
    'acen': (.8, .4, .4),
    'gvar': (.8, .8, .8),
    'stalk': (.9, .9, .9),
}

# Add a new column for colors
ideo['colors'] = ideo['gieStain'].apply(lambda x: color_lookup[x])

# Same thing for genes

genes = genes[genes.chrom.apply(lambda x: x in chromosome_list)]
genes['width'] = genes.end - genes.start
genes_color_lookup = {
    'JFCF_6_T_1_C': sns.color_palette("tab20")[0],
    'JFCF_6_T_1_D': sns.color_palette("tab20")[1],
    'JFCF_6_T_1_F': sns.color_palette("tab20")[2],
    'JFCF_6_T_1_G': sns.color_palette("tab20")[3],
    'JFCF_6_T_1_H': sns.color_palette("tab20")[4],
    'JFCF_6_T_1_L': sns.color_palette("tab20")[5],
    'JFCF_6_T_1_M': sns.color_palette("tab20")[6],
    'JFCF_6_T_1_P_ALT': sns.color_palette("tab20")[7],
    'JFCF_6_T_1_P_TEL': sns.color_palette("tab20")[8],
    'JFCF_6_T_1_R': sns.color_palette("tab20")[9],
    'JFCF_6_T_1J_1_3C': sns.color_palette("tab20")[10],
    'JFCF_6_T_1J_11C': sns.color_palette("tab20")[11],
    'JFCF_6_T_1J_11E': sns.color_palette("tab20")[12],
    'JFCF_6_T_1J_6B': sns.color_palette("tab20")[13],
    'JFCF_6_T_5K': sns.color_palette("tab20")[14]
}
genes['colors'] = genes['name'].map(lambda x: genes_color_lookup[x]
                                    if x in genes_color_lookup else '#2243a8')

fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(111)

# Now all we have to do is call our function for the ideogram data...
print("adding ideograms...")
for collection in chromosome_collections(ideo, chrom_ybase, chrom_height):
    ax.add_collection(collection)

# ...and the gene data
print("adding genes...")
for collection in chromosome_collections(genes,
                                         gene_ybase,
                                         gene_height,
                                         gene_mode=True,
                                         alpha=0.9,
                                         linewidths=2):
    ax.add_collection(collection)

# Axes tweaking
ax.set_yticks([chrom_centers[i] for i in chromosome_list])
ax.set_yticklabels(chromosome_list)
ax.axis('tight')

def make_proxy(x, **kwargs):
    color = genes_color_lookup[x]
    return Line2D([0, 1], [0, 1], color=color, **kwargs)

proxies = [make_proxy(x, linewidth=2) for x in genes_color_lookup.keys()]

ax.legend(proxies, list(genes_color_lookup.keys()), loc='lower right')

plt.show()
# Out:
# /Users/scai/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:77: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# /Users/scai/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:104: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# adding ideograms...
# chr1
# chr12
# chr14
# chr2
# chr5
# chr6
# chr7
# adding genes...
# chr1
# chr12
# chr14
# chr2
# chr5
# chr6
# chr7
