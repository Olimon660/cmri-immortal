# %%
import pandas as pd
from glob import glob
import re
pd.options.display.max_columns = 100

# %%
def map_name(name):
    name = name.replace("-", "_") 
    if name == "IIICF":
        name = "IIICF_P7"
    if name == "IIICFE6E7C4post":
        name = "IIICF_E6E7_C4_post"
    if name == "IIICFE6E7C4pre":
        name = "IIICF_E6E7_C4_pre"
    if name == "IVG_BF_LXSNpost":
        name = "IVG_BF_LXSN_post"
    if name == "IVG_BF_LXSNpre":
        name = "IVG_BF_LXSN_pre"
    if name == "JFCF_6_T_1_P":
        name = "JFCF_6_T_1_P_TEL"
    if name == "JFCF_6_T_1_PALT":
        name = "JFCF_6_T_1_P_ALT"
    if name == "JFCF6_P12_H06L4ALXX_6":
        name = "JFCF_6"
    if name in ("JFCF6_T_1J_1_3C_H06L4ALXX_3", "JFCF6_T_1J_1_3C"):
        name = "JFCF_6_T_1J_1_3C"
    if name in ("JFCF6_T_1J_6B_H06L4ALXX_4", "JFCF6_T_1J_6B"):
        name = "JFCF_6_T_1J_6B"
    if name == "JFCF_61M":
        name = "JFCF_6_T_1_M"
    if name == "JFCF_61Q":
        name = "JFCF_6_T_1_Q"
    if name == "LFS05F24post":
        name = "LFS_05F_24_post"
    if name == "LFS05F24pre":
        name = "LFS_05F_24_pre"
    if name == "MeT_4Apost":
        name = "MeT_4A_post"
    if name == "MeT_4Apre":
        name = "MeT_4A_pre"
    return name

# %% [markdown]
# # combined annovar

# %%
df_list = []
for fp in glob(
        "/home/scai/processing_simoncai/tmm/tel_vs_alt/immortal_simon/annovar/somatic/*"
):
    name = fp.replace(
        "/home/scai/processing_simoncai/tmm/tel_vs_alt/immortal_simon/annovar/somatic/",
        "")
    sample = re.search(r"(JF.*)\.hg19_.*", name).group(1)
    df = pd.read_csv(fp, sep='\t')
    df['sample'] = sample
    df_list.append(df)
df_all = pd.concat(df_list)
df_all.to_csv(
    "/home/scai/processing_simoncai/tmm/tel_vs_alt/immortal_simon/annovar/combined_somatic.tsv",
    index=False,
    sep='\t')

# %%
df_all = pd.read_csv("/home/scai/processing_simoncai/tmm/tel_vs_alt/immortal_simon/annovar/combined.csv")

# %%
df_all.groupby(['Func.refGene']).size()
# Out:
# Func.refGene
# UTR3                    1256
# UTR5                     188
# downstream               852
# exonic                   940
# intergenic             83056
# intronic               47278
# ncRNA_exonic             600
# ncRNA_intronic          9924
# ncRNA_splicing             7
# splicing                  34
# upstream                 869
# upstream;downstream       28
# dtype: int64

# %%
df_filtered = df_all[~df_all['Func.refGene'].isin(['intronic','intergenic', 'ncRNA_intronic'])]

# %%
df_filtered.groupby(['sample']).size()
# Out:
# sample
# JFCF-6_T_1J_11C    157208
# JFCF-6_T_1J_11E    156174
# JFCF-6_T_1_C       159015
# JFCF-6_T_1_D       152700
# JFCF-6_T_1_F       154176
# JFCF-6_T_1_G       156104
# JFCF-6_T_1_H       157514
# JFCF-6_T_1_L       150344
# JFCF-6_T_1_P       159923
# JFCF-6_T_1_PALT    158496
# JFCF-6_T_1_R       154949
# JFCF-6_T_2H        156718
# JFCF-6_T_5K        157419
# JFCF-6_p15         162196
# JFCF6_T_1J_1-3C    153227
# JFCF6_T_1J_6B      153658
# JFCF_61M           142889
# JFCF_61Q           147341
# dtype: int64

# %%
df_all[df_all['Gene.refGene']=='ATRX']
# Out:
#        Chr     Start       End Ref Alt Func.refGene Gene.refGene  \
# 6352  chrX  76960038  76960038   C   T     intronic         ATRX
# 5965  chrX  76938581  76938581   C   A       exonic         ATRX
# 6654  chrX  76833467  76833467   G   A     intronic         ATRX
#
#      GeneDetail.refGene ExonicFunc.refGene  \
# 6352                  .                  .
# 5965                  .           stopgain
# 6654                  .                  .
#
#                                        AAChange.refGene  ... Otherinfo6  \
# 6352                                                  .  ...          .
# 5965  ATRX:NM_138270:exon8:c.G2053T:p.E685X,ATRX:NM_...  ...          .
# 6654                                                  .  ...          .
#
#      Otherinfo7 Otherinfo8 Otherinfo9 Otherinfo10  \
# 6352          C          T          .        PASS
# 5965          C          A          .        PASS
# 6654          G          A          .        PASS
#
#                                             Otherinfo11  \
# 6352  CONTQ=93;DP=35;ECNT=1;GERMQ=86;MBQ=37,41;MFRL=...
# 5965  CONTQ=93;DP=26;ECNT=1;GERMQ=28;MBQ=37,41;MFRL=...
# 6654  CONTQ=93;DP=44;ECNT=1;GERMQ=55;MBQ=37,35;MFRL=...
#
#                    Otherinfo12                           Otherinfo13  \
# 6352  GT:AD:AF:DP:F1R2:F2R1:SB    0/1:0,14:0.937:14:0,4:0,10:0,0,5,9
# 5965  GT:AD:AF:DP:F1R2:F2R1:SB      0/1:4,9:0.667:13:1,6:3,3:2,2,6,3
# 6654  GT:AD:AF:DP:F1R2:F2R1:SB  0/1:14,10:0.418:24:10,2:4,7:2,12,4,6
#
#                                Otherinfo14           sample
# 6352  0/0:21,0:0.045:21:8,0:13,0:11,10,0,0     JFCF-6_T_1_L
# 5965     0/0:13,0:0.067:13:7,0:6,0:9,4,0,0  JFCF-6_T_1_PALT
# 6654   0/0:20,0:0.045:20:12,0:8,0:9,11,0,0      JFCF-6_T_5K
#
# [3 rows x 69 columns]

# %%
df_filtered.to_csv(
    "/home/scai/processing_simoncai/tmm/tel_vs_alt/immortal_simon/annovar/annovar_germline_filtered.tsv", sep='\t',
    index=False)

# %% [markdown]
# # combine annovar and SV

# %%
mutect = pd.read_csv(
    "/home/scai/processing_simoncai/tmm/tel_vs_alt/immortal_simon/annovar/combined_somatic.tsv",
    sep='\t')
mutect_filtered = mutect[~mutect['Func.refGene'].isin(['intronic','intergenic', 'ncRNA_intronic'])]

# %%
mutect_filtered.head()
# Out:
#      Chr    Start      End Ref Alt  Func.refGene Gene.refGene  \
# 0   chrM      736      736   C   T  ncRNA_exonic         RNR1
# 1   chrM     2442     2442   G   A  ncRNA_exonic         RNR2
# 2   chrM     3088     3088   T   C  ncRNA_exonic         RNR2
# 8   chr1  1532854  1532854   G   C    downstream       FNDC10
# 11  chr1  2131783  2131783   G   A          UTR5       FAAP20
#
#          GeneDetail.refGene ExonicFunc.refGene AAChange.refGene cytoBand  \
# 0                         .                  .                .        .
# 1                         .                  .                .        .
# 2                         .                  .                .        .
# 8                  dist=538                  .                .  1p36.33
# 11  NM_001282670:c.-1356C>T                  .                .  1p36.33
#
#    ExAC_ALL ExAC_AFR ExAC_AMR ExAC_EAS ExAC_FIN ExAC_NFE ExAC_OTH ExAC_SAS  \
# 0         .        .        .        .        .        .        .        .
# 1         .        .        .        .        .        .        .        .
# 2         .        .        .        .        .        .        .        .
# 8         .        .        .        .        .        .        .        .
# 11        .        .        .        .        .        .        .        .
#
#    avsnp147 SIFT_score SIFT_pred Polyphen2_HDIV_score Polyphen2_HDIV_pred  \
# 0         .          .         .                    .                   .
# 1         .          .         .                    .                   .
# 2         .          .         .                    .                   .
# 8         .          .         .                    .                   .
# 11        .          .         .                    .                   .
#
#    Polyphen2_HVAR_score Polyphen2_HVAR_pred LRT_score LRT_pred  \
# 0                     .                   .         .        .
# 1                     .                   .         .        .
# 2                     .                   .         .        .
# 8                     .                   .         .        .
# 11                    .                   .         .        .
#
#    MutationTaster_score MutationTaster_pred MutationAssessor_score  \
# 0                     .                   .                      .
# 1                     .                   .                      .
# 2                     .                   .                      .
# 8                     .                   .                      .
# 11                    .                   .                      .
#
#    MutationAssessor_pred FATHMM_score FATHMM_pred PROVEAN_score PROVEAN_pred  \
# 0                      .            .           .             .            .
# 1                      .            .           .             .            .
# 2                      .            .           .             .            .
# 8                      .            .           .             .            .
# 11                     .            .           .             .            .
#
#    VEST3_score CADD_raw CADD_phred DANN_score fathmm-MKL_coding_score  \
# 0            .        .          .          .                       .
# 1            .        .          .          .                       .
# 2            .        .          .          .                       .
# 8            .        .          .          .                       .
# 11           .        .          .          .                       .
#
#    fathmm-MKL_coding_pred MetaSVM_score MetaSVM_pred MetaLR_score MetaLR_pred  \
# 0                       .             .            .            .           .
# 1                       .             .            .            .           .
# 2                       .             .            .            .           .
# 8                       .             .            .            .           .
# 11                      .             .            .            .           .
#
#    integrated_fitCons_score integrated_confidence_value GERP++_RS  \
# 0                         .                           .         .
# 1                         .                           .         .
# 2                         .                           .         .
# 8                         .                           .         .
# 11                        .                           .         .
#
#    phyloP7way_vertebrate phyloP20way_mammalian phastCons7way_vertebrate  \
# 0                      .                     .                        .
# 1                      .                     .                        .
# 2                      .                     .                        .
# 8                      .                     .                        .
# 11                     .                     .                        .
#
#    phastCons20way_mammalian SiPhy_29way_logOdds  Otherinfo1 Otherinfo2  \
# 0                         .                   .        0.25          .
# 1                         .                   .        0.25          .
# 2                         .                   .        0.25          .
# 8                         .                   .        0.25          .
# 11                        .                   .        0.25          .
#
#     Otherinfo3 Otherinfo4  Otherinfo5 Otherinfo6 Otherinfo7 Otherinfo8  \
# 0         3465       chrM         736          .          C          T
# 1         3290       chrM        2442          .          G          A
# 2         3347       chrM        3088          .          T          C
# 8            8       chr1     1532854          .          G          C
# 11          28       chr1     2131783          .          G          A
#
#    Otherinfo9 Otherinfo10                                        Otherinfo11  \
# 0           .        PASS  CONTQ=93;DP=7596;ECNT=1;GERMQ=93;MBQ=37,41;MFR...
# 1           .        PASS  CONTQ=93;DP=7680;ECNT=1;GERMQ=93;MBQ=37,41;MFR...
# 2           .        PASS  CONTQ=93;DP=7681;ECNT=1;GERMQ=93;MBQ=37,41;MFR...
# 8           .        PASS  CONTQ=93;DP=32;ECNT=1;GERMQ=22;MBQ=25,22;MFRL=...
# 11          .        PASS  CONTQ=93;DP=57;ECNT=1;GERMQ=79;MBQ=37,41;MFRL=...
#
#                  Otherinfo12  \
# 0   GT:AD:AF:DP:F1R2:F2R1:SB
# 1   GT:AD:AF:DP:F1R2:F2R1:SB
# 2   GT:AD:AF:DP:F1R2:F2R1:SB
# 8   GT:AD:AF:DP:F1R2:F2R1:SB
# 11  GT:AD:AF:DP:F1R2:F2R1:SB
#
#                                           Otherinfo13  \
# 0   0/1:3898,40:0.01:3938:1686,20:2189,19:2511,138...
# 1   0/1:4148,41:0.0093:4189:1861,16:2271,22:2223,1...
# 2   0/1:3953,183:0.044:4136:1922,88:1999,95:1931,2...
# 8                  0/1:4,18:0.792:22:1,5:2,6:0,4,10,8
# 11                0/1:16,12:0.433:28:8,6:8,6:10,6,7,5
#
#                                           Otherinfo14           sample
# 0   0/0:3465,0:0.0002864:3465:1236,0:2190,0:2182,1...  JFCF-6_T_1J_11C
# 1   0/0:3290,0:0.0003009:3290:1525,0:1729,0:1766,1...  JFCF-6_T_1J_11C
# 2   0/0:3347,0:0.0002958:3347:1579,0:1738,0:1636,1...  JFCF-6_T_1J_11C
# 8                       0/0:8,0:0.1:8:3,0:2,0:0,8,0,0  JFCF-6_T_1J_11C
# 11              0/0:28,0:0.033:28:13,0:15,0:11,17,0,0  JFCF-6_T_1J_11C

# %%
mutect_filtered = mutect_filtered.rename(
    columns={
        'sample': 'Name',
        'Gene.refGene': 'Gene',
        'Func.refGene': 'Type',
        'Chr': 'Chr1',
        'Start': 'Pos1',
        'Ref': 'Ref1',
        'Alt': 'Alt1'
    })

# %%
mutect_filtered['Source'] = 'MuTect2'
mutect_filtered['Key'] = mutect_filtered.apply(
    lambda row:
    f"MuTect2_{row['Type']}_{row['Gene']}_{row['Name']}_{row['Chr1']}_{row['Pos1']}_{row['Ref1']}_{row['Alt1']}",
    axis=1)

# %%
cols = ['Key', 'Name', 'Source']
cols = cols + [x for x in mutect_filtered.columns if 'Other' not in x and x not in cols]
cols.remove('End')

# %%
mutect_filtered = mutect_filtered[cols]

# %%
mutect_filtered['Name'] = mutect_filtered['Name'].map(lambda x:map_name(x))
# Out:
# /home/scai/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
mutect_filtered.head()
# Out:
#                                                   Key             Name  \
# 0   MuTect2_ncRNA_exonic_RNR1_JFCF-6_T_1J_11C_chrM...  JFCF-6_T_1J_11C
# 1   MuTect2_ncRNA_exonic_RNR2_JFCF-6_T_1J_11C_chrM...  JFCF-6_T_1J_11C
# 2   MuTect2_ncRNA_exonic_RNR2_JFCF-6_T_1J_11C_chrM...  JFCF-6_T_1J_11C
# 8   MuTect2_downstream_FNDC10_JFCF-6_T_1J_11C_chr1...  JFCF-6_T_1J_11C
# 11  MuTect2_UTR5_FAAP20_JFCF-6_T_1J_11C_chr1_21317...  JFCF-6_T_1J_11C
#
#      Source  Chr1     Pos1 Ref1 Alt1          Type    Gene  \
# 0   MuTect2  chrM      736    C    T  ncRNA_exonic    RNR1
# 1   MuTect2  chrM     2442    G    A  ncRNA_exonic    RNR2
# 2   MuTect2  chrM     3088    T    C  ncRNA_exonic    RNR2
# 8   MuTect2  chr1  1532854    G    C    downstream  FNDC10
# 11  MuTect2  chr1  2131783    G    A          UTR5  FAAP20
#
#          GeneDetail.refGene ExonicFunc.refGene AAChange.refGene cytoBand  \
# 0                         .                  .                .        .
# 1                         .                  .                .        .
# 2                         .                  .                .        .
# 8                  dist=538                  .                .  1p36.33
# 11  NM_001282670:c.-1356C>T                  .                .  1p36.33
#
#    ExAC_ALL ExAC_AFR ExAC_AMR ExAC_EAS ExAC_FIN ExAC_NFE ExAC_OTH ExAC_SAS  \
# 0         .        .        .        .        .        .        .        .
# 1         .        .        .        .        .        .        .        .
# 2         .        .        .        .        .        .        .        .
# 8         .        .        .        .        .        .        .        .
# 11        .        .        .        .        .        .        .        .
#
#    avsnp147 SIFT_score SIFT_pred Polyphen2_HDIV_score Polyphen2_HDIV_pred  \
# 0         .          .         .                    .                   .
# 1         .          .         .                    .                   .
# 2         .          .         .                    .                   .
# 8         .          .         .                    .                   .
# 11        .          .         .                    .                   .
#
#    Polyphen2_HVAR_score Polyphen2_HVAR_pred LRT_score LRT_pred  \
# 0                     .                   .         .        .
# 1                     .                   .         .        .
# 2                     .                   .         .        .
# 8                     .                   .         .        .
# 11                    .                   .         .        .
#
#    MutationTaster_score MutationTaster_pred MutationAssessor_score  \
# 0                     .                   .                      .
# 1                     .                   .                      .
# 2                     .                   .                      .
# 8                     .                   .                      .
# 11                    .                   .                      .
#
#    MutationAssessor_pred FATHMM_score FATHMM_pred PROVEAN_score PROVEAN_pred  \
# 0                      .            .           .             .            .
# 1                      .            .           .             .            .
# 2                      .            .           .             .            .
# 8                      .            .           .             .            .
# 11                     .            .           .             .            .
#
#    VEST3_score CADD_raw CADD_phred DANN_score fathmm-MKL_coding_score  \
# 0            .        .          .          .                       .
# 1            .        .          .          .                       .
# 2            .        .          .          .                       .
# 8            .        .          .          .                       .
# 11           .        .          .          .                       .
#
#    fathmm-MKL_coding_pred MetaSVM_score MetaSVM_pred MetaLR_score MetaLR_pred  \
# 0                       .             .            .            .           .
# 1                       .             .            .            .           .
# 2                       .             .            .            .           .
# 8                       .             .            .            .           .
# 11                      .             .            .            .           .
#
#    integrated_fitCons_score integrated_confidence_value GERP++_RS  \
# 0                         .                           .         .
# 1                         .                           .         .
# 2                         .                           .         .
# 8                         .                           .         .
# 11                        .                           .         .
#
#    phyloP7way_vertebrate phyloP20way_mammalian phastCons7way_vertebrate  \
# 0                      .                     .                        .
# 1                      .                     .                        .
# 2                      .                     .                        .
# 8                      .                     .                        .
# 11                     .                     .                        .
#
#    phastCons20way_mammalian SiPhy_29way_logOdds
# 0                         .                   .
# 1                         .                   .
# 2                         .                   .
# 8                         .                   .
# 11                        .                   .

# %%
sv_df = pd.read_csv("../immortal_simon/gridss/DATA_GRIDSS.tsv", sep="\t").drop_duplicates()

# %%
sv_df.head()
# Out:
#                                                  Key          Name  Source  \
# 0  SV_GRIDSS_HIGH_RNR2_Mortal_chrM_2553_2554_chr8...        JFCF_6  GRIDSS
# 1  SV_GRIDSS_LOW_NULL_Mortal_chrM_2553_2554_chr8_...        JFCF_6  GRIDSS
# 2  SV_GRIDSS_HIGH_RNR2_Immortal_chrM_2553_2554_ch...  JFCF_6_T_1_M  GRIDSS
# 3  SV_GRIDSS_LOW_NULL_Immortal_chrM_2553_2554_chr...  JFCF_6_T_1_M  GRIDSS
# 4  SV_GRIDSS_HIGH_CBWD1_Mortal_chrM_6420_6421_chr...        JFCF_6  GRIDSS
#
#    dbSNP            Type  Chr1       Pos1  Chr2               Pos2  \
# 0  False  Translocations  chrM  2553-2554  chr8  24130087-24130088
# 1  False  Translocations  chrM  2553-2554  chr8  24130087-24130088
# 2  False  Translocations  chrM  2553-2554  chr8  24130087-24130088
# 3  False  Translocations  chrM  2553-2554  chr8  24130087-24130088
# 4  False  Translocations  chrM  6420-6421  chr9      129766-129767
#
#                           Qual1                         Qual2  AF1  AF2  \
# 0   NotSplit:216.24;Split:43.18   NotSplit:216.24;Split:43.18  NaN  NaN
# 1   NotSplit:216.24;Split:43.18   NotSplit:216.24;Split:43.18  NaN  NaN
# 2   NotSplit:216.24;Split:43.18   NotSplit:216.24;Split:43.18  NaN  NaN
# 3   NotSplit:216.24;Split:43.18   NotSplit:216.24;Split:43.18  NaN  NaN
# 4  NotSplit:139.36;Split:252.41  NotSplit:139.36;Split:252.41  NaN  NaN
#
#                  Read1                Read2   Gene          Consequence  \
# 0  NotSplit:13;Split:2  NotSplit:13;Split:2   RNR2  transcript_ablation
# 1  NotSplit:13;Split:2  NotSplit:13;Split:2    NaN       feature_fusion
# 2  NotSplit:13;Split:2  NotSplit:13;Split:2   RNR2  transcript_ablation
# 3  NotSplit:13;Split:2  NotSplit:13;Split:2    NaN       feature_fusion
# 4  NotSplit:8;Split:11  NotSplit:8;Split:11  CBWD1  transcript_ablation
#
#   Impact Ref1                    Alt1 Ref2                  Alt2
# 0   HIGH    T        T[CHR8:24130088[    T          ]CHRM:2554]T
# 1    LOW    T        T[CHR8:24130088[    T          ]CHRM:2554]T
# 2   HIGH    T        T[CHR8:24130088[    T          ]CHRM:2554]T
# 3    LOW    T        T[CHR8:24130088[    T          ]CHRM:2554]T
# 4   HIGH    C  CAAAAAAAA]CHR9:129767]    A  ATTTTTTTT]CHRM:6421]

# %%
sv_df['lower'] = sv_df['Pos1'].map(lambda x:min(int(x.split('-')[0]),int(x.split('-')[1])))
sv_df['upper'] = sv_df['Pos2'].map(lambda x:max(int(x.split('-')[0]),int(x.split('-')[1])))

# %%
sv_df['lower'] = sv_df.apply(lambda row:min(int(row['Pos1'].split('-')[0]),int(row['Pos2'].split('-')[0])),axis=1)
sv_df['upper'] = sv_df.apply(lambda row:max(int(row['Pos1'].split('-')[1]),int(row['Pos2'].split('-')[1])),axis=1)

# %%
sv_df_same_chrom = sv_df[sv_df['Chr1']==sv_df['Chr2']]

# %%
sv_df_same_chrom = sv_df_same_chrom.reset_index(drop=True)

# %%
sv_df_bed = sv_df_same_chrom[['Chr1', 'lower', 'upper', 'Key']]

# %%
sv_df_bed['strand'] = '.'
# Out:
# /home/scai/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sv_df_bed.to_csv("../immortal_simon/gridss/sv_df.bed", index=False, header=False, sep='\t')

# %%
sv_df_bed_exon = pd.read_csv(
    "../immortal_simon/gridss/sv_exon_counts.bed",
    sep='\t',
    names=['chr', 'start', 'end', 'key_bed', 'strand', 'exon_count'])

# %%
sv_df_same_chrom_exon = pd.concat([sv_df_same_chrom, sv_df_bed_exon], axis=1, sort=False)

# %%
sv_df_same_chrom_exon = sv_df_same_chrom_exon.drop(['chr', 'start', 'end', 'key_bed', 'strand'],axis=1)

# %%
sv_df_same_chrom_exon = sv_df_same_chrom_exon[sv_df_same_chrom_exon['exon_count'] > 0].reset_index(drop=True)

# %%
sv_df_exon = pd.concat([sv_df[sv_df['Chr1']!=sv_df['Chr2']].reset_index(drop=True), sv_df_same_chrom_exon], sort=False)

# %%
sv_df_exon.to_csv("../immortal_simon/gridss/DATA_GRIDSS_Exon.tsv", sep="\t", index=False)

# %%
combined = pd.concat([sv_df_exon, mutect_filtered], ignore_index=True, sort=False)

# %%
combined.tail()
# Out:
#                                                      Key          Name  \
# 50490  MuTect2_UTR3_SHROOM4_JFCF_61Q_chrX_50336329_CC_TT  JFCF_6_T_1_Q
# 50491   MuTect2_UTR3_AMMECR1_JFCF_61Q_chrX_109441214_T_G  JFCF_6_T_1_Q
# 50492  MuTect2_exonic_SLC25A5_JFCF_61Q_chrX_118603644...  JFCF_6_T_1_Q
# 50493  MuTect2_ncRNA_exonic_LINC00894_JFCF_61Q_chrX_1...  JFCF_6_T_1_Q
# 50494  MuTect2_downstream_TTTY11_JFCF_61Q_chrY_865086...  JFCF_6_T_1_Q
#
#         Source dbSNP          Type  Chr1       Pos1 Chr2 Pos2 Qual1 Qual2  \
# 50490  MuTect2   NaN          UTR3  chrX   50336329  NaN  NaN   NaN   NaN
# 50491  MuTect2   NaN          UTR3  chrX  109441214  NaN  NaN   NaN   NaN
# 50492  MuTect2   NaN        exonic  chrX  118603644  NaN  NaN   NaN   NaN
# 50493  MuTect2   NaN  ncRNA_exonic  chrX  149115253  NaN  NaN   NaN   NaN
# 50494  MuTect2   NaN    downstream  chrY    8650868  NaN  NaN   NaN   NaN
#
#        AF1  AF2 Read1 Read2       Gene Consequence Impact Ref1 Alt1 Ref2 Alt2  \
# 50490  NaN  NaN   NaN   NaN    SHROOM4         NaN    NaN   CC   TT  NaN  NaN
# 50491  NaN  NaN   NaN   NaN    AMMECR1         NaN    NaN    T    G  NaN  NaN
# 50492  NaN  NaN   NaN   NaN    SLC25A5         NaN    NaN    G    T  NaN  NaN
# 50493  NaN  NaN   NaN   NaN  LINC00894         NaN    NaN    C    T  NaN  NaN
# 50494  NaN  NaN   NaN   NaN     TTTY11         NaN    NaN    C    A  NaN  NaN
#
#        lower  upper  exon_count  \
# 50490    NaN    NaN         NaN
# 50491    NaN    NaN         NaN
# 50492    NaN    NaN         NaN
# 50493    NaN    NaN         NaN
# 50494    NaN    NaN         NaN
#
#                                       GeneDetail.refGene ExonicFunc.refGene  \
# 50490                    NM_020717:c.*3366_*3365delinsAA                  .
# 50491  NM_001025580:c.*534A>C;NM_001171689:c.*534A>C;...                  .
# 50492                                                  .  nonsynonymous SNV
# 50493                                                  .                  .
# 50494                                           dist=488                  .
#
#                              AAChange.refGene cytoBand   ExAC_ALL ExAC_AFR  \
# 50490                                       .  Xp11.22          .        .
# 50491                                       .     Xq23          .        .
# 50492  SLC25A5:NM_001152:exon2:c.G132T:p.Q44H     Xq24  8.568e-05   0.0005
# 50493                                       .     Xq28          .        .
# 50494                                       .   Yp11.2          .        .
#
#       ExAC_AMR ExAC_EAS ExAC_FIN   ExAC_NFE ExAC_OTH ExAC_SAS     avsnp147  \
# 50490        .        .        .          .        .        .            .
# 50491        .        .        .          .        .        .            .
# 50492        0        0        0  4.323e-05        0   0.0002  rs200353173
# 50493        .        .        .          .        .        .  rs369641170
# 50494        .        .        .          .        .        .            .
#
#       SIFT_score SIFT_pred Polyphen2_HDIV_score Polyphen2_HDIV_pred  \
# 50490          .         .                    .                   .
# 50491          .         .                    .                   .
# 50492      0.017         D                0.133                   B
# 50493          .         .                    .                   .
# 50494          .         .                    .                   .
#
#       Polyphen2_HVAR_score Polyphen2_HVAR_pred LRT_score LRT_pred  \
# 50490                    .                   .         .        .
# 50491                    .                   .         .        .
# 50492                0.083                   B     0.000        D
# 50493                    .                   .         .        .
# 50494                    .                   .         .        .
#
#       MutationTaster_score MutationTaster_pred MutationAssessor_score  \
# 50490                    .                   .                      .
# 50491                    .                   .                      .
# 50492                1.000                   D                  2.825
# 50493                    .                   .                      .
# 50494                    .                   .                      .
#
#       MutationAssessor_pred FATHMM_score FATHMM_pred PROVEAN_score  \
# 50490                     .            .           .             .
# 50491                     .            .           .             .
# 50492                     M        -1.29           T         -2.89
# 50493                     .            .           .             .
# 50494                     .            .           .             .
#
#       PROVEAN_pred VEST3_score CADD_raw CADD_phred DANN_score  \
# 50490            .           .        .          .          .
# 50491            .           .        .          .          .
# 50492            D       0.416    2.390      18.76      0.979
# 50493            .           .        .          .          .
# 50494            .           .        .          .          .
#
#       fathmm-MKL_coding_score fathmm-MKL_coding_pred MetaSVM_score  \
# 50490                       .                      .             .
# 50491                       .                      .             .
# 50492                   0.939                      D        -0.355
# 50493                       .                      .             .
# 50494                       .                      .             .
#
#       MetaSVM_pred MetaLR_score MetaLR_pred integrated_fitCons_score  \
# 50490            .            .           .                        .
# 50491            .            .           .                        .
# 50492            T        0.451           T                        .
# 50493            .            .           .                        .
# 50494            .            .           .                        .
#
#       integrated_confidence_value GERP++_RS phyloP7way_vertebrate  \
# 50490                           .         .                     .
# 50491                           .         .                     .
# 50492                           .     0.646                -0.327
# 50493                           .         .                     .
# 50494                           .         .                     .
#
#       phyloP20way_mammalian phastCons7way_vertebrate phastCons20way_mammalian  \
# 50490                     .                        .                        .
# 50491                     .                        .                        .
# 50492                -0.165                    0.995                    0.977
# 50493                     .                        .                        .
# 50494                     .                        .                        .
#
#       SiPhy_29way_logOdds
# 50490                   .
# 50491                   .
# 50492               7.212
# 50493                   .
# 50494                   .

# %%
combined.shape
# Out:
# (50495, 72)

# %%
combined.to_csv(
    "/home/scai/processing_simoncai/tmm/tel_vs_alt/immortal_simon/annovar/annovar_mutect_gridss.tsv", sep='\t',
    index=False)

# %%
combined['Name'].unique()
# Out:
# array(['JFCF_6', 'JFCF_6_T_1_M', 'JFCF_6_T_1_Q', 'JFCF_6_T_1_C',
#        'JFCF_6_T_1_D', 'JFCF_6_T_1_F', 'JFCF_6_T_1_G', 'JFCF_6_T_1_H',
#        'JFCF_6_T_1J_11C', 'JFCF_6_T_1J_11E', 'JFCF_6_T_1J_1_3C',
#        'JFCF_6_T_1J_6B', 'JFCF_6_T_1_L', 'JFCF_6_T_1_P_ALT',
#        'JFCF_6_T_1_P_TEL', 'JFCF_6_T_1_R', 'JFCF_6_T_2H', 'JFCF_6_T_5K'],
#       dtype=object)

# %%
combined[combined['Gene']=='ATRX']
# Out:
#                                                      Key              Name  \
# 47963  MuTect2_exonic_ATRX_JFCF-6_T_1_PALT_chrX_76938...  JFCF_6_T_1_P_ALT
#
#         Source dbSNP    Type  Chr1      Pos1 Chr2 Pos2 Qual1 Qual2  AF1  AF2  \
# 47963  MuTect2   NaN  exonic  chrX  76938581  NaN  NaN   NaN   NaN  NaN  NaN
#
#       Read1 Read2  Gene Consequence Impact Ref1 Alt1 Ref2 Alt2  lower  upper  \
# 47963   NaN   NaN  ATRX         NaN    NaN    C    A  NaN  NaN    NaN    NaN
#
#        exon_count GeneDetail.refGene ExonicFunc.refGene  \
# 47963         NaN                  .           stopgain
#
#                                         AAChange.refGene cytoBand ExAC_ALL  \
# 47963  ATRX:NM_138270:exon8:c.G2053T:p.E685X,ATRX:NM_...   Xq21.1        .
#
#       ExAC_AFR ExAC_AMR ExAC_EAS ExAC_FIN ExAC_NFE ExAC_OTH ExAC_SAS avsnp147  \
# 47963        .        .        .        .        .        .        .        .
#
#       SIFT_score SIFT_pred Polyphen2_HDIV_score Polyphen2_HDIV_pred  \
# 47963          .         .                    .                   .
#
#       Polyphen2_HVAR_score Polyphen2_HVAR_pred LRT_score LRT_pred  \
# 47963                    .                   .     0.398        N
#
#       MutationTaster_score MutationTaster_pred MutationAssessor_score  \
# 47963                    1                   A                      .
#
#       MutationAssessor_pred FATHMM_score FATHMM_pred PROVEAN_score  \
# 47963                     .            .           .             .
#
#       PROVEAN_pred VEST3_score CADD_raw CADD_phred DANN_score  \
# 47963            .           .   10.238         36      0.997
#
#       fathmm-MKL_coding_score fathmm-MKL_coding_pred MetaSVM_score  \
# 47963                   0.679                      D             .
#
#       MetaSVM_pred MetaLR_score MetaLR_pred integrated_fitCons_score  \
# 47963            .            .           .                        .
#
#       integrated_confidence_value GERP++_RS phyloP7way_vertebrate  \
# 47963                           .      5.74                 0.871
#
#       phyloP20way_mammalian phastCons7way_vertebrate phastCons20way_mammalian  \
# 47963                 0.935                    0.845                    0.998
#
#       SiPhy_29way_logOdds
# 47963              11.023

# %%
sv_somatic = sv_df[(sv_df['Key'].str.contains('Somatic'))]

# %%
sv_somatic[sv_somatic['Gene']=='ZNF680']
# Out:
#                                                       Key              Name  \
# 782599  SV_GRIDSS_HIGH_ZNF680_Somatic_chr7_64008217_64...  JFCF_6_T_1J_1_3C
#
#         Source  dbSNP       Type  Chr1               Pos1  Chr2  \
# 782599  GRIDSS  False  Inversion  chr7  64008217-64008222  chr7
#
#                      Pos2                         Qual1  \
# 782599  64010216-64010221  NotSplit:397.99;Split:399.09
#
#                                Qual2  AF1  AF2                 Read1  \
# 782599  NotSplit:397.99;Split:399.09  NaN  NaN  NotSplit:22;Split:16
#
#                        Read2    Gene                Consequence Impact Ref1  \
# 782599  NotSplit:22;Split:16  ZNF680  bidirectional_gene_fusion   HIGH    C
#
#                     Alt1 Ref2              Alt2
# 782599  C]CHR7:64010219]    G  G]CHR7:64008220]

# %%
sv_df.groupby(['Type']).size()
# Out:
# Type
# Deletion          720871
# Duplication        31508
# Insertion         579477
# Inversion           8133
# Translocations     13228
# dtype: int64

# %%
sv_mortal = sv_df[sv_df['Name']=='JFCF_6'].drop_duplicates(['Key'])

# %%
sv_mortal = sv_mortal[sv_mortal['Impact']=='HIGH']

# %%
sv_mortal.shape
# Out:
# (43107, 22)

# %%
sv_mortal.groupby(['Type']).size()
# Out:
# Type
# Deletion          22848
# Duplication         852
# Insertion         18841
# Inversion           139
# Translocations      427
# dtype: int64

# %%
sv_mortal[sv_mortal['Read1']=='NotSplit:0;Split:0'].shape
# Out:
# (36591, 22)

# %%
sv_mortal[sv_mortal['Read1']=='NotSplit:0;Split:0'].groupby(['Consequence']).size()
# Out:
# Consequence
# bidirectional_gene_fusion           757
# gene_fusion                       31015
# gene_fusion&frameshift_variant     4812
# transcript_ablation                   7
# dtype: int64
