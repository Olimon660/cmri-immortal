# %%
import pandas as pd

# %%
ALL = pd.read_csv('./Raw_MuTect2_ALL.csv', sep='\t')
ALL['Pos1'] = ALL['Pos1'].astype(float)

# %%
ALL.shape
# Out:
# (843952, 22)

# %%
sample_list = [
    'IIICF_E6E7_A1', 'IIICF_T_C3', 'IIICF_d2', 'IIICF_E6_A1', 'IIICF_402DE_D2',
    'IIICF_E6E7_C4_post', 'MeT_4A_post', 'LFS_05F_24_post'
]

# %%
sample_map = {
    'IIICF_E6E7_A1':'U_IIICF_E6E7_A1',
    'IIICF_T_C3':'U_IIICF_T_C3',
    'IIICF_d2':'U_IIICF_d2',
    'IIICF_E6_A1':'U_IIICF_E6_A1',
    'IIICF_402DE_D2':'N_IIICF_402DE_D2',
    'IIICF_E6E7_C4_post':'N_IIICF_E6E7_C4_post',
    'MeT_4A_post':'N_MeT_4A_post',
    'LFS_05F_24_post':'N_LFS_05F_24_post',
}

# %%
ALL = ALL[ALL['Name'].isin(sample_list)]
ALL['Name'] = ALL['Name'].map(lambda x:sample_map[x])

# %% [markdown]
# # MODERATE

# %% [markdown]
# ## TF<sub>ATRX</sub> analysis

# %% [markdown]
# ### p=0.00005

# %%
gene_list = [
    'ASCL1', 'ATF6', 'EGR1', 'ESRRA', 'FOXS1', 'GLI1', 'HAND1', 'HESX1',
    'HOXA2', 'HOXA9', 'HOXD8', 'HSFX1', 'KLF8', 'MYBL1', 'MYOD1', 'SOX7',
    'TBX19', 'TCF7L1', 'THRB', 'ZBTB6', 'ZNF213', 'ZNF280A', 'ZNF287',
    'ZNF561', 'ZNF562', 'ZNF582'
]
gene_set = pd.read_csv(
    '../../bitbucket/CNA/data/ref_data/EnsemblGRCh37Genes.tsv', sep='\t')
p5 = gene_set[gene_set['GeneName'].isin(gene_list)].reset_index(drop=True)

# %%
df_list = []
for i in range(p5.shape[0]):
    start = float(p5.iloc[i, 3])
    end = float(p5.iloc[i, 4])
    chromosome = 'chr' + str(p5.iloc[i, 2])
    print('checking:', p5.iloc[i, 1], chromosome + ', ', start, end)
    data = ALL[ALL['Chr1'] == chromosome]
    df = data[(start <= data['Pos1']) & (data['Pos1'] <= end)]
    df['Gene_fromScript'] = p5.iloc[i, 1]
    df_list.append(df)
df_combined = pd.concat(df_list)
# Out:
# checking: ZNF213 chr16,  3179778.0 3192806.0
# checking: ZNF561 chr19,  9715356.0 9732075.0
# checking: ZNF562 chr19,  9759330.0 9785776.0
# checking: SOX7 chr8,  10581278.0 10697357.0
# checking: ZNF287 chr17,  16454701.0 16472520.0
# checking: MYOD1 chr11,  17741115.0 17743678.0
# checking: ZNF280A chr22,  22868060.0 22874613.0
# checking: THRB chr3,  24158651.0 24536773.0
# checking: HOXA2 chr7,  27139721.0 27142430.0
# checking: HOXA9 chr7,  27202054.0 27210117.0
# checking: FOXS1 chr20,  30432103.0 30433420.0
# /Users/scai/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# checking: KLF8 chrX,  56258854.0 56314322.0
# checking: ZNF582 chr19,  56887413.0 56904914.0
# checking: HESX1 chr3,  57231944.0 57260549.0
# checking: GLI1 chr12,  57853918.0 57866045.0
# checking: ESRRA chr11,  64073044.0 64084215.0
# checking: MYBL1 chr8,  67474410.0 67526482.0
# checking: TCF7L1 chr2,  85360533.0 85537511.0
# checking: ASCL1 chr12,  103351464.0 103354294.0
# checking: ZBTB6 chr9,  125670335.0 125675609.0
# checking: EGR1 chr5,  137801179.0 137805004.0
# checking: HSFX1 chrX,  148855726.0 148858525.0
# checking: HAND1 chr5,  153854532.0 153857824.0
# checking: ATF6 chr1,  161736084.0 161933860.0
# checking: TBX19 chr1,  168250278.0 168283664.0
# checking: HOXD8 chr2,  176994422.0 176997423.0

# %%
df_combined = df_combined.sort_values(by=['Name']).reset_index(drop=True)
df_combined['Pos1'] = df_combined['Pos1'].astype(str)
df_combined
# Out:
#                                                   Key                  Name  \
# 0       SNP_MuTect2_MODIFIER_TCF7L1_chr2_85494511_A_G      N_IIICF_402DE_D2
# 1        IND_MuTect2_MODIFIER_THRB_chr3_24363123_AT_A      N_IIICF_402DE_D2
# 2   IND_MuTect2_MODIFIER_THRB_chr3_24194460_AAAAAG...      N_IIICF_402DE_D2
# 3        SNP_MuTect2_MODIFIER_PINX1_chr8_10665419_G_C  N_IIICF_E6E7_C4_post
# 4        SNP_MuTect2_MODIFIER_PINX1_chr8_10665419_G_C  N_IIICF_E6E7_C4_post
# 5         SNP_MuTect2_MODIFIER_SOX7_chr8_10665419_G_C  N_IIICF_E6E7_C4_post
# 6       SNP_MuTect2_MODIFIER_SOX7.1_chr8_10665419_G_C  N_IIICF_E6E7_C4_post
# 7       SNP_MuTect2_MODIFIER_TCF7L1_chr2_85445790_C_A  N_IIICF_E6E7_C4_post
# 8        SNP_MuTect2_MODIFIER_MYBL1_chr8_67499604_C_A  N_IIICF_E6E7_C4_post
# 9   IND_MuTect2_MODIFIER_RP1-77H15.1_chr17_1646328...  N_IIICF_E6E7_C4_post
# 10  IND_MuTect2_MODIFIER_ZNF287_chr17_16463282_TCT...  N_IIICF_E6E7_C4_post
# 11  IND_MuTect2_MODIFIER_ZNF287_chr17_16463282_TCT...  N_IIICF_E6E7_C4_post
# 12        SNP_MuTect2_MODIFIER_THRB_chr3_24517953_T_A     N_LFS_05F_24_post
# 13        SNP_MuTect2_MODIFIER_THRB_chr3_24507667_C_T     N_LFS_05F_24_post
# 14  IND_MuTect2_MODIFIER_ATF6_chr1_161790730_TAAAT...     N_LFS_05F_24_post
# 15     IND_MuTect2_MODIFIER_THRB_chr3_24432275_TAAA_T         N_MeT_4A_post
# 16   IND_MuTect2_MODIFIER_ATF6_chr1_161744196_TACAC_T         N_MeT_4A_post
# 17  SNP_MuTect2_MODIFIER_CTD-2135J3.3_chr8_1058690...         N_MeT_4A_post
# 18  SNP_MuTect2_MODIFIER_CTD-2135J3.3_chr8_1058690...         N_MeT_4A_post
# 19      SNP_MuTect2_MODIFIER_SOX7.1_chr8_10586901_C_A         N_MeT_4A_post
# 50       SNP_MuTect2_MODIFIER_ATF6_chr1_161802825_T_C            U_IIICF_d2
# 51  IND_MuTect2_MODIFIER_THRB_chr3_24194460_AAAAAG...            U_IIICF_d2
# 52      SNP_MuTect2_MODIFIER_SOX7.1_chr8_10643191_C_T            U_IIICF_d2
# 53        SNP_MuTect2_MODIFIER_SOX7_chr8_10643191_C_T            U_IIICF_d2
# 54   IND_MuTect2_MODIFIER_TCF7L1_chr2_85461254_CTTT_C            U_IIICF_d2
# 55      SNP_MuTect2_MODIFIER_TCF7L1_chr2_85392764_C_G            U_IIICF_d2
# 56      SNP_MuTect2_MODIFIER_TCF7L1_chr2_85392764_C_G            U_IIICF_d2
# 57       SNP_MuTect2_MODIFIER_PINX1_chr8_10643191_C_T            U_IIICF_d2
# 58       SNP_MuTect2_MODIFIER_PINX1_chr8_10643191_C_T            U_IIICF_d2
# 59       SNP_MuTect2_MODIFIER_PINX1_chr8_10643191_C_T            U_IIICF_d2
# 60    IND_MuTect2_MODIFIER_TCF7L1_chr2_85467083_AAC_A            U_IIICF_d2
# 61  SNP_MuTect2_MODIFIER_SNORD112.6_chr8_10643191_C_T            U_IIICF_d2
#
#      Source  dbSNP Type   Chr1         Pos1  Chr2  Pos2         Qual1  \
# 0   MuTect2  False  SNP   chr2   85494511.0   NaN   NaN  2.32:-0.9477
# 1   MuTect2  False  IND   chr3   24363123.0   NaN   NaN    6.9:-1.402
# 2   MuTect2  False  IND   chr3   24194460.0   NaN   NaN   4.83:-1.262
# 3   MuTect2  False  SNP   chr8   10665419.0   NaN   NaN   7.83:-1.431
# 4   MuTect2  False  SNP   chr8   10665419.0   NaN   NaN   7.83:-1.431
# 5   MuTect2  False  SNP   chr8   10665419.0   NaN   NaN   7.83:-1.431
# 6   MuTect2  False  SNP   chr8   10665419.0   NaN   NaN   7.83:-1.431
# 7   MuTect2  False  SNP   chr2   85445790.0   NaN   NaN    6.92:-1.38
# 8   MuTect2  False  SNP   chr8   67499604.0   NaN   NaN   3.31:-1.079
# 9   MuTect2  False  IND  chr17   16463282.0   NaN   NaN  5.32:-0.5887
# 10  MuTect2  False  IND  chr17   16463282.0   NaN   NaN  5.32:-0.5887
# 11  MuTect2  False  IND  chr17   16463282.0   NaN   NaN  5.32:-0.5887
# 12  MuTect2  False  SNP   chr3   24517953.0   NaN   NaN    8.98:-1.49
# 13  MuTect2  False  SNP   chr3   24507667.0   NaN   NaN    6.5:-1.332
# 14  MuTect2  False  IND   chr1  161790730.0   NaN   NaN   3.56:-1.137
# 15  MuTect2  False  IND   chr3   24432275.0   NaN   NaN  2.22:-0.7158
# 16  MuTect2  False  IND   chr1  161744196.0   NaN   NaN    2.69:-1.04
# 17  MuTect2  False  SNP   chr8   10586901.0   NaN   NaN   6.02:-1.322
# 18  MuTect2  False  SNP   chr8   10586901.0   NaN   NaN   6.02:-1.322
# 19  MuTect2  False  SNP   chr8   10586901.0   NaN   NaN   6.02:-1.322
MuTect2  False  SNP   chr8   10643191.0   NaN   NaN   5.72:-1.319
#
#          ...          Read1     Read2          Gene  \
# 0        ...         [8, 0]   [39, 5]        TCF7L1
# 1        ...        [23, 0]  [16, 15]          THRB
# 2        ...        [16, 0]   [12, 4]          THRB
# 3        ...        [5, 21]   [26, 0]         PINX1
# 4        ...        [5, 21]   [26, 0]         PINX1
# 5        ...        [5, 21]   [26, 0]          SOX7
# 6        ...        [5, 21]   [26, 0]        SOX7.1
# 7        ...        [13, 5]   [23, 0]        TCF7L1
# 8        ...        [18, 2]   [11, 0]         MYBL1
# 9        ...        [15, 3]   [24, 1]   RP1-77H15.1
# 10       ...        [15, 3]   [24, 1]        ZNF287
# 11       ...        [15, 3]   [24, 1]        ZNF287
# 12       ...        [30, 3]   [30, 0]          THRB
# 13       ...        [13, 5]   [24, 1]          THRB
# 14       ...         [5, 2]   [12, 0]          ATF6
# 15       ...        [13, 2]    [8, 0]          THRB
# 16       ...         [9, 6]    [9, 0]          ATF6
# 17       ...        [11, 2]   [20, 0]  CTD-2135J3.3
# 18       ...        [11, 2]   [20, 0]  CTD-2135J3.3
# 19       ...        [11, 2]   [20, 0]        SOX7.1
# 20       ...        [11, 2]   [20, 0]          SOX7
# 21       ...         [8, 0]   [18, 5]        TCF7L1
# 22       ...        [20, 0]   [37, 7]          ATF6
# 23       ...        [25, 0]  [20, 27]          ATF6
# 24       ...        [20, 0]   [42, 5]          ATF6
# 25       ...        [14, 0]  [20, 24]          THRB
# 26       ...        [23, 0]  [44, 10]          THRB
# 27       ...        [16, 0]  [16, 19]          THRB
# 28       ...        [35, 0]  [47, 11]          THRB
# 29       ...        [17, 0]  [33, 10]          THRB
# ..       ...            ...       ...           ...
# 32       ...        [25, 0]   [33, 5]          THRB
# 33       ...         [8, 0]    [4, 2]        TCF7L1
# 34       ...        [16, 0]    [8, 5]          THRB
# 35       ...        [25, 0]  [21, 15]          THRB
# 36       ...        [26, 0]  [15, 12]         ZBTB6
# 37       ...        [26, 0]  [15, 12]        ZBTB26
# 38       ...        [26, 0]  [12, 18]         ZBTB6
# 39       ...        [11, 0]   [17, 3]    AC093162.3
# 40       ...        [26, 0]  [12, 18]        ZBTB26
# 41       ...        [11, 0]   [17, 3]        TCF7L1
# 42       ...        [10, 0]   [16, 3]    AC093162.3
# 43       ...        [25, 0]  [25, 11]          THRB
# 44       ...         [8, 0]    [8, 6]        TCF7L1
# 45       ...        [16, 0]    [9, 9]          THRB
# 46       ...        [17, 0]  [37, 18]          THRB
# 47       ...        [17, 0]  [37, 18]           NaN
# 48       ...        [17, 0]  [37, 18]           NaN
# 49       ...        [10, 0]   [16, 3]        TCF7L1
# 50       ...        [25, 0]   [14, 2]          ATF6
# 51       ...        [16, 0]  [10, 10]          THRB
# 52       ...        [19, 0]    [9, 2]        SOX7.1
# 53       ...        [19, 0]    [9, 2]          SOX7
# 54       ...         [8, 0]  [10, 13]        TCF7L1
# 55       ...        [22, 0]   [50, 5]        TCF7L1
# 56       ...        [22, 0]   [50, 5]        TCF7L1
# 57       ...        [19, 0]    [9, 2]         PINX1
# 58       ...        [19, 0]    [9, 2]         PINX1
# 59       ...        [19, 0]    [9, 2]         PINX1
# 60       ...        [12, 0]   [15, 6]        TCF7L1
# 61       ...        [19, 0]    [9, 2]    SNORD112.6
#
#                                      Consequence    Impact            Ref1  \
# 0                                 intron_variant  MODIFIER               A
# 1                                 intron_variant  MODIFIER              AT
# 2                                 intron_variant  MODIFIER      AAAAAGAAAG
# 3                                 intron_variant  MODIFIER               G
# 4          intron_variant&NMD_transcript_variant  MODIFIER               G
# 5                                 intron_variant  MODIFIER               G
# 6                                 intron_variant  MODIFIER               G
# 7                                 intron_variant  MODIFIER               C
# 8                                 intron_variant  MODIFIER               C
# 9                          upstream_gene_variant  MODIFIER    TCTGAGATGGAG
# 10                                intron_variant  MODIFIER    TCTGAGATGGAG
# 11  intron_variant&non_coding_transcript_variant  MODIFIER    TCTGAGATGGAG
# 12                                intron_variant  MODIFIER               T
# 13                                intron_variant  MODIFIER               C
# 14                                intron_variant  MODIFIER  TAAATAAGACAAGG
# 15                                intron_variant  MODIFIER            TAAA
# 16                                intron_variant  MODIFIER           TACAC
# 17                         upstream_gene_variant  MODIFIER               C
# 18            non_coding_transcript_exon_variant  MODIFIER               C
# 19                                intron_variant  MODIFIER               C
# 20                                intron_variant  MODIFIER               C
# 21                                intron_variant  MODIFIER            CTTT
# 22                                intron_variant  MODIFIER               A
# 23                                intron_variant  MODIFIER               G
# 24                                intron_variant  MODIFIER               G
# 25                                intron_variant  MODIFIER               C
# 26                                intron_variant  MODIFIER               C
# 27                                intron_variant  MODIFIER      AAAAAGAAAG
# 28                                intron_variant  MODIFIER               C
# 29                                intron_variant  MODIFIER               C
# ..                                           ...       ...             ...
# 32                                intron_variant  MODIFIER               A
# 33                                intron_variant  MODIFIER            CTTT
# 34                                intron_variant  MODIFIER      AAAAAGAAAG
# 35                                intron_variant  MODIFIER               C
# 36                              missense_variant  MODERATE               T
# 37                       downstream_gene_variant  MODIFIER               T
# 38                              missense_variant  MODERATE               T
# 39                         upstream_gene_variant  MODIFIER               T
# 40                       downstream_gene_variant  MODIFIER               T
# 41                                intron_variant  MODIFIER               T
# 42                         upstream_gene_variant  MODIFIER               A
# 43                                intron_variant  MODIFIER               C
# 44                                intron_variant  MODIFIER            CTTT
# 45                                intron_variant  MODIFIER      AAAAAGAAAG
# 46                                intron_variant  MODIFIER               C
# 47                     regulatory_region_variant  MODIFIER               C
# 48                       TF_binding_site_variant  MODIFIER               C
# 49                                intron_variant  MODIFIER               A
# 50                                intron_variant  MODIFIER               T
# 51                                intron_variant  MODIFIER      AAAAAGAAAG
# 52                                intron_variant  MODIFIER               C
# 53                                intron_variant  MODIFIER               C
# 54                                intron_variant  MODIFIER            CTTT
# 55  intron_variant&non_coding_transcript_variant  MODIFIER               C
# 56                                intron_variant  MODIFIER               C
# 57                                intron_variant  MODIFIER               C
# 58                       downstream_gene_variant  MODIFIER               C
# 59         intron_variant&NMD_transcript_variant  MODIFIER               C
# 60                                intron_variant  MODIFIER             AAC
# 61                       downstream_gene_variant  MODIFIER               C
#
#    Alt1 Ref2 Alt2 Gene_fromScript
# 0     G  NaN  NaN          TCF7L1
# 1     A  NaN  NaN            THRB
# 2     A  NaN  NaN            THRB
# 3     C  NaN  NaN            SOX7
# 4     C  NaN  NaN            SOX7
# 5     C  NaN  NaN            SOX7
# 6     C  NaN  NaN            SOX7
# 7     A  NaN  NaN          TCF7L1
# 8     A  NaN  NaN           MYBL1
# 9     T  NaN  NaN          ZNF287
# 10    T  NaN  NaN          ZNF287
# 11    T  NaN  NaN          ZNF287
# 12    A  NaN  NaN            THRB
# 13    T  NaN  NaN            THRB
# 14    T  NaN  NaN            ATF6
# 15    T  NaN  NaN            THRB
# 16    T  NaN  NaN            ATF6
# 17    A  NaN  NaN            SOX7
# 18    A  NaN  NaN            SOX7
# 19    A  NaN  NaN            SOX7
# 20    A  NaN  NaN            SOX7
# 21    C  NaN  NaN          TCF7L1
# 22    C  NaN  NaN            ATF6
# 23    A  NaN  NaN            ATF6
# 24    A  NaN  NaN            ATF6
# 25    T  NaN  NaN            THRB
# 26    T  NaN  NaN            THRB
# 27    A  NaN  NaN            THRB
# 28    A  NaN  NaN            THRB
# 29    T  NaN  NaN            THRB
# ..  ...  ...  ...             ...
# 32    G  NaN  NaN            THRB
# 33    C  NaN  NaN          TCF7L1
# 34    A  NaN  NaN            THRB
# 35    A  NaN  NaN            THRB
# 36    A  NaN  NaN           ZBTB6
# 37    A  NaN  NaN           ZBTB6
# 38    A  NaN  NaN           ZBTB6
# 39    G  NaN  NaN          TCF7L1
# 40    A  NaN  NaN           ZBTB6
# 41    G  NaN  NaN          TCF7L1
# 42   AG  NaN  NaN          TCF7L1
# 43    A  NaN  NaN            THRB
# 44    C  NaN  NaN          TCF7L1
# 45    A  NaN  NaN            THRB
# 46    T  NaN  NaN            THRB
# 47    T  NaN  NaN            THRB
# 48    T  NaN  NaN            THRB
# 49   AG  NaN  NaN          TCF7L1
# 50    C  NaN  NaN            ATF6
# 51    A  NaN  NaN            THRB
# 52    T  NaN  NaN            SOX7
# 53    T  NaN  NaN            SOX7
# 54    C  NaN  NaN          TCF7L1
# 55    G  NaN  NaN          TCF7L1
# 56    G  NaN  NaN          TCF7L1
# 57    T  NaN  NaN            SOX7
# 58    T  NaN  NaN            SOX7
# 59    T  NaN  NaN            SOX7
# 60    A  NaN  NaN          TCF7L1
# 61    T  NaN  NaN            SOX7
#
# [62 rows x 23 columns]

# %%
writer = pd.ExcelWriter('./MUTECT_TF.xlsx', engine = 'xlsxwriter')
df_combined.to_excel(writer, sheet_name = 'p=0.00005', index=False)

# %% [markdown]
# ### p=0.0001

# %%
gene_list = pd.read_csv('./ATRX_TF_0_0001.csv', header=None).iloc[:, 0]
gene_set = pd.read_csv(
    '../../bitbucket/CNA/data/ref_data/EnsemblGRCh37Genes.tsv', sep='\t')
p1 = gene_set[gene_set['GeneName'].isin(gene_list)].reset_index(drop=True)

# %%
df_list = []
for i in range(p1.shape[0]):
    start = float(p1.iloc[i, 3])
    end = float(p1.iloc[i, 4])
    chromosome = 'chr' + str(p1.iloc[i, 2])
    print('checking:', p1.iloc[i, 1], chromosome + ', ', start, end)
    data = ALL[ALL['Chr1'] == chromosome]
    df = data[(start <= data['Pos1']) & (data['Pos1'] <= end)]
    df['Gene_fromScript'] = p1.iloc[i, 1]
    df_list.append(df)
df_combined = pd.concat(df_list)
# Out:
# checking: ZNF213 chr16,  3179778.0 3192806.0
# checking: RFX3 chr9,  3218297.0 3526004.0
# checking: ZNF561 chr19,  9715356.0 9732075.0
# checking: ZNF562 chr19,  9759330.0 9785776.0
# checking: SOX7 chr8,  10581278.0 10697357.0
# checking: CASZ1 chr1,  10696661.0 10856707.0
# checking: ZNF287 chr17,  16454701.0 16472520.0
# checking: MYOD1 chr11,  17741115.0 17743678.0
# checking: E2F3 chr6,  20402398.0 20493941.0
# /Users/scai/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# checking: ZNF280A chr22,  22868060.0 22874613.0
# checking: ZNF70 chr22,  24083769.0 24093279.0
# checking: THRB chr3,  24158651.0 24536773.0
# checking: HOXA2 chr7,  27139721.0 27142430.0
# checking: HOXA9 chr7,  27202054.0 27210117.0
# checking: FOXS1 chr20,  30432103.0 30433420.0
# checking: PAX6 chr11,  31806340.0 31839509.0
# checking: ZBTB12 chrHSCHR6_MHC_QBL,  31857779.0 31860166.0
# checking: ZNF567 chr19,  37178514.0 37218603.0
# checking: CRX chr19,  48322703.0 48346587.0
# checking: GATA1 chrX,  48644962.0 48652716.0
# checking: TCF4 chr18,  52889562.0 53332018.0
# checking: KLF8 chrX,  56258854.0 56314322.0
# checking: ZNF582 chr19,  56887413.0 56904914.0
# checking: HESX1 chr3,  57231944.0 57260549.0
# checking: GLI1 chr12,  57853918.0 57866045.0
# checking: FOXB1 chr15,  60296421.0 60353929.0
# checking: ESRRA chr11,  64073044.0 64084215.0
# checking: MEIS1 chr2,  66660584.0 66801001.0
# checking: MYBL1 chr8,  67474410.0 67526482.0
# checking: MYF6 chr12,  81101277.0 81103253.0
# checking: TCF7L1 chr2,  85360533.0 85537511.0
# checking: ALX1 chr12,  85673885.0 85695562.0
# checking: NR2C1 chr12,  95414005.0 95467479.0
# checking: ZNF367 chr9,  99148223.0 99180611.0
# checking: OSR2 chr8,  99956631.0 99964332.0
# checking: ASCL1 chr12,  103351464.0 103354294.0
# checking: ZFPM2 chr8,  106330920.0 106816760.0
# checking: GLI2 chr2,  121493199.0 121750229.0
# checking: ZBTB6 chr9,  125670335.0 125675609.0
# checking: PBX3 chr9,  128509624.0 128729656.0
# checking: ZNF891 chr12,  133694740.0 133707059.0
# checking: EGR1 chr5,  137801179.0 137805004.0
# checking: EDF1 chr9,  139756571.0 139760738.0
# checking: HSFX1 chrX,  148855726.0 148858525.0
# checking: ZNF687 chr1,  151254094.0 151264656.0
# checking: HAND1 chr5,  153854532.0 153857824.0
# checking: ATF6 chr1,  161736084.0 161933860.0
# checking: TBX19 chr1,  168250278.0 168283664.0
# checking: HOXD9 chr2,  176987088.0 176989853.0
# checking: HOXD8 chr2,  176994422.0 176997423.0

# %%
df_combined = df_combined.sort_values(by=['Name']).reset_index(drop=True)
df_combined['Pos1'] = df_combined['Pos1'].astype(str)
df_combined
# Out:
#                                                    Key                  Name  \
# 0    IND_MuTect2_MODIFIER_RFX3_chr9_3457139_CAAAAAA...      N_IIICF_402DE_D2
# 1        SNP_MuTect2_MODIFIER_FOXB1_chr15_60352182_G_T      N_IIICF_402DE_D2
# 2        SNP_MuTect2_MODIFIER_TCF7L1_chr2_85494511_A_G      N_IIICF_402DE_D2
# 3    IND_MuTect2_MODIFIER_THRB_chr3_24194460_AAAAAG...      N_IIICF_402DE_D2
# 4        SNP_MuTect2_MODIFIER_ZFPM2_chr8_106426225_G_A      N_IIICF_402DE_D2
# 5        SNP_MuTect2_MODIFIER_ZFPM2_chr8_106426225_G_A      N_IIICF_402DE_D2
# 6    SNP_MuTect2_MODIFIER_RP11-127H5.1_chr8_1064262...      N_IIICF_402DE_D2
# 7       SNP_MuTect2_MODERATE_ZNF567_chr19_37211190_C_G      N_IIICF_402DE_D2
# 8       SNP_MuTect2_MODIFIER_ZNF850_chr19_37211190_C_G      N_IIICF_402DE_D2
# 9       SNP_MuTect2_MODIFIER_ZNF567_chr19_37211190_C_G      N_IIICF_402DE_D2
# 10        IND_MuTect2_MODIFIER_THRB_chr3_24363123_AT_A      N_IIICF_402DE_D2
# 11        SNP_MuTect2_MODIFIER_GLI2_chr2_121663454_G_C      N_IIICF_402DE_D2
# 12        SNP_MuTect2_MODIFIER_GLI2_chr2_121663454_G_C      N_IIICF_402DE_D2
# 13        SNP_MuTect2_MODIFIER_GLI2_chr2_121663454_G_C      N_IIICF_402DE_D2
# 14        SNP_MuTect2_MODIFIER_PBX3_chr9_128725966_G_C      N_IIICF_402DE_D2
# 15        SNP_MuTect2_MODIFIER_PBX3_chr9_128725966_G_C      N_IIICF_402DE_D2
# 16        SNP_MuTect2_MODIFIER_PBX3_chr9_128725966_G_C      N_IIICF_402DE_D2
# 17   IND_MuTect2_MODIFIER_AL365202.1_chr9_3457139_C...      N_IIICF_402DE_D2
# 18       SNP_MuTect2_MODIFIER_FOXB1_chr15_60352180_T_G      N_IIICF_402DE_D2
# 19      SNP_MuTect2_MODIFIER_ZNF567_chr19_37211190_C_G      N_IIICF_402DE_D2
# 20        SNP_MuTect2_MODIFIER_PAX6_chr11_31837640_C_A  N_IIICF_E6E7_C4_post
# 21        SNP_MuTect2_MODIFIER_PAX6_chr11_31837640_C_A  N_IIICF_E6E7_C4_post
# 22        SNP_MuTect2_MODIFIER_PAX6_chr11_31837640_C_A  N_IIICF_E6E7_C4_post
# 23        SNP_MuTect2_MODIFIER_RCN1_chr11_31837640_C_A  N_IIICF_E6E7_C4_post
# 186        SNP_MuTect2_MODIFIER_CRX_chr19_48342264_C_A            U_IIICF_d2
# 187         SNP_MuTect2_MODIFIER_RFX3_chr9_3250175_A_G            U_IIICF_d2
# 188       SNP_MuTect2_MODIFIER_PINX1_chr8_10643191_C_T            U_IIICF_d2
# 189       SNP_MuTect2_MODIFIER_GLI2_chr2_121658563_C_G            U_IIICF_d2
# 190       SNP_MuTect2_MODIFIER_GLI2_chr2_121658563_C_G            U_IIICF_d2
# 191  SNP_MuTect2_MODIFIER_RP11-127H5.1_chr8_1064020...            U_IIICF_d2
# 192      SNP_MuTect2_MODIFIER_ZFPM2_chr8_106402080_C_T            U_IIICF_d2
#
#       Source  dbSNP Type   Chr1         Pos1  Chr2  Pos2         Qual1  \
# 0    MuTect2  False  IND   chr9    3457139.0   NaN   NaN   3.86:-1.179
# 1    MuTect2  False  SNP  chr15   60352182.0   NaN   NaN   3.33:-1.158
# 2    MuTect2  False  SNP   chr2   85494511.0   NaN   NaN  2.32:-0.9477
# 3    MuTect2  False  IND   chr3   24194460.0   NaN   NaN   4.83:-1.262
# 4    MuTect2  False  SNP   chr8  106426225.0   NaN   NaN    6.92:-1.38
# 5    MuTect2  False  SNP   chr8  106426225.0   NaN   NaN    6.92:-1.38
# 6    MuTect2  False  SNP   chr8  106426225.0   NaN   NaN    6.92:-1.38
# 7    MuTect2  False  SNP  chr19   37211190.0   NaN   NaN   6.88:-1.387
# 8    MuTect2  False  SNP  chr19   37211190.0   NaN   NaN   6.88:-1.387
# 9    MuTect2  False  SNP  chr19   37211190.0   NaN   NaN   6.88:-1.387
# 10   MuTect2  False  IND   chr3   24363123.0   NaN   NaN    6.9:-1.402
# 11   MuTect2  False  SNP   chr2  121663454.0   NaN   NaN  2.61:-0.9558
# 12   MuTect2  False  SNP   chr2  121663454.0   NaN   NaN  2.61:-0.9558
# 13   MuTect2  False  SNP   chr2  121663454.0   NaN   NaN  2.61:-0.9558
# 14   MuTect2  False  SNP   chr9  128725966.0   NaN   NaN   8.13:-1.454
# 15   MuTect2  False  SNP   chr9  128725966.0   NaN   NaN   8.13:-1.454
# 16   MuTect2  False  SNP   chr9  128725966.0   NaN   NaN   8.13:-1.454
# 17   MuTect2  False  IND   chr9    3457139.0   NaN   NaN   3.86:-1.179
# 18   MuTect2  False  SNP  chr15   60352180.0   NaN   NaN   3.33:-1.158
# 19   MuTect2  False  SNP  chr19   37211190.0   NaN   NaN   6.88:-1.387
# 20   MuTect2  False  SNP  chr11   31837640.0   NaN   NaN   3.61:-1.114
# 21   MuTect2  False  SNP  chr11   31837640.0   NaN   NaN   3.61:-1.114
# 22   MuTect2  False  SNP  chr11   31837640.0   NaN   NaN   3.61:-1.114
# 23   MuTect2  False  SNP  chr11   31837640.0   NaN   NaN   3.61:-1.114
# 24   MuTect2  False  SNP   chr2   85445790.0   NaN   NaN    6.92:-1.38
# 3         ...        [16, 0]   [12, 4]           THRB
# 4         ...        [23, 0]   [29, 9]          ZFPM2
# 5         ...        [23, 0]   [29, 9]          ZFPM2
# 6         ...        [23, 0]   [29, 9]   RP11-127H5.1
# 7         ...        [23, 0]   [18, 5]         ZNF567
# 8         ...        [23, 0]   [18, 5]         ZNF850
# 9         ...        [23, 0]   [18, 5]         ZNF567
# 10        ...        [23, 0]  [16, 15]           THRB
# 11        ...        [11, 1]   [31, 4]           GLI2
# 12        ...        [11, 1]   [31, 4]           GLI2
# 13        ...        [11, 1]   [31, 4]           GLI2
# 14        ...        [27, 0]   [19, 2]           PBX3
# 15        ...        [27, 0]   [19, 2]           PBX3
# 16        ...        [27, 0]   [19, 2]           PBX3
# 17        ...        [13, 0]   [12, 3]     AL365202.1
# 18        ...        [11, 0]   [12, 4]          FOXB1
# 19        ...        [23, 0]   [18, 5]         ZNF567
# 20        ...        [19, 5]   [12, 0]           PAX6
# 21        ...        [19, 5]   [12, 0]           PAX6
# 22        ...        [19, 5]   [12, 0]           PAX6
# 23        ...        [19, 5]   [12, 0]           RCN1
# 24        ...        [13, 5]   [23, 0]         TCF7L1
# 25        ...         [9, 2]   [16, 0]          ZFPM2
# 26        ...         [9, 2]   [16, 0]          ZFPM2
# 27        ...         [9, 2]   [16, 0]  RP11-152P17.2
# 28        ...         [9, 2]   [16, 0]          ZFPM2
# 29        ...        [19, 5]   [12, 0]           RCN1
# ..        ...            ...       ...            ...
# 163       ...         [8, 0]  [10, 13]         TCF7L1
# 164       ...        [22, 0]   [50, 5]         TCF7L1
# 165       ...        [19, 0]    [9, 2]           SOX7
# 166       ...        [19, 0]    [9, 2]         SOX7.1
# 167       ...        [22, 0]   [50, 5]         TCF7L1
# 168       ...        [16, 0]  [10, 10]           THRB
# 169       ...        [14, 0]   [37, 3]         ZNF367
# 170       ...        [19, 0]    [9, 2]          PINX1
# 171       ...        [26, 0]   [41, 3]           GLI2
# 172       ...        [23, 0]   [34, 3]         TPRX2P
# 173       ...        [30, 0]   [14, 4]           RFX3
# 174       ...        [30, 0]   [14, 4]           RFX3
# 175       ...        [14, 0]   [26, 5]          ZFPM2
# 176       ...        [14, 0]   [26, 5]   RP11-127H5.1
# 177       ...        [25, 0]  [14, 23]          ZFPM2
# 178       ...        [25, 0]  [14, 23]   RP11-127H5.1
# 179       ...        [25, 0]  [14, 23]          ZFPM2
# 180       ...        [12, 0]   [15, 6]         TCF7L1
# 181       ...        [23, 0]   [34, 3]            CRX
# 182       ...        [26, 0]  [22, 13]          ZFPM2
# 183       ...        [19, 0]   [14, 3]           TCF4
# 184       ...        [19, 0]   [14, 3]           TCF4
# 185       ...        [23, 0]   [34, 3]            CRX
# 186       ...        [23, 0]   [34, 3]            CRX
# 187       ...        [29, 0]    [9, 5]           RFX3
# 188       ...        [19, 0]    [9, 2]          PINX1
# 189       ...        [26, 0]   [41, 3]           GLI2
# 190       ...        [26, 0]   [41, 3]           GLI2
# 191       ...        [26, 0]  [22, 13]   RP11-127H5.1
# 192       ...        [26, 0]  [22, 13]          ZFPM2
#
#                                       Consequence    Impact  \
# 0                                  intron_variant  MODIFIER
# 1    intron_variant&non_coding_transcript_variant  MODIFIER
# 2                                  intron_variant  MODIFIER
# 3                                  intron_variant  MODIFIER
# 4                                  intron_variant  MODIFIER
# 5    intron_variant&non_coding_transcript_variant  MODIFIER
# 6           intron_variant&NMD_transcript_variant  MODIFIER
# 7                                missense_variant  MODERATE
# 8                                  intron_variant  MODIFIER
# 9                                  intron_variant  MODIFIER
# 10                                 intron_variant  MODIFIER
# 11                                 intron_variant  MODIFIER
# 12          intron_variant&NMD_transcript_variant  MODIFIER
# 13   intron_variant&non_coding_transcript_variant  MODIFIER
# 14                                 intron_variant  MODIFIER
# 15          intron_variant&NMD_transcript_variant  MODIFIER
# 16   intron_variant&non_coding_transcript_variant  MODIFIER
# 17                                 intron_variant  MODIFIER
# 18   intron_variant&non_coding_transcript_variant  MODIFIER
# 19          intron_variant&NMD_transcript_variant  MODIFIER
# 20   intron_variant&non_coding_transcript_variant  MODIFIER
# 21                          upstream_gene_variant  MODIFIER
# 22                                 intron_variant  MODIFIER
# 23                          upstream_gene_variant  MODIFIER
# 24                                 intron_variant  MODIFIER
# 25                                 intron_variant  MODIFIER
# 26                        downstream_gene_variant  MODIFIER
# 27   intron_variant&non_coding_transcript_variant  MODIFIER
# 28   intron_variant&non_coding_transcript_variant  MODIFIER
# 29                                 intron_variant  MODIFIER
# ..                                            ...       ...
# 163                                intron_variant  MODIFIER
# 164  intron_variant&non_coding_transcript_variant  MODIFIER
# 165                                intron_variant  MODIFIER
# 166                                intron_variant  MODIFIER
# 167                                intron_variant  MODIFIER
# 168                                intron_variant  MODIFIER
# 169                                intron_variant  MODIFIER
# 170         intron_variant&NMD_transcript_variant  MODIFIER
# 171                                intron_variant  MODIFIER
# 172                                intron_variant  MODIFIER
# 173                       downstream_gene_variant  MODIFIER
# 174                                intron_variant  MODIFIER
# 175                                intron_variant  MODIFIER
# 176         intron_variant&NMD_transcript_variant  MODIFIER
# 177                                intron_variant  MODIFIER
# 178         intron_variant&NMD_transcript_variant  MODIFIER
# 179  intron_variant&non_coding_transcript_variant  MODIFIER
# 180                                intron_variant  MODIFIER
# 181                                intron_variant  MODIFIER
# 182  intron_variant&non_coding_transcript_variant  MODIFIER
# 183  intron_variant&non_coding_transcript_variant  MODIFIER
# 184                                intron_variant  MODIFIER
# 185                         upstream_gene_variant  MODIFIER
# 186                       downstream_gene_variant  MODIFIER
# 187                                intron_variant  MODIFIER
# 188                       downstream_gene_variant  MODIFIER
# 189         intron_variant&NMD_transcript_variant  MODIFIER
# 190  intron_variant&non_coding_transcript_variant  MODIFIER
# 191         intron_variant&NMD_transcript_variant  MODIFIER
# 192                                intron_variant  MODIFIER
#
#                    Ref1 Alt1 Ref2 Alt2 Gene_fromScript
# 0    CAAAAAAAAAAAAAAAAA    C  NaN  NaN            RFX3
# 1                     G    T  NaN  NaN           FOXB1
# 2                     A    G  NaN  NaN          TCF7L1
# 3            AAAAAGAAAG    A  NaN  NaN            THRB
# 4                     G    A  NaN  NaN           ZFPM2
# 5                     G    A  NaN  NaN           ZFPM2
# 6                     G    A  NaN  NaN           ZFPM2
# 7                     C    G  NaN  NaN          ZNF567
# 8                     C    G  NaN  NaN          ZNF567
# 9                     C    G  NaN  NaN          ZNF567
# 10                   AT    A  NaN  NaN            THRB
# 11                    G    C  NaN  NaN            GLI2
# 12                    G    C  NaN  NaN            GLI2
# 13                    G    C  NaN  NaN            GLI2
# 14                    G    C  NaN  NaN            PBX3
# 15                    G    C  NaN  NaN            PBX3
# 16                    G    C  NaN  NaN            PBX3
# 17   CAAAAAAAAAAAAAAAAA    C  NaN  NaN            RFX3
# 18                    T    G  NaN  NaN           FOXB1
# 19                    C    G  NaN  NaN          ZNF567
# 20                    C    A  NaN  NaN            PAX6
# 21                    C    A  NaN  NaN            PAX6
# 22                    C    A  NaN  NaN            PAX6
# 23                    C    A  NaN  NaN            PAX6
# 24                    C    A  NaN  NaN          TCF7L1
# 25                    C    G  NaN  NaN           ZFPM2
# 26                    C    G  NaN  NaN           ZFPM2
# 27                    C    G  NaN  NaN           ZFPM2
# 28                    C    G  NaN  NaN           ZFPM2
# 29                    C    A  NaN  NaN            PAX6
# ..                  ...  ...  ...  ...             ...
# 163                CTTT    C  NaN  NaN          TCF7L1
# 164                   C    G  NaN  NaN          TCF7L1
# 165                   C    T  NaN  NaN            SOX7
# 166                   C    T  NaN  NaN            SOX7
# 167                   C    G  NaN  NaN          TCF7L1
# 168          AAAAAGAAAG    A  NaN  NaN            THRB
# 169                   A    C  NaN  NaN          ZNF367
# 170                   C    T  NaN  NaN            SOX7
# 171                   C    G  NaN  NaN            GLI2
# 172                   C    A  NaN  NaN             CRX
# 173                   T    G  NaN  NaN            RFX3
# 174                   T    G  NaN  NaN            RFX3
# 175                   G    T  NaN  NaN           ZFPM2
# 176                   G    T  NaN  NaN           ZFPM2
# 177                   G    A  NaN  NaN           ZFPM2
# 178                   G    A  NaN  NaN           ZFPM2
# 179                   G    A  NaN  NaN           ZFPM2
# 180                 AAC    A  NaN  NaN          TCF7L1
# 181                   C    A  NaN  NaN             CRX
# 182                   C    T  NaN  NaN           ZFPM2
# 183                   G    A  NaN  NaN            TCF4
# 184                   G    A  NaN  NaN            TCF4
# 185                   C    A  NaN  NaN             CRX
# 186                   C    A  NaN  NaN             CRX
# 187                   A    G  NaN  NaN            RFX3
# 188                   C    T  NaN  NaN            SOX7
# 189                   C    G  NaN  NaN            GLI2
# 190                   C    G  NaN  NaN            GLI2
# 191                   C    T  NaN  NaN           ZFPM2
# 192                   C    T  NaN  NaN           ZFPM2
#
# [193 rows x 23 columns]

# %%
df_combined.to_excel(writer, sheet_name = 'p=0.0001', index=False)

# %%
writer.save()
writer.close()
